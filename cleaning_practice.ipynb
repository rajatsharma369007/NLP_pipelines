# %% [markdown]
# # Cleaning Quiz: Udacity's Course Catalog
# It's your turn! Udacity's [course catalog page](https://www.udacity.com/courses/all) has changed since the last video was filmed. One notable change is the introduction of  _schools_.
#
# In this activity, you're going to perform similar actions with BeautifulSoup to extract the following information from each course listing on the page:
# 1. The course name - e.g. "Data Analyst"
# 2. The school the course belongs to - e.g. "School of Data Science"
#
# **Note: All solution notebooks can be found by clicking on the Jupyter icon on the top left of this workspace.**

# %% [markdown]
# ### Step 1: Get text from Udacity's course catalog web page
# You can use the `requests` library to do this.
#
# You may have to scroll down past the javascript and CSS in the output of the last cell in this section to see the text.

# %%
# import statements
import requests
from bs4 import BeautifulSoup

# %%
# fetch web page
r = requests.get("https://in.udacity.com/courses/all")

# %%
# display text from web page
print(r.text)
# Out:
# <!DOCTYPE html><html><head>
#   <meta charset="utf-8">
#   <script type="text/javascript" class="ng-star-inserted">window.NREUM||(NREUM={}),__nr_require=function(t,n,e){function r(e){if(!n[e]){var o=n[e]={exports:{}};t[e][0].call(o.exports,function(n){var o=t[e][1][n];return r(o||n)},o,o.exports)}return n[e].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<e.length;o++)r(e[o]);return r}({1:[function(t,n,e){function r(t){try{s.console&&console.log(t)}catch(n){}}var o,i=t("ee"),a=t(15),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,n,e){r(e.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,n){return t}).join(", ")))},{}],2:[function(t,n,e){function r(t,n,e,r,s){try{p?p-=1:o(s||new UncaughtException(t,n,e),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,n,e){this.message=t||"Uncaught error with no additional information",this.sourceURL=n,this.line=e}function o(t,n){var e=n?null:c.now();i("err",[t,e])}var i=t("handle"),a=t(16),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(8),t(7),"addEventListener"in window&&t(5),c.xhrWrappable&&t(9),d=!0)}s.on("fn-start",function(t,n,e){d&&(p+=1)}),s.on("fn-err",function(t,n,e){d&&!e[l]&&(f(e,l,function(){return!0}),this.thrown=!0,o(e))}),s.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,n,e){t("loader").features.ins=!0},{}],4:[function(t,n,e){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(8),s=t(7),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",y="pushState",g=t("loader");g.features.stn=!0,t(6);var b=NREUM.o.EV;o.on(m,function(t,n){var e=t[0];e instanceof b&&(this.bstStart=g.now())}),o.on(w,function(t,n){var e=t[0];e instanceof b&&i("bst",[e,n,this.bstStart,g.now()])}),a.on(m,function(t,n,e){this.bstStart=g.now(),this.bstType=e}),a.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),this.bstType])}),s.on(m,function(){this.bstStart=g.now()}),s.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),"requestAnimationFrame"])}),o.on(y+p,function(t){this.time=g.now(),this.startPath=location.pathname+location.hash}),o.on(y+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+c]?window.performance[f](u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["c"+c]()},!1):window.performance[f]("webkit"+u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+c]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,n,e){function r(t){for(var n=t;n&&!n.hasOwnProperty(u);)n=Object.getPrototypeOf(n);n&&o(n)}function o(t){s.inPlace(t,[u,d],"-",i)}function i(t,n){return t[1]}var a=t("ee").get("events"),s=t(18)(a,!0),c=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";n.exports=a,"getPrototypeOf"in Object?(r(document),r(window),r(f.prototype)):f.prototype.hasOwnProperty(u)&&(o(window),o(f.prototype)),a.on(u+"-start",function(t,n){var e=t[1],r=c(e,"nr@wrapped",function(){function t(){if("function"==typeof e.handleEvent)return e.handleEvent.apply(e,arguments)}var n={object:t,"function":e}[typeof e];return n?s(n,"fn-",null,n.name||"anonymous"):e});this.wrapped=t[1]=r}),a.on(d+"-start",function(t){t[1]=this.wrapped||t[1]})},{}],6:[function(t,n,e){var r=t("ee").get("history"),o=t(18)(r);n.exports=r ...
# ;NREUM.info={beacon:"bam.nr-data.net",errorBeacon:"bam.nr-data.net",licenseKey:"2059d2614a",applicationID:"218955133",sa:1}</script><meta name="newrelic">
#   <title>Courses | Udacity</title>
#   <base href="/"><link rel="preload" href="runtime.5a236107fd7b72276ee5.js" as="script"><link rel="preload" href="polyfills.b4dc5834e54404d27544.js" as="script"><link rel="preload" href="scripts.371a0cb6c7cd60c0dc25.js" as="script"><link rel="preload" href="main.98d77d22ab81212b18ae.js" as="script">
#
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <link rel="icon" type="image/x-icon" href="favicon.ico">
#   <link rel="dns-prefetch" href="https://sgmt.udacity.com">
#   <link rel="dns-prefetch" href="https://classroom.udacity.com">
#   <!-- inject:js -->
#   <script src="assets/vendor/segment-a8f352c7c0.js" async="" data-analytics-bootstrap=""></script>
#   <!-- endinject -->
# <link rel="stylesheet" href="styles.13e7218d55cbf7de9275.css"><style ng-transition="iridium-in">html[_ngcontent-sc0] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc0], *[_ngcontent-sc0]::after, *[_ngcontent-sc0]::before {
#   box-sizing: inherit; }
#
#
#
# html.wf-loading[_ngcontent-sc0]   .tk-font[_ngcontent-sc0] {
#   visibility: hidden; }
#
# html.wf-active[_ngcontent-sc0]   .tk-font[_ngcontent-sc0] {
#   visibility: initial; }
#
#
#
# .tk-font-balboa[_ngcontent-sc0] {
#   font-family: balboa, 'Open Sans', sans-serif; }
#
# .tk-font-balboa-condensed[_ngcontent-sc0] {
#   font-family: balboa-extra-condensed, 'Open Sans', sans-serif; }
#
# a[_ngcontent-sc0] {
#   color: darkviolet; }
#
# .popup[_ngcontent-sc0]   span[_ngcontent-sc0] {
#   font-size: 0.85rem; }
#
# .popup[_ngcontent-sc0]   span.download-app-text[_ngcontent-sc0] {
#     margin-top: 0.75rem;
#     display: inline-block; }
#
# .popup[_ngcontent-sc0]   .white-text[_ngcontent-sc0] {
#   color: #fff;
#   margin-top: 1.5rem; }
#
# body[_ngcontent-sc0] {
#   color: #028bb1; }
#
# [_nghost-sc0] {
#   display: block;
#   position: relative; }
#
# .sticky.isFixed[_nghost-sc0]   ir-header[_ngcontent-sc0], .sticky.isFixed   [_nghost-sc0]   ir-header[_ngcontent-sc0] {
#   top: auto; }
#
# @media screen and (min-width: 48rem) {
#     .sticky.isFixed[_nghost-sc0]   ir-header[_ngcontent-sc0], .sticky.isFixed   [_nghost-sc0]   ir-header[_ngcontent-sc0] {
#       top: 52px; } }</style><style ng-transition="iridium-in">html[_ngcontent-sc1] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc1], *[_ngcontent-sc1]::after, *[_ngcontent-sc1]::before {
#   box-sizing: inherit; }
#
#
#
# html.wf-loading[_ngcontent-sc1]   .tk-font[_ngcontent-sc1] {
#   visibility: hidden; }
#
# html.wf-active[_ngcontent-sc1]   .tk-font[_ngcontent-sc1] {
#   visibility: initial; }
#
#
#
# .tk-font-balboa[_ngcontent-sc1] {
#   font-family: balboa, 'Open Sans', sans-serif; }
#
# .tk-font-balboa-condensed[_ngcontent-sc1] {
#   font-family: balboa-extra-condensed, 'Open Sans', sans-serif; }
#
# .invisible[_ngcontent-sc1] {
#   visibility: hidden !important; }
#
# .hide[_ngcontent-sc1] {
#   display: none !important; }
#
# .show[_ngcontent-sc1] {
#   display: block !important; }
#
# .sr-only[_ngcontent-sc1] {
#   height: 1px;
#   width: 1px;
#   overflow: hidden;
#   position: absolute !important;
#   clip: rect(1px, 1px, 1px, 1px); }
#
# .hidden-xs-up[_ngcontent-sc1] {
#   display: none !important; }
#
# @media (max-width: 479px) {
#   .hidden-xs-down[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (min-width: 480px) {
#   .hidden-sm-up[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (max-width: 767px) {
#   .hidden-sm-down[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (min-width: 768px) {
#   .hidden-md-up[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (max-width: 991px) {
#   .hidden-md-down[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (min-width: 992px) {
#   .hidden-lg-up[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (max-width: 1179px) {
#   .hidden-lg-down[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (min-width: 1180px) {
#   .hidden-xl-up[_ngcontent-sc1] {
#     display: none !important; } }
#
# .hidden-xl-down[_ngcontent-sc1] {
#   display: none !important; }
#
# .visible-print-block[_ngcontent-sc1] {
#   display: none !important; }
#
# @media print {
#     .visible-print-block[_ngcontent-sc1] {
#       display: block !important; } }
#
# .visible-print-inline[_ngcontent-sc1] {
#   display: none !important; }
#
# @media print {
#     .visible-print-inline[_ngcontent-sc1] {
#       display: inline !important; } }
#
# .visible-print-inline-block[_ngcontent-sc1] {
#   display: none !important; }
#
# @media print {
#     .visible-print-inline-block[_ngcontent-sc1] {
#       display: inline-block !important; } }
#
# @media print {
#   .hidden-print[_ngcontent-sc1] {
#     display: none !important; } }
#
# #contain-all[_ngcontent-sc1] {
#   width: 100%;
#   overflow: hidden;
#   background: #fff;
#   -webkit-backface-visibility: hidden;
#           backface-visibility: hidden;
#   -webkit-transform-style: preserve-3d; }
#
# .outer_contain[_ngcontent-sc1] {
#   margin: 0 auto;
#   max-width: 90rem; }
#
# .contain[_ngcontent-sc1] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto;
#   padding-top: 3rem;
#   padding-bottom: 3rem;
#   padding-left: 0.75rem;
#   padding-right: 0.75rem; }
#
# .contain[_ngcontent-sc1]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# @media screen and (min-width: 48rem) {
#
#     .contain[_ngcontent-sc1] {
#       padding-top: 6rem;
#       padding-bottom: 6rem; } }
#
# @media screen and (min-width: 30rem) {
#
#     .contain[_ngcontent-sc1] {
#       padding-left: 0.99rem;
#       padding-right: 0.99rem; } }
#
# @media screen and (min-width: 48rem) {
#
#     .contain[_ngcontent-sc1] {
#       padding-left: 1.5rem;
#       padding-right: 1.5rem; } }
#
# @media screen and (min-width: 73.75rem) {
#
#     .contain[_ngcontent-sc1] {
#       padding-left: 0;
#       padding-right: 0; } }
#
# .contain.no-padding[_ngcontent-sc1] {
#     padding: 0; }
#
# .contain.no-padding-top[_ngcontent-sc1] {
#     padding-top: 0; }
#
# .contain.no-padding-bottom[_ngcontent-sc1] {
#     padding-bottom: 0; }
#
# .contain--none[_ngcontent-sc1] {
#     padding-top: 0rem;
#     padding-bottom: 0rem;
#     margin: 0 auto; }
#
# @media screen and (min-width: 48rem) {
#
#       .contain--none[_ngcontent-sc1] {
#         padding-top: 0rem;
#         padding-bottom: 0rem; } }
#
# .contain--small[_ngcontent-sc1] {
#     padding-top: 3rem;
#     padding-bottom: 3rem;
#     margin: 0 auto; }
#
# @media screen and (min-width: 48rem) {
#
#       .contain--small[_ngcontent-sc1] {
#         padding-top: 4.5rem;
#         padding-bottom: 4.5rem; } }
#
# .cards_contain[_ngcontent-sc1] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto; }
#
# .cards_contain[_ngcontent-sc1]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# [_ngcontent-sc1]:-webkit-full-screen-ancestor {
#   -webkit-animation: none !important;
#           animation: none !important;
#   -webkit-animation-fill-mode: none !important;
#   animation-fill-mode: none !important; }
#
# [_ngcontent-sc1]:target:before {
#   content: '';
#   display: inline-block;
#   height: 130px;
#   margin: -130px 0 0; }
#
# .header[_ngcontent-sc1] {
#   max-width: 100%;
#   margin-left: auto;
#   margin-right: auto; }
#
# .header[_ngcontent-sc1]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# .header.header--clone[_ngcontent-sc1] {
#     width: 100%;
#     top: -1000px; }
#
# .header.header--clone[_ngcontent-sc1]   .header__navbar[_ngcontent-sc1] {
#       height: 4.5rem; }
#
# .header.header--stick[_ngcontent-sc1] {
#     top: 0;
#     background-color: #fff;
#     z-index: 8000;
#     box-shadow: 0px 1px 2px rgba(0, 0, 0, 0.1); }
#
# .header__navbar[_ngcontent-sc1] {
#     max-width: 73.75rem;
#     margin-left: auto;
#     margin-right: auto;
#     height: 4.5rem;
#     padding: 0 1.5em; }
#
# .header__navbar[_ngcontent-sc1]::after {
#       clear: both;
#       content: "";
#       display: table; }
#
# @media screen and (min-width: 48rem) {
#       .header__navbar[_ngcontent-sc1] {
#         height: 6rem; } }
#
# @media screen and (min-width: 73.75rem) {
#       .header__navbar[_ngcontent-sc1] {
#         padding: 0; } }
#
# .header__navbar--toggle[_ngcontent-sc1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69491525%;
#       width: 15.25423729%; }
#
# .header__navbar--toggle[_ngcontent-sc1]:last-child {
#         margin-right: 0; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--toggle[_ngcontent-sc1] {
#           display: none; } }
#
# .header__navbar--logo[_ngcontent-sc1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69491525%;
#       width: 66.10169492%; }
#
# .header__navbar--logo[_ngcontent-sc1]:last-child {
#         margin-right: 0; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc1] {
#           float: left;
#           display: block;
#           margin-right: 0.84033613%;
#           width: 20.16806723%; }
#           .header__navbar--logo[_ngcontent-sc1]:last-child {
#             margin-right: 0; } }
#
# .header__navbar--catalog[_ngcontent-sc1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       display: none; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--catalog[_ngcontent-sc1] {
#           float: left;
#           display: block;
#           margin-right: 0.84033613%;
#           width: 7.56302521%; }
#           .header__navbar--catalog[_ngcontent-sc1]:last-child {
#             margin-right: 0; } }
#
# .header__navbar--navigation[_ngcontent-sc1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       display: none; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--navigation[_ngcontent-sc1] {
#           float: left;
#           display: block;
#           margin-right: 1.69491525%;
#           width: 74.57627119%; }
#           .header__navbar--navigation[_ngcontent-sc1]:last-child {
#             margin-right: 0; } }
#
# .header__navbar--logo[_ngcontent-sc1] {
#     text-align: center; }
#
# @media screen and (min-width: 62rem) {
#       .header__navbar--logo[_ngcontent-sc1] {
#         text-align: left; } }
#
# .header__navbar--logo[_ngcontent-sc1]   .logo-wordmark[_ngcontent-sc1] {
#       width: 11.25rem;
#       height: 1.875rem;
#       display: none; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc1]   .logo-wordmark[_ngcontent-sc1] {
#           display: block; } }
#
# .header__navbar--logo[_ngcontent-sc1]   .logo-mark[_ngcontent-sc1] {
#       display: block;
#       margin: 0 auto;
#       width: 1.875rem;
#       height: 1.875rem; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc1]   .logo-mark[_ngcontent-sc1] {
#           display: none; } }
#
# .header__navbar--toggle[_ngcontent-sc1]   .nav-toggle[_ngcontent-sc1] {
#     display: block;
#     width: 1.25rem;
#     height: 1.25rem;
#     cursor: pointer;
#     transition: -webkit-transform .25s ease;
#     transition: transform .25s ease;
#     transition: transform .25s ease, -webkit-transform .25s ease; }
#
# .header__navbar--toggle[_ngcontent-sc1]   .nav-toggle[_ngcontent-sc1]   .bar[_ngcontent-sc1] {
#       display: block;
#       width: 100%;
#       height: 0.1875rem;
#       margin-left: -0.5rem;
#       margin-top: 0.1875rem;
#       background: #02b3e4;
#       transition: opacity .25s ease, -webkit-transform .25s ease;
#       transition: opacity .25s ease, transform .25s ease;
#       transition: opacity .25s ease, transform .25s ease, -webkit-transform .25s ease;
#       -webkit-user-select: none;
#          -moz-user-select: none;
#           -ms-user-select: none;
#               user-select: none; }
#
# .header__navbar--navigation[_ngcontent-sc1]   nav[_ngcontent-sc1] {
#     float: right; }
#
# .header__navbar--navigation[_ngcontent-sc1]   a[_ngcontent-sc1], .header__navbar--navigation[_ngcontent-sc1]   div[_ngcontent-sc1] {
#     float: left; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button[_ngcontent-sc1] {
#     display: none;
#     letter-spacing: 0;
#     font-size: 0.875rem;
#     text-transform: capitalize;
#     height: 2.25rem;
#     font-weight: 400;
#     margin-left: 2.5rem;
#     line-height: 1.9375rem; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button[_ngcontent-sc1]:first-child {
#       margin-left: 0; }
#
# @media screen and (min-width: 62rem) {
#       .header__navbar--navigation[_ngcontent-sc1]   .button[_ngcontent-sc1] {
#         display: block; } }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--navigation[_ngcontent-sc1] {
#       padding: 0;
#       color: #525c65; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--navigation[_ngcontent-sc1]:hover {
#         color: #474f57; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--primary[_ngcontent-sc1], .header__navbar--navigation[_ngcontent-sc1]   .button--turquoise[_ngcontent-sc1] {
#       width: 7.75rem;
#       box-shadow: 8px 10px 20px 0px rgba(46, 61, 73, 0.15);
#       background-color: #02b3e4; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--primary[_ngcontent-sc1]:hover, .header__navbar--navigation[_ngcontent-sc1]   .button--turquoise[_ngcontent-sc1]:hover {
#         box-shadow: 2px 4px 8px 0px rgba(46, 61, 73, 0.2);
#         background-color: #02b7e9; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--turquoise[_ngcontent-sc1] {
#       background-color: #02ccba; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--turquoise[_ngcontent-sc1]:hover {
#         background-color: #02d1bf; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--guest[_ngcontent-sc1], .header__navbar--navigation[_ngcontent-sc1]   .button--student[_ngcontent-sc1] {
#       display: none; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .divider[_ngcontent-sc1] {
#     cursor: default; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .divider[_ngcontent-sc1]::before {
#       content: '';
#       border-left: 1px solid rgba(82, 92, 101, 0.4);
#       width: 0px;
#       height: 12px; }
#
# .header__sidenav[_ngcontent-sc1] {
#     background-color: #2e3d49; }
#
# .header__sidenav--logo[_ngcontent-sc1] {
#       height: 4.5rem;
#       display: block;
#       background-color: #1C262F; }
#
# .header__sidenav--logo[_ngcontent-sc1]::after {
#         clear: both;
#         content: "";
#         display: table; }
#
# .header__sidenav--logo[_ngcontent-sc1]   .logo-link[_ngcontent-sc1] {
#         display: block;
#         width: 100%;
#         height: 100%; }
#
# .header__sidenav--logo[_ngcontent-sc1]   .logo-link[_ngcontent-sc1]   .logo-wordmark[_ngcontent-sc1] {
#           position: relative;
#           top: 50%;
#           -webkit-transform: translateY(-50%);
#           transform: translateY(-50%);
#           padding-left: 1.5em;
#           width: 11.25rem;
#           height: 1.875rem; }
#
# .header__sidenav--logo[_ngcontent-sc1]   .logo-link[_ngcontent-sc1]   #wordmark[_ngcontent-sc1] {
#           fill: #fff; }
#
# .header__sidenav--navigation[_ngcontent-sc1] {
#       display: block; }
#
# .header__sidenav--navigation[_ngcontent-sc1]::after {
#         clear: both;
#         content: "";
#         display: table; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   li[_ngcontent-sc1] {
#         height: 4.5rem; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   a[_ngcontent-sc1] {
#         padding-top: 1.5rem;
#         padding-bottom: 1.5rem;
#         color: #fff;
#         display: block;
#         padding-left: 1.5em; }
#
# @media screen and (min-width: 48rem) {
#           .header__sidenav--navigation[_ngcontent-sc1]   a[_ngcontent-sc1] {
#             padding-top: 1.5rem;
#             padding-bottom: 1.5rem; } }
#
# .header__sidenav--navigation[_ngcontent-sc1]   a[_ngcontent-sc1]:hover {
#           color: #cccccc; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   .guest[_ngcontent-sc1], .header__sidenav--navigation[_ngcontent-sc1]   .student[_ngcontent-sc1] {
#         display: none; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   .guest[_ngcontent-sc1]   a[_ngcontent-sc1], .header__sidenav--navigation[_ngcontent-sc1]   .student[_ngcontent-sc1]   a[_ngcontent-sc1] {
#           color: #02b3e4; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   .guest[_ngcontent-sc1]   a[_ngcontent-sc1]:hover, .header__sidenav--navigation[_ngcontent-sc1]   .student[_ngcontent-sc1]   a[_ngcontent-sc1]:hover {
#             color: #01647f; }
#
# [_nghost-sc1] {
#   background: #2e3d49;
#   position: fixed;
#   top: 0;
#   left: 0;
#   height: 100vh;
#   display: block;
#   overflow-y: auto;
#   z-index: -1000;
#   width: 16.25rem;
#   -webkit-overflow-scrolling: touch;
#   display: block; }
#
# @media screen and (min-width: 62rem) {
#     [_nghost-sc1] {
#       display: none; } }
#
# [_nghost-sc1]   .logo-link[_ngcontent-sc1] {
#     height: 4.5rem;
#     display: block;
#     background-color: #1C262F; }
#
# [_nghost-sc1]   .logo-link[_ngcontent-sc1]::after {
#       clear: both;
#       content: "";
#       display: table; }
#
# [_nghost-sc1]   .logo-link[_ngcontent-sc1]   .logo-wordmark[_ngcontent-sc1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       padding-left: 1.5em;
#       width: 11.25rem;
#       height: 1.875rem; }
#
# [_nghost-sc1]   .logo-link[_ngcontent-sc1]   #wordmark[_ngcontent-sc1] {
#       fill: #fff; }
#
# [_nghost-sc1]   ul[_ngcontent-sc1] {
#     list-style: none;
#     padding: 0; }
#
# .mobile-nav__active[_nghost-sc1] {
#     visibility: visible;
#     opacity: 1; }
#
# .mobile-nav__inactive[_nghost-sc1] {
#     visibility: hidden;
#     transition: visibility 0.3s; }
#
# .page-lg[_nghost-sc1], .page-lg   [_nghost-sc1] {
#   display: none; }</style><style ng-transition="iridium-in">html[_ngcontent-sc2] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc2], *[_ngcontent-sc2]::after, *[_ngcontent-sc2]::before {
#   box-sizing: inherit; }
#
#
#
# html.wf-loading[_ngcontent-sc2]   .tk-font[_ngcontent-sc2] {
#   visibility: hidden; }
#
# html.wf-active[_ngcontent-sc2]   .tk-font[_ngcontent-sc2] {
#   visibility: initial; }
#
#
#
# .tk-font-balboa[_ngcontent-sc2] {
#   font-family: balboa, 'Open Sans', sans-serif; }
#
# .tk-font-balboa-condensed[_ngcontent-sc2] {
#   font-family: balboa-extra-condensed, 'Open Sans', sans-serif; }
#
# [_nghost-sc2] {
#   position: absolute;
#   width: 100%;
#   top: 0;
#   left: 0;
#   min-height: 100vh;
#   z-index: 0;
#   transition: -webkit-transform 0.3s ease;
#   transition: transform 0.3s ease;
#   transition: transform 0.3s ease, -webkit-transform 0.3s ease;
#   background: #fff; }
#
# .menu--open[_nghost-sc2]:not(.nav-experiment), .menu--open:not(.nav-experiment)   [_nghost-sc2] {
#   -webkit-transform: translateX(16.25rem);
#           transform: translateX(16.25rem); }
#
# .menu--open[_nghost-sc2], .menu--open   [_nghost-sc2] {
#   height: 100vh;
#   overflow: hidden; }
#
# @media screen and (min-width: 62rem) {
#     .menu--open[_nghost-sc2], .menu--open   [_nghost-sc2] {
#       overflow: auto;
#       -webkit-transform: none;
#               transform: none;
#       height: auto; } }
#
# .sticky[_nghost-sc2]:not(.no-sticky-header), .sticky:not(.no-sticky-header)   [_nghost-sc2] {
#   padding-top: 4.5rem; }
#
# @media screen and (min-width: 48rem) {
#     .sticky[_nghost-sc2]:not(.no-sticky-header), .sticky:not(.no-sticky-header)   [_nghost-sc2] {
#       padding-top: 6rem; } }
#
# .page-cn.page-school-of-data-science[_nghost-sc2], .page-cn.page-school-of-data-science   [_nghost-sc2] {
#   padding-top: 0; }</style><style ng-transition="iridium-in">html[_ngcontent-sc3] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc3], *[_ngcontent-sc3]::after, *[_ngcontent-sc3]::before {
#   box-sizing: inherit; }
#
#
#
# html.wf-loading[_ngcontent-sc3]   .tk-font[_ngcontent-sc3] {
#   visibility: hidden; }
#
# html.wf-active[_ngcontent-sc3]   .tk-font[_ngcontent-sc3] {
#   visibility: initial; }
#
#
#
# .tk-font-balboa[_ngcontent-sc3] {
#   font-family: balboa, 'Open Sans', sans-serif; }
#
# .tk-font-balboa-condensed[_ngcontent-sc3] {
#   font-family: balboa-extra-condensed, 'Open Sans', sans-serif; }
#
# [_nghost-sc3] {
#   display: block;
#   overflow: hidden; }
#
# .moustache[_ngcontent-sc3] {
#   position: relative;
#   width: 100%;
#   background: #fff;
#   padding: 0.75rem 1.75rem 0.75rem 1.5rem;
#   color: #fff;
#   z-index: 8999; }
#
# .moustache[_ngcontent-sc3]   .paragraph[_ngcontent-sc3] {
#     margin: 0 auto;
#     max-width: 73.75rem; }
#
# .moustache[_ngcontent-sc3]   p[_ngcontent-sc3]   a[_ngcontent-sc3] {
#     border-bottom: none; }
#
# .moustache[_ngcontent-sc3]   p[_ngcontent-sc3]   a.moustache__link--button[_ngcontent-sc3] {
#       border-bottom: 1px solid;
#       margin: 0 0.8rem; }
#
# .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache[_ngcontent-sc3]   a[_ngcontent-sc3] {
#     color: #02b3e4;
#     display: inline-block;
#     margin: 0; }
#
# .moustache[_ngcontent-sc3]   .close-btn[_ngcontent-sc3] {
#     position: absolute;
#     top: 0;
#     right: 1rem;
#     bottom: 0;
#     display: flex;
#     background-color: transparent;
#     border: none;
#     outline: none;
#     opacity: 0.75;
#     margin: auto 0;
#     padding: 0;
#     color: #fff;
#     transition: opacity 0.3s ease; }
#
# .moustache[_ngcontent-sc3]   .close-btn[_ngcontent-sc3]   svg[_ngcontent-sc3] {
#       height: 0.8rem;
#       width: auto; }
#
# .moustache[_ngcontent-sc3]   .close-btn[_ngcontent-sc3]:hover {
#       opacity: 1; }
#
# .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#     fill: #02b3e4; }
#
# .moustache.white[_ngcontent-sc3] {
#     background: #fff; }
#
# .moustache.white[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.white[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #02b3e4;
#       font-size: 1rem; }
#
# .moustache.white[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #02b3e4; }
#
# .moustache.blue[_ngcontent-sc3] {
#     background: #02b3e4; }
#
# .moustache.blue[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.blue[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #fff;
#       font-size: 1rem; }
#
# .moustache.blue[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #fff; }
#
# .moustache.blue-turquoise[_ngcontent-sc3] {
#     background: linear-gradient(to right, #02b3e4, #02ccba); }
#
# .moustache.blue-turquoise[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.blue-turquoise[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #fff;
#       font-size: 1rem; }
#
# .moustache.blue-turquoise[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #fff; }
#
# .moustache.purple-turquoise[_ngcontent-sc3] {
#     background: linear-gradient(to right, #a951ed, #02ccba); }
#
# .moustache.purple-turquoise[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.purple-turquoise[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #fff;
#       font-size: 1rem; }
#
# .moustache.purple-turquoise[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #fff; }
#
# .moustache.magenta-yellow[_ngcontent-sc3] {
#     background: linear-gradient(to right, #ff5483, #ffae0c); }
#
# .moustache.magenta-yellow[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.magenta-yellow[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #fff;
#       font-size: 1rem; }
#
# .moustache.magenta-yellow[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #fff; }
#
# .moustache.yellow-purple[_ngcontent-sc3] {
#     background: linear-gradient(to right, #ffae0c, #a951ed); }
#
# .moustache.yellow-purple[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.yellow-purple[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #fff;
#       font-size: 1rem; }
#
# .moustache.yellow-purple[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #fff; }
#
# .moustache.yellow-on-black[_ngcontent-sc3] {
#     background: #000; }
#
# .moustache.yellow-on-black[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.yellow-on-black[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #ffae0c;
#       font-size: 1rem; }
#
# .moustache.yellow-on-black[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #ffae0c; }
#
# .moustache.black-on-yellow[_ngcontent-sc3] {
#     background: #ecc81a; }
#
# .moustache.black-on-yellow[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.black-on-yellow[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #000;
#       font-size: 1rem; }
#
# .moustache.black-on-yellow[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #000; }
#
# .page-in.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-corporate[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-corporate   [_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-campaign[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-campaign   [_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-google-india-scholarships[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-google-india-scholarships   [_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-ucollege[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-ucollege   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   display: none; }
#
# .page-cn[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-cn   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   background: #02b3e4; }
#
# .page-cn[_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn   [_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn[_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3], .page-cn   [_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3] {
#     color: #fff;
#     font-size: 1rem; }
#
# .page-cn[_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3], .page-cn   [_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#     fill: #fff; }
#
# .page-cn.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-cn.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   background: #fff; }
#
# .page-cn.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3], .page-cn.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3] {
#     color: #02b3e4;
#     font-size: 1rem; }
#
# .page-cn.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3], .page-cn.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#     fill: #02b3e4; }
#
# .page-cn.page-homepage.sticky.isFixed[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-cn.page-homepage.sticky.isFixed   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   background: #02b3e4; }
#
# .page-cn.page-homepage.sticky.isFixed[_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn.page-homepage.sticky.isFixed   [_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn.page-homepage.sticky.isFixed[_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3], .page-cn.page-homepage.sticky.isFixed   [_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3] {
#     color: #fff;
#     font-size: 1rem; }
#
# .page-cn.page-homepage.sticky.isFixed[_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3], .page-cn.page-homepage.sticky.isFixed   [_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#     fill: #fff; }
#
# .sticky.isFixed[_nghost-sc3]   .moustache[_ngcontent-sc3], .sticky.isFixed   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   position: fixed;
#   z-index: 8001;
#   top: 0; }
#
# .page-cn.page-20181111[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-cn.page-20181111   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   display: none; }</style><style ng-transition="iridium-in">html[_ngcontent-sc4] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc4], *[_ngcontent-sc4]::after, *[_ngcontent-sc4]::before {
#   box-sizing: inherit; }
#
#
#
# html.wf-loading[_ngcontent-sc4]   .tk-font[_ngcontent-sc4] {
#   visibility: hidden; }
#
# html.wf-active[_ngcontent-sc4]   .tk-font[_ngcontent-sc4] {
#   visibility: initial; }
#
#
#
# .tk-font-balboa[_ngcontent-sc4] {
#   font-family: balboa, 'Open Sans', sans-serif; }
#
# .tk-font-balboa-condensed[_ngcontent-sc4] {
#   font-family: balboa-extra-condensed, 'Open Sans', sans-serif; }
#
# .geo-redirect-modal[_ngcontent-sc4] {
#   padding: 3.5em 2.5em 4em;
#   text-align: center; }
#
# .geo-redirect-modal[_ngcontent-sc4]   .geo-redirect-flag[_ngcontent-sc4] {
#     vertical-align: sub; }
#
# .geo-redirect-modal[_ngcontent-sc4]   .geo-redirect-cta[_ngcontent-sc4] {
#     vertical-align: baseline; }
#
# .geo-redirect-modal[_ngcontent-sc4]   .button[_ngcontent-sc4] {
#     margin: auto; }
#
# .geo-redirect-modal[_ngcontent-sc4]   label[_ngcontent-sc4] {
#     clear: left;
#     display: block;
#     position: relative;
#     padding-left: 2.833333333em;
#     margin: 0 auto 2.5em;
#     font-size: 0.875em;
#     color: #dbe2e8;
#     font-weight: 400;
#     text-align: left;
#     width: 60%; }
#
# .geo-redirect-modal[_ngcontent-sc4]   label[_ngcontent-sc4]::before {
#       content: '';
#       position: absolute;
#       top: 0;
#       left: 0;
#       width: 1.666666667em;
#       height: 1.666666667em;
#       border: 1px solid #dbe2e8; }
#
# .geo-redirect-modal[_ngcontent-sc4]   label[_ngcontent-sc4]::after {
#       content: '';
#       position: absolute;
#       top: 0;
#       left: 0;
#       width: 1.666666667em;
#       height: 1.666666667em;
#       background-image: url("/assets/iridium/images/svgs/check_blue.svg");
#       background-repeat: no-repeat;
#       background-position: center;
#       background-size: 0%;
#       transition: opacity 0.3s ease, background-size 0.3s ease; }
#
# .geo-redirect-modal[_ngcontent-sc4]   input[type=checkbox][_ngcontent-sc4] {
#     visibility: hidden;
#     width: 0; }</style><style ng-transition="iridium-in">@charset "UTF-8";
# html[_ngcontent-sc5] {
#   box-sizing: border-box; }
# *[_ngcontent-sc5], *[_ngcontent-sc5]::after, *[_ngcontent-sc5]::before {
#   box-sizing: inherit; }
#
# html.wf-loading[_ngcontent-sc5]   .tk-font[_ngcontent-sc5] {
#   visibility: hidden; }
# html.wf-active[_ngcontent-sc5]   .tk-font[_ngcontent-sc5] {
#   visibility: initial; }
#
# .tk-font-balboa[_ngcontent-sc5] {
#   font-family: balboa, 'Open Sans', sans-serif; }
# .tk-font-balboa-condensed[_ngcontent-sc5] {
#   font-family: balboa-extra-condensed, 'Open Sans', sans-serif; }
# .invisible[_ngcontent-sc5] {
#   visibility: hidden !important; }
# .hide[_ngcontent-sc5] {
#   display: none !important; }
# .show[_ngcontent-sc5] {
#   display: block !important; }
# .sr-only[_ngcontent-sc5] {
#   height: 1px;
#   width: 1px;
#   overflow: hidden;
#   position: absolute !important;
#   clip: rect(1px, 1px, 1px, 1px); }
# .hidden-xs-up[_ngcontent-sc5] {
#   display: none !important; }
# @media (max-width: 479px) {
#   .hidden-xs-down[_ngcontent-sc5] {
#     display: none !important; } }
# @media (min-width: 480px) {
#   .hidden-sm-up[_ngcontent-sc5] {
#     display: none !important; } }
# @media (max-width: 767px) {
#   .hidden-sm-down[_ngcontent-sc5] {
#     display: none !important; } }
# @media (min-width: 768px) {
#   .hidden-md-up[_ngcontent-sc5] {
#     display: none !important; } }
# @media (max-width: 991px) {
#   .hidden-md-down[_ngcontent-sc5] {
#     display: none !important; } }
# @media (min-width: 992px) {
#   .hidden-lg-up[_ngcontent-sc5] {
#     display: none !important; } }
# @media (max-width: 1179px) {
#   .hidden-lg-down[_ngcontent-sc5] {
#     display: none !important; } }
# @media (min-width: 1180px) {
#   .hidden-xl-up[_ngcontent-sc5] {
#     display: none !important; } }
# .hidden-xl-down[_ngcontent-sc5] {
#   display: none !important; }
# .visible-print-block[_ngcontent-sc5] {
#   display: none !important; }
# @media print {
#     .visible-print-block[_ngcontent-sc5] {
#       display: block !important; } }
# .visible-print-inline[_ngcontent-sc5] {
#   display: none !important; }
# @media print {
#     .visible-print-inline[_ngcontent-sc5] {
#       display: inline !important; } }
# .visible-print-inline-block[_ngcontent-sc5] {
#   display: none !important; }
# @media print {
#     .visible-print-inline-block[_ngcontent-sc5] {
#       display: inline-block !important; } }
# @media print {
#   .hidden-print[_ngcontent-sc5] {
#     display: none !important; } }
# #contain-all[_ngcontent-sc5] {
#   width: 100%;
#   overflow: hidden;
#   background: #fff;
#   -webkit-backface-visibility: hidden;
#           backface-visibility: hidden;
#   -webkit-transform-style: preserve-3d; }
# .outer_contain[_ngcontent-sc5] {
#   margin: 0 auto;
#   max-width: 90rem; }
# .contain[_ngcontent-sc5] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto;
#   padding-top: 3rem;
#   padding-bottom: 3rem;
#   padding-left: 0.75rem;
#   padding-right: 0.75rem; }
# .contain[_ngcontent-sc5]::after {
#     clear: both;
#     content: "";
#     display: table; }
# @media screen and (min-width: 48rem) {
#
#     .contain[_ngcontent-sc5] {
#       padding-top: 6rem;
#       padding-bottom: 6rem; } }
# @media screen and (min-width: 30rem) {
#
#     .contain[_ngcontent-sc5] {
#       padding-left: 0.99rem;
#       padding-right: 0.99rem; } }
# @media screen and (min-width: 48rem) {
#
#     .contain[_ngcontent-sc5] {
#       padding-left: 1.5rem;
#       padding-right: 1.5rem; } }
# @media screen and (min-width: 73.75rem) {
#
#     .contain[_ngcontent-sc5] {
#       padding-left: 0;
#       padding-right: 0; } }
# .contain.no-padding[_ngcontent-sc5] {
#     padding: 0; }
# .contain.no-padding-top[_ngcontent-sc5] {
#     padding-top: 0; }
# .contain.no-padding-bottom[_ngcontent-sc5] {
#     padding-bottom: 0; }
# .contain--none[_ngcontent-sc5] {
#     padding-top: 0rem;
#     padding-bottom: 0rem;
#     margin: 0 auto; }
# @media screen and (min-width: 48rem) {
#
#       .contain--none[_ngcontent-sc5] {
#         padding-top: 0rem;
#         padding-bottom: 0rem; } }
# .contain--small[_ngcontent-sc5] {
#     padding-top: 3rem;
#     padding-bottom: 3rem;
#     margin: 0 auto; }
# @media screen and (min-width: 48rem) {
#
#       .contain--small[_ngcontent-sc5] {
#         padding-top: 4.5rem;
#         padding-bottom: 4.5rem; } }
# .cards_contain[_ngcontent-sc5] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto; }
# .cards_contain[_ngcontent-sc5]::after {
#     clear: both;
#     content: "";
#     display: table; }
# [_ngcontent-sc5]:-webkit-full-screen-ancestor {
#   -webkit-animation: none !important;
#           animation: none !important;
#   -webkit-animation-fill-mode: none !important;
#   animation-fill-mode: none !important; }
# [_ngcontent-sc5]:target:before {
#   content: '';
#   display: inline-block;
#   height: 130px;
#   margin: -130px 0 0; }
# .header[_ngcontent-sc5], [_nghost-sc5] {
#   max-width: 100%;
#   margin-left: auto;
#   margin-right: auto; }
# .header[_ngcontent-sc5]::after, [_nghost-sc5]::after {
#     clear: both;
#     content: "";
#     display: table; }
# .header.header--clone[_ngcontent-sc5], .header--clone[_nghost-sc5] {
#     width: 100%;
#     top: -1000px; }
# .header.header--clone[_ngcontent-sc5]   .header__navbar[_ngcontent-sc5], .header--clone[_nghost-sc5]   .header__navbar[_ngcontent-sc5], .header.header--clone[_ngcontent-sc5]   header[_ngcontent-sc5], .header--clone[_nghost-sc5]   header[_ngcontent-sc5] {
#       height: 4.5rem; }
# .header.header--stick[_ngcontent-sc5], .header--stick[_nghost-sc5] {
#     top: 0;
#     background-color: #fff;
#     z-index: 8000;
#     box-shadow: 0px 1px 2px rgba(0, 0, 0, 0.1); }
# .header__navbar[_ngcontent-sc5], header[_ngcontent-sc5] {
#     max-width: 73.75rem;
#     margin-left: auto;
#     margin-right: auto;
#     height: 4.5rem;
#     padding: 0 1.5em; }
# .header__navbar[_ngcontent-sc5]::after, header[_ngcontent-sc5]::after {
#       clear: both;
#       content: "";
#       display: table; }
# @media screen and (min-width: 48rem) {
#       .header__navbar[_ngcontent-sc5], header[_ngcontent-sc5] {
#         height: 6rem; } }
# @media screen and (min-width: 73.75rem) {
#       .header__navbar[_ngcontent-sc5], header[_ngcontent-sc5] {
#         padding: 0; } }
# .header__navbar--toggle[_ngcontent-sc5] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69491525%;
#       width: 15.25423729%; }
# .header__navbar--toggle[_ngcontent-sc5]:last-child {
#         margin-right: 0; }
# @media screen and (min-width: 62rem) {
#         .header__navbar--toggle[_ngcontent-sc5] {
#           display: none; } }
# .header__navbar--logo[_ngcontent-sc5] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69491525%;
#       width: 66.10169492%; }
# .header__navbar--logo[_ngcontent-sc5]:last-child {
#         margin-right: 0; }
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc5] {
#           float: left;
#           display: block;
#           margin-right: 0.84033613%;
#           width: 20.16806723%; }
#           .header__navbar--logo[_ngcontent-sc5]:last-child {
#             margin-right: 0; } }
# .header__navbar--catalog[_ngcontent-sc5] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       display: none; }
# @media screen and (min-width: 62rem) {
#         .header__navbar--catalog[_ngcontent-sc5] {
#           float: left;
#           display: block;
#           margin-right: 0.84033613%;
#           width: 7.56302521%; }
#           .header__navbar--catalog[_ngcontent-sc5]:last-child {
#             margin-right: 0; } }
# .header__navbar--navigation[_ngcontent-sc5] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       display: none; }
# @media screen and (min-width: 62rem) {
#         .header__navbar--navigation[_ngcontent-sc5] {
#           float: left;
#           display: block;
#           margin-right: 1.69491525%;
#           width: 74.57627119%; }
#           .header__navbar--navigation[_ngcontent-sc5]:last-child {
#             margin-right: 0; } }
# .header__navbar--logo[_ngcontent-sc5] {
#     text-align: center; }
# @media screen and (min-width: 62rem) {
#       .header__navbar--logo[_ngcontent-sc5] {
#         text-align: left; } }
# .header__navbar--logo[_ngcontent-sc5]   .logo-wordmark[_ngcontent-sc5], .header__navbar--logo[_ngcontent-sc5]   .logo-wordmark--cn[_ngcontent-sc5] {
#       width: 11.25rem;
#       height: 1.875rem;
#       display: none; }
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc5]   .logo-wordmark[_ngcontent-sc5], .header__navbar--logo[_ngcontent-sc5]   .logo-wordmark--cn[_ngcontent-sc5] {
#           display: block; } }
# .header__navbar--logo[_ngcontent-sc5]   .logo-mark[_ngcontent-sc5] {
#       display: block;
#       margin: 0 auto;
#       width: 1.875rem;
#       height: 1.875rem; }
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc5]   .logo-mark[_ngcontent-sc5] {
#           display: none; } }
# .header__navbar--toggle[_ngcontent-sc5]   .nav-toggle[_ngcontent-sc5] {
#     display: block;
#     width: 1.25rem;
#     height: 1.25rem;
#     cursor: pointer;
#     transition: -webkit-transform .25s ease;
#     transition: transform .25s ease;
#     transition: transform .25s ease, -webkit-transform .25s ease; }
# .header__navbar--toggle[_ngcontent-sc5]   .nav-toggle[_ngcontent-sc5]   .bar[_ngcontent-sc5] {
#       display: block;
#       width: 100%;
#       height: 0.1875rem;
#       margin-left: -0.5rem;
#       margin-top: 0.1875rem;
#       background: #02b3e4;
#       transition: opacity .25s ease, -webkit-transform .25s ease;
#       transition: opacity .25s ease, transform .25s ease;
#       transition: opacity .25s ease, transform .25s ease, -webkit-transform .25s ease;
#       -webkit-user-select: none;
#          -moz-user-select: none;
#           -ms-user-select: none;
#               user-select: none; }
# .header__navbar--navigation[_ngcontent-sc5]   nav[_ngcontent-sc5] {
#     float: right; }
# .header__navbar--navigation[_ngcontent-sc5]   a[_ngcontent-sc5], .header__navbar--navigation[_ngcontent-sc5]   div[_ngcontent-sc5] {
#     float: left; }
# .header__navbar--navigation[_ngcontent-sc5]   .button[_ngcontent-sc5] {
#     display: none;
#     letter-spacing: 0;
#     font-size: 0.875rem;
#     text-transform: capitalize;
#     height: 2.25rem;
#     font-weight: 400;
#     margin-left: 2.5rem;
#     line-height: 1.9375rem; }
# .header__navbar--navigation[_ngcontent-sc5]   .button[_ngcontent-sc5]:first-child {
#       margin-left: 0; }
# @media screen and (min-width: 62rem) {
#       .header__navbar--navigation[_ngcontent-sc5]   .button[_ngcontent-sc5] {
#         display: block; } }
# .header__navbar--navigation[_ngcontent-sc5]   .button--navigation[_ngcontent-sc5] {
#       padding: 0;
#       color: #525c65; }
# .header__navbar--navigation[_ngcontent-sc5]   .button--navigation[_ngcontent-sc5]:hover {
#         color: #474f57; }
# .header__navbar--navigation[_ngcontent-sc5]   .button--primary[_ngcontent-sc5], .header__navbar--navigation[_ngcontent-sc5]   .button--turquoise[_ngcontent-sc5] {
#       width: 7.75rem;
#       box-shadow: 8px 10px 20px 0px rgba(46, 61, 73, 0.15);
#       background-color: #02b3e4; }
# .header__navbar--navigation[_ngcontent-sc5]   .button--primary[_ngcontent-sc5]:hover, .header__navbar--navigation[_ngcontent-sc5]   .button--turquoise[_ngcontent-sc5]:hover {
#         box-shadow: 2px 4px 8px 0px rgba(46, 61, 73, 0.2);
#         background-color: #02b7e9; }
# .header__navbar--navigation[_ngcontent-sc5]   .button--turquoise[_ngcontent-sc5] {
#       background-color: #02ccba; }
# .header__navbar--navigation[_ngcontent-sc5]   .button--turquoise[_ngcontent-sc5]:hover {
#         background-color: #02d1bf; }
# .header__navbar--navigation[_ngcontent-sc5]   .button--guest[_ngcontent-sc5], .header__navbar--navigation[_ngcontent-sc5]   .button--student[_ngcontent-sc5] {
#       display: none; }
# .header__navbar--navigation[_ngcontent-sc5]   .divider[_ngcontent-sc5] {
#     cursor: default; }
# .header__navbar--navigation[_ngcontent-sc5]   .divider[_ngcontent-sc5]::before {
#       content: '';
#       border-left: 1px solid rgba(82, 92, 101, 0.4);
#       width: 0px;
#       height: 12px; }
# .header__sidenav[_ngcontent-sc5] {
#     background-color: #2e3d49; }
# .header__sidenav--logo[_ngcontent-sc5] {
#       height: 4.5rem;
#       display: block;
#       background-color: #1C262F; }
# .header__sidenav--logo[_ngcontent-sc5]::after {
#         clear: both;
#         content: "";
#         display: table; }
# .header__sidenav--logo[_ngcontent-sc5]   .logo-link[_ngcontent-sc5] {
#         display: block;
#         width: 100%;
#         height: 100%; }
# .header__sidenav--logo[_ngcontent-sc5]   .logo-link[_ngcontent-sc5]   .logo-wordmark[_ngcontent-sc5], .header__sidenav--logo[_ngcontent-sc5]   .logo-link[_ngcontent-sc5]   .logo-wordmark--cn[_ngcontent-sc5] {
#           position: relative;
#           top: 50%;
#           -webkit-transform: translateY(-50%);
#           transform: translateY(-50%);
#           padding-left: 1.5em;
#           width: 11.25rem;
#           height: 1.875rem; }
# .header__sidenav--logo[_ngcontent-sc5]   .logo-link[_ngcontent-sc5]   #wordmark[_ngcontent-sc5] {
#           fill: #fff; }
# .header__sidenav--navigation[_ngcontent-sc5] {
#       display: block; }
# .header__sidenav--navigation[_ngcontent-sc5]::after {
#         clear: both;
#         content: "";
#         display: table; }
# .header__sidenav--navigation[_ngcontent-sc5]   li[_ngcontent-sc5] {
#         height: 4.5rem; }
# .header__sidenav--navigation[_ngcontent-sc5]   a[_ngcontent-sc5] {
#         padding-top: 1.5rem;
#         padding-bottom: 1.5rem;
#         color: #fff;
#         display: block;
#         padding-left: 1.5em; }
# @media screen and (min-width: 48rem) {
#           .header__sidenav--navigation[_ngcontent-sc5]   a[_ngcontent-sc5] {
#             padding-top: 1.5rem;
#             padding-bottom: 1.5rem; } }
# .header__sidenav--navigation[_ngcontent-sc5]   a[_ngcontent-sc5]:hover {
#           color: #cccccc; }
# .header__sidenav--navigation[_ngcontent-sc5]   .guest[_ngcontent-sc5], .header__sidenav--navigation[_ngcontent-sc5]   .student[_ngcontent-sc5] {
#         display: none; }
# .header__sidenav--navigation[_ngcontent-sc5]   .guest[_ngcontent-sc5]   a[_ngcontent-sc5], .header__sidenav--navigation[_ngcontent-sc5]   .student[_ngcontent-sc5]   a[_ngcontent-sc5] {
#           color: #02b3e4; }
# ...
#                 &quot;cta_type&quot;: &quot;link&quot;,
#                 &quot;cta_location&quot;: &quot;HomePage&quot;
#               }" href="https://auth.udacity.com/sign-in?next=https://classroom.udacity.com/authenticated"> Log In </a><!----></li><!----><li _ngcontent-sc1="" class="ng-star-inserted"><!----><a _ngcontent-sc1="" data-analytics-event="Navbar Link Clicked" class="turquoise ng-star-inserted" title="Career Paths" data-analytics-attrs="{
#                 &quot;category&quot;: &quot;Navbar Link&quot;,
#                 &quot;label&quot;: &quot;Navbar Link - Mobile Header Link Clicked - Career Paths&quot;,
#                 &quot;cta_message&quot;: &quot;Career Paths&quot;,
#                 &quot;cta_type&quot;: &quot;link&quot;,
#                 &quot;cta_location&quot;: &quot;HomePage&quot;
#               }" href="/career-path/all"> Career Paths </a><!----></li><!----><!----></ul></nav></ir-nav-mobile><ir-content _ngcontent-sc0="" _nghost-sc2=""><ir-moustache _ngcontent-sc0="" _nghost-sc3="" class="ng-tns-c3-0 ng-trigger ng-trigger-shrinkUpAnimation ng-star-inserted" style=""><!----></ir-moustache><ir-geo-redirect-modal _ngcontent-sc0="" _nghost-sc4=""><ir-modal _ngcontent-sc4="" _nghost-sc10="" class="ng-tns-c10-1"><div _ngcontent-sc10="" class="wrapper"><!----><!----><!----><!----><!----><!----></div><!----></ir-modal></ir-geo-redirect-modal><ir-header _ngcontent-sc0="" _nghost-sc5=""><div _ngcontent-sc5="" class="wrapper"><header _ngcontent-sc5=""><div _ngcontent-sc5="" class="header__navbar--toggle"><a _ngcontent-sc5="" class="nav-toggle" href="#"><span _ngcontent-sc5="" class="bar bar_top"></span><span _ngcontent-sc5="" class="bar bar_mid"></span><span _ngcontent-sc5="" class="bar bar_bottom"></span></a></div><div _ngcontent-sc5="" class="header__navbar--logo"><a _ngcontent-sc5="" class="logo-link" title="Udacity" href="/"><!----><div _ngcontent-sc5="" class="logo-wordmark ng-star-inserted"><!----><!----><!----><svg _ngcontent-sc5="" alt="Udacity" height="30" viewBox="0 0 180 30" width="180" class="ng-star-inserted"><g _ngcontent-sc5="" fill="none" fill-rule="evenodd"><path _ngcontent-sc5="" d="M57.6 17.239187c0 2.546698-2.085517 4.407747-4.965517 4.407747-2.88 0-4.965517-1.86105-4.965517-4.407747V7.835994H45.68276v9.501143c0 3.330298 2.88 6.170846 6.951723 6.170846 4.071724 0 6.951724-2.938498 6.951724-6.170846V7.835994H57.6v9.403193zm16.286897-9.403193h-5.36276v15.67199h5.36276c4.468965 0 7.547586-3.03645 7.547586-7.835996 0-4.701596-3.07862-7.835994-7.547586-7.835994zm-.19862 13.71299h-3.177932V9.794994h3.17793c3.376553 0 5.76 2.252847 5.76 5.876994 0 3.917998-2.482757 5.779046-5.76 5.876996zm43.49793.29385c-3.575172 0-5.95862-2.644648-5.95862-6.170846 0-3.526197 2.482758-6.072895 5.95862-6.072895 2.78069 0 4.468966 1.5672 4.468966 1.5672l.794483-1.3713s-1.787587-1.86105-5.46207-1.86105c-4.766896 0-7.746206 3.526198-7.746206 7.738045 0 4.309797 3.07862 7.933945 7.944827 7.933945 3.773793 0 5.66069-2.5467 5.66069-2.5467l-1.092414-1.175398c-.09931-.09795-1.588965 1.959-4.568276 1.959zm14.896553-14.00684h1.986206v15.67199h-1.986207zm10.924137 1.959h4.965517v13.71299h1.986207V9.794994h4.96552v-1.959H143.0069m30.587583 0l-4.766896 7.150344-4.866207-7.150347h-2.085518l5.95862 8.717546v6.954445h1.986208v-6.954444l5.85931-8.71754m-81.434482 0l-6.157242 15.67199h1.986207l1.688276-4.5057 6.45517-1.3713 2.18483 5.876998h1.986203l-6.05793-15.67199h-2.085518zm-1.886897 9.305242l2.97931-7.248294h.099315L97.92 16.063788l-5.56138 1.07745z" fill="#2E3D49" id="wordmark"></path><path _ngcontent-sc5="" d="M29 .5l1 .5v13c0 5.551887-2.8897 8.695692-5.995216 10.099885L24.0094 24.1l-7.620963 4.388562c-.05877.03456-.11776.068527-.176957.101902l-.08642.049764.001806-.00254C14.48289 29.545895 12.684682 30 11 30 6 30 0 26 0 18V6l2 1v11c0 8 6 10 9 10 1.858706 0 4.86901-.76773 6.89043-3.254517C14.181726 23.872636 10 20.678703 10 14V2.2L2 7 0 6l10-6 1 .5 1 .5v13c0 6.939958 4.515283 8.612086 7.017542 8.933368C19.625786 21.62159 20 19.997902 20 18V5l2 1v12c0 1.852645-.321777 3.49077-.878395 4.91438C23.648223 22.549217 28 20.813144 28 14V2.25L22 6l-2-1 8-5 1 .5z" fill="#02B3E4" id="mark"></path></g></svg></div><!----></a><a _ngcontent-sc5="" id="ga-294bb9" irhybridlink="/" title="Udacity" href="/"><div _ngcontent-sc5="" class="logo-mark"><svg _ngcontent-sc5="" alt="Udacity" height="30" viewBox="0 0 30 30" width="30"><path _ngcontent-sc5="" d="M29 .5l1 .5v13c0 5.551887-2.8897 8.695692-5.995216 10.099885L24.0094 24.1l-7.620963 4.388562c-.05877.03456-.11776.068527-.176957.101902l-.08642.049764.001806-.00254C14.48289 29.545895 12.684682 30 11 30 6 30 0 26 0 18V6l2 1v11c0 8 6 10 9 10 1.858706 0 4.86901-.76773 6.89043-3.254517C14.181726 23.872636 10 20.678703 10 14V2.2L2 7 0 6l10-6 1 .5 1 .5v13c0 6.939958 4.515283 8.612086 7.017542 8.933368C19.6 ...
#                     &quot;category&quot;: &quot;Navbar Link&quot;,
#                     &quot;label&quot;: &quot;Navbar Link - Header Link Clicked - Nanodegree&quot;,
#                     &quot;cta_type&quot;: &quot;link&quot;,
#                     &quot;cta_destination&quot;: &quot;self&quot;,
#                     &quot;cta_location&quot;: &quot;Homepage&quot;
#                   }" href="/nanodegree"> Nanodegree </a><!----><!----><!----><a _ngcontent-sc5="" data-analytics-event="Navbar Link Clicked" class="button button--navigation ng-star-inserted" title="For Enterprise" data-analytics-attrs="{
#                     &quot;category&quot;: &quot;Navbar Link&quot;,
#                     &quot;label&quot;: &quot;Navbar Link - Header Link Clicked - For Enterprise&quot;,
#                     &quot;cta_type&quot;: &quot;link&quot;,
#                     &quot;cta_destination&quot;: &quot;self&quot;,
#                     &quot;cta_location&quot;: &quot;Homepage&quot;
#                   }" href="/enterprise"> For Enterprise </a><!----><!----><!----><a _ngcontent-sc5="" data-analytics-event="Navbar Link Clicked" class="button button--navigation ng-star-inserted" title="Hire Talent" data-analytics-attrs="{
#                     &quot;category&quot;: &quot;Navbar Link&quot;,
#                     &quot;label&quot;: &quot;Navbar Link - Header Link Clicked - Hire Talent&quot;,
#                     &quot;cta_type&quot;: &quot;link&quot;,
#                     &quot;cta_destination&quot;: &quot;self&quot;,
#                     &quot;cta_location&quot;: &quot;Homepage&quot;
#                   }" href="/hire-talent"> Hire Talent </a><!----><!----><!----><a _ngcontent-sc5="" data-analytics-event="Navbar Link Clicked" class="button button--navigation ng-star-inserted" title="Career Paths" data-analytics-attrs="{
#                     &quot;category&quot;: &quot;Navbar Link&quot;,
#                     &quot;label&quot;: &quot;Navbar Link - Header Link Clicked - Career Paths&quot;,
#                     &quot;cta_type&quot;: &quot;link&quot;,
#                     &quot;cta_destination&quot;: &quot;self&quot;,
#                     &quot;cta_location&quot;: &quot;Homepage&quot;
#                   }" href="/career-path/all"> Career Paths </a><!----><!----><div _ngcontent-sc5="" class="button button--navigation divider"></div><!----><a _ngcontent-sc5="" data-analytics-event="Navbar Link Clicked" style="display:inline" class="button button--navigation ng-star-inserted" title="Log In" data-analytics-attrs="{
#                 &quot;category&quot;: &quot;Navbar Link&quot;,
#                 &quot;label&quot;: &quot;Navbar Link - Header Link Clicked - Log In&quot;,
#                 &quot;cta_type&quot;: &quot;link&quot;,
#                 &quot;cta_destination&quot;: &quot;self&quot;,
#                 &quot;cta_location&quot;: &quot;Homepage&quot;
#               }" href="https://auth.udacity.com/sign-up?next=https://classroom.udacity.com/authenticated"> Log In </a></div><!----><!----><!----><!----><!----><a _ngcontent-sc5="" class="button button--turquoise ng-star-inserted" title="Your Gift"><span _ngcontent-sc5="" class="icon" inlinesvg="/assets/iridium/images/user-profile/gift-white.svg"><svg height="16" viewBox="0 0 17 16" width="17" xmlns="http://www.w3.org/2000/svg"><g fill="none" fill-rule="evenodd" stroke="#fff" stroke-linecap="round" stroke-linejoin="round"><path d="m.95 4.667h14.666m-12.666-2a1.899 1.899 0 0 1 1.777-2c2.63 0 3.556 4 3.556 4h-3.556a1.897 1.897 0 0 1 -1.778-2z"></path><path d="m11.839 4.667h-3.556s.933-4 3.556-4a1.899 1.899 0 0 1 1.777 2 1.897 1.897 0 0 1 -1.777 2zm2.444 2.666v6.667c0 .736-.597 1.333-1.334 1.333h-9.333a1.333 1.333 0 0 1 -1.333-1.333v-6.667m6 0v8"></path></g></svg></span> Your Gift </a></nav></div></header></div><ir-modal _ngcontent-sc5="" _nghost-sc10="" class="ng-tns-c10-2"><div _ngcontent-sc10="" class="wrapper modal--height-vh"><!----><!----><!----><!----><!----><!----></div><!----></ir-modal><!----><ir-modal _ngcontent-sc5="" class="user-profile-modal ng-tns-c10-3 ng-star-inserted" _nghost-sc10=""><div _ngcontent-sc10="" class="wrapper"><!----><!----><!----><!----><!----><!----></div><!----></ir-modal></ir-header><router-outlet _ngcontent-sc0=""></router-outlet><ir-course-catalog _nghost-sc262="" class="ng-star-inserted"><section _ngcontent-sc262=""><div _ngcontent-sc262="" class="contain intro"><h1 _ngcontent-sc262="">Program Catalog</h1></div></section><section _ngcontent-sc262=""><div _ngcontent-sc262=""><div _ngcontent-sc262="" class="col-sm-12 adjust-search"><input _ngcontent-sc262="" placeholder="Search" type="text" value="" class="ng-untouched ng-pristine ng-valid"></div></div></section><section _ngcontent-sc262=""><div _ngcontent-sc262="" class="contain"><div _ngcontent-sc262="" class="catalog-sort-filters hidden-sm-down"><ir-dropdown-select-input _ngcontent-sc262="" _nghost-sc68=""><!----><div _ngcontent-sc68="" class="dropdown ng-star-inserted"><div _ngcontent-sc68="" class="container"><div _ngcontent-sc68="" class="select"><input _ngcontent-sc68="" class="selected-value" type="hidden" value="#"><button _ngcontent-sc68="" class="selected"><label _ngcontent-sc68="" class="selected-text">Sort by Popular</label></button><span _ngcontent-sc68="" class="pointer pointer-down"></span></div><ul _ngcontent-sc68="" class="options click-off-close"><!----><li _ngcontent-sc68="" class="ng-star-inserted"><button _ngcontent-sc68="" class="option" type="button"><label _ngcontent-sc68="" class="option-text">Sort by Newest</label></button></li></ul></div></div><!----></ir-dropdown-select-input></div><div _ngcontent-sc262="" class="row row-gap-medium"><div _ngcontent-sc262="" class="filter-col"><div _ngcontent-sc262="" class="hidden-md-up"><span _ngcontent-sc262="" class="mobile-filter-cta blue uppercase"><img _ngcontent-sc262="" src="/assets/iridium/images/course-catalog/filter-icon.svg">Filters</span><!----></div><div _ngcontent-sc262="" class="filters-wrapper hidden-sm-down"><div _ngcontent-sc262="" class="hidden-sm-down mb-2"><ir-multi-select-filters _ngcontent-sc262="" _nghost-sc263=""><div _ngcontent-sc263=""><h4 _ngcontent-sc263="">Filter By</h4><ir-catalog-multiselect _ngcontent-sc263="" _nghost-sc266=""><div _ngcontent-sc266="" class="multiselect-dropdown" irclickoutside=""><div _ngcontent-sc266="" class=""><span _ngcontent-sc266="" class="dropdown-btn"><!----><!----><!----><span _ngcontent-sc266="" class="placeholder ng-star-inserted">Select Program Details</span><!----><!----><!----><span _ngcontent-sc266="" class="pointer pointer-down"></span></span></div><div _ngcontent-sc266="" class="dropdown-list" hidden=""><div _ngcontent-sc266="" class="filter-section" style="max-height:197px;"><!----><div _ngcontent-sc266="" class="ng-star-inserted"><div _ngcontent-sc266="" class="uppercase filter-header">Type</div><ul _ngcontent-sc2 ...
# <script type="text/javascript" src="runtime.5a236107fd7b72276ee5.js"></script><script type="text/javascript" src="polyfills.b4dc5834e54404d27544.js"></script><script type="text/javascript" src="scripts.371a0cb6c7cd60c0dc25.js"></script><script type="text/javascript" src="main.98d77d22ab81212b18ae.js"></script>
#
# <script id="iridium-in-state" type="application/json">{&q;/courses/all?udacityAgentHeader=Iridium-Circle-Build-1d9c7@CACHE_LOCALIZED_DATA-catalogFilters&a;locale=en-IN&q;:[{&q;section&q;:&q;Type&q;,&q;values&q;:[{&q;title&q;:&q;Nanodegree&q;,&q;propertyPath&q;:&q;slug&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;--nd&q;}},{&q;title&q;:&q;Free Courses&q;,&q;propertyPath&q;:&q;slug&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;notWithKey&q;:&q;--nd&q;}}]},{&q;section&q;:&q;Skill Level&q;,&q;values&q;:[{&q;title&q;:&q;Beginner&q;,&q;propertyPath&q;:&q;level&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;beginner&q;}},{&q;title&q;:&q;Intermediate&q;,&q;propertyPath&q;:&q;level&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;intermediate&q;}},{&q;title&q;:&q;Advanced&q;,&q;propertyPath&q;:&q;level&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;advanced&q;}}]},{&q;section&q;:&q;Estimated Duration&q;,&q;values&q;:[{&q;title&q;:&q;&l;1 month&q;,&q;propertyPath&q;:&q;metadata.expected_duration_in_months&q;,&q;type&q;:&q;range&q;,&q;matchCriteria&q;:{&q;rangeMin&q;:0,&q;rangeMinInclusive&q;:true,&q;rangeMax&q;:1,&q;rangeMaxInclusive&q;:false}},{&q;title&q;:&q;1 - 3 months&q;,&q;propertyPath&q;:&q;metadata.expected_duration_in_months&q;,&q;type&q;:&q;range&q;,&q;matchCriteria&q;:{&q;rangeMin&q;:1,&q;rangeMinInclusive&q;:true,&q;rangeMax&q;:3,&q;rangeMaxInclusive&q;:true}},{&q;title&q;:&q;3+ months&q;,&q;propertyPath&q;:&q;metadata.expected_duration_in_months&q;,&q;type&q;:&q;range&q;,&q;matchCriteria&q;:{&q;rangeMin&q;:3,&q;rangeMinInclusive&q;:true}}]}],&q;/courses/all?udacityAgentHeader=Iridium-Circle-Build-1d9c7@CACHE_LOCALIZED_DATA-skillFilters&a;locale=en-IN&q;:[{&q;section&q;:&q;Skills&q;,&q;values&q;:[{&q;title&q;:&q;AI Algorithms&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;AI Algorithms&q;}},{&q;title&q;:&q;AR development&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;AR development&q;}},{&q;title&q;:&q;ARKit&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;ARKit&q;}},{&q;title&q;:&q;Alteryx&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Alteryx&q;}},{&q;title&q;:&q;Android Development&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Android Development&q;}},{&q;title&q;:&q;Blueprint programming&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Blueprint programming&q;}},{&q;title&q;:&q;C++&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;C++&q;}},{&q;title&q;:&q;Career Advancement&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Career Advancement&q;}},{&q;title&q;:&q;CSS&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;CSS&q;}},{&q;title&q;:&q;Controls and Estimation&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Controls and Estimation&q;}},{&q;title&q;:&q;Core Data&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Core Data&q;}},{&q;title&q;:&q;Deep Learning&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Deep Learning&q;}},{&q;title&q;:&q;Design Sprint&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Design Sprint&q;}},{&q;title&q;:&q;Digital Marketing&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Digital Marketing& ...

# %% [markdown]
# ### Step 2: Use BeautifulSoup to remove HTML tags
# Use `"lxml"` rather than `"html5lib"`.
#
# Again, you may have to scroll down past the javascript and CSS in the output of the last cell in this section to see the text. **Alternatively,** you can run the following two lines right before running `soup.get_text()`:
#
# ```python
# for script in soup(["script", "style"]):
#     script.decompose()
# ```
# Read more about this [here](https://stackoverflow.com/questions/22799990/beatifulsoup4-get-text-still-has-javascript).

# %%
soup = BeautifulSoup(r.text, 'lxml')
print(soup.get_text())
# Out:
# window.NREUM||(NREUM={}),__nr_require=function(t,n,e){function r(e){if(!n[e]){var o=n[e]={exports:{}};t[e][0].call(o.exports,function(n){var o=t[e][1][n];return r(o||n)},o,o.exports)}return n[e].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<e.length;o++)r(e[o]);return r}({1:[function(t,n,e){function r(t){try{s.console&&console.log(t)}catch(n){}}var o,i=t("ee"),a=t(15),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,n,e){r(e.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,n){return t}).join(", ")))},{}],2:[function(t,n,e){function r(t,n,e,r,s){try{p?p-=1:o(s||new UncaughtException(t,n,e),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,n,e){this.message=t||"Uncaught error with no additional information",this.sourceURL=n,this.line=e}function o(t,n){var e=n?null:c.now();i("err",[t,e])}var i=t("handle"),a=t(16),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(8),t(7),"addEventListener"in window&&t(5),c.xhrWrappable&&t(9),d=!0)}s.on("fn-start",function(t,n,e){d&&(p+=1)}),s.on("fn-err",function(t,n,e){d&&!e[l]&&(f(e,l,function(){return!0}),this.thrown=!0,o(e))}),s.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,n,e){t("loader").features.ins=!0},{}],4:[function(t,n,e){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(8),s=t(7),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",y="pushState",g=t("loader");g.features.stn=!0,t(6);var b=NREUM.o.EV;o.on(m,function(t,n){var e=t[0];e instanceof b&&(this.bstStart=g.now())}),o.on(w,function(t,n){var e=t[0];e instanceof b&&i("bst",[e,n,this.bstStart,g.now()])}),a.on(m,function(t,n,e){this.bstStart=g.now(),this.bstType=e}),a.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),this.bstType])}),s.on(m,function(){this.bstStart=g.now()}),s.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),"requestAnimationFrame"])}),o.on(y+p,function(t){this.time=g.now(),this.startPath=location.pathname+location.hash}),o.on(y+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+c]?window.performance[f](u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["c"+c]()},!1):window.performance[f]("webkit"+u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+c]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,n,e){function r(t){for(var n=t;n&&!n.hasOwnProperty(u);)n=Object.getPrototypeOf(n);n&&o(n)}function o(t){s.inPlace(t,[u,d],"-",i)}function i(t,n){return t[1]}var a=t("ee").get("events"),s=t(18)(a,!0),c=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";n.exports=a,"getPrototypeOf"in Object?(r(document),r(window),r(f.prototype)):f.prototype.hasOwnProperty(u)&&(o(window),o(f.prototype)),a.on(u+"-start",function(t,n){var e=t[1],r=c(e,"nr@wrapped",function(){function t(){if("function"==typeof e.handleEvent)return e.handleEvent.apply(e,arguments)}var n={object:t,"function":e}[typeof e];return n?s(n,"fn-",null,n.name||"anonymous"):e});this.wrapped=t[1]=r}),a.on(d+"-start",function(t){t[1]=this.wrapped||t[1]})},{}],6:[function(t,n,e){var r=t("ee").get("history"),o=t(18)(r);n.exports=r,o.inPlace(window.history,["pushState","replaceState"],"-" ...
# ;NREUM.info={beacon:"bam.nr-data.net",errorBeacon:"bam.nr-data.net",licenseKey:"2059d2614a",applicationID:"218955133",sa:1}
# Courses | Udacity
#
#
#
#
#
#
#
#
# html[_ngcontent-sc0] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc0], *[_ngcontent-sc0]::after, *[_ngcontent-sc0]::before {
#   box-sizing: inherit; }
#
#
#
# html.wf-loading[_ngcontent-sc0]   .tk-font[_ngcontent-sc0] {
#   visibility: hidden; }
#
# html.wf-active[_ngcontent-sc0]   .tk-font[_ngcontent-sc0] {
#   visibility: initial; }
#
#
#
# .tk-font-balboa[_ngcontent-sc0] {
#   font-family: balboa, 'Open Sans', sans-serif; }
#
# .tk-font-balboa-condensed[_ngcontent-sc0] {
#   font-family: balboa-extra-condensed, 'Open Sans', sans-serif; }
#
# a[_ngcontent-sc0] {
#   color: darkviolet; }
#
# .popup[_ngcontent-sc0]   span[_ngcontent-sc0] {
#   font-size: 0.85rem; }
#
# .popup[_ngcontent-sc0]   span.download-app-text[_ngcontent-sc0] {
#     margin-top: 0.75rem;
#     display: inline-block; }
#
# .popup[_ngcontent-sc0]   .white-text[_ngcontent-sc0] {
#   color: #fff;
#   margin-top: 1.5rem; }
#
# body[_ngcontent-sc0] {
#   color: #028bb1; }
#
# [_nghost-sc0] {
#   display: block;
#   position: relative; }
#
# .sticky.isFixed[_nghost-sc0]   ir-header[_ngcontent-sc0], .sticky.isFixed   [_nghost-sc0]   ir-header[_ngcontent-sc0] {
#   top: auto; }
#
# @media screen and (min-width: 48rem) {
#     .sticky.isFixed[_nghost-sc0]   ir-header[_ngcontent-sc0], .sticky.isFixed   [_nghost-sc0]   ir-header[_ngcontent-sc0] {
#       top: 52px; } }html[_ngcontent-sc1] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc1], *[_ngcontent-sc1]::after, *[_ngcontent-sc1]::before {
#   box-sizing: inherit; }
#
#
#
# html.wf-loading[_ngcontent-sc1]   .tk-font[_ngcontent-sc1] {
#   visibility: hidden; }
#
# html.wf-active[_ngcontent-sc1]   .tk-font[_ngcontent-sc1] {
#   visibility: initial; }
#
#
#
# .tk-font-balboa[_ngcontent-sc1] {
#   font-family: balboa, 'Open Sans', sans-serif; }
#
# .tk-font-balboa-condensed[_ngcontent-sc1] {
#   font-family: balboa-extra-condensed, 'Open Sans', sans-serif; }
#
# .invisible[_ngcontent-sc1] {
#   visibility: hidden !important; }
#
# .hide[_ngcontent-sc1] {
#   display: none !important; }
#
# .show[_ngcontent-sc1] {
#   display: block !important; }
#
# .sr-only[_ngcontent-sc1] {
#   height: 1px;
#   width: 1px;
#   overflow: hidden;
#   position: absolute !important;
#   clip: rect(1px, 1px, 1px, 1px); }
#
# .hidden-xs-up[_ngcontent-sc1] {
#   display: none !important; }
#
# @media (max-width: 479px) {
#   .hidden-xs-down[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (min-width: 480px) {
#   .hidden-sm-up[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (max-width: 767px) {
#   .hidden-sm-down[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (min-width: 768px) {
#   .hidden-md-up[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (max-width: 991px) {
#   .hidden-md-down[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (min-width: 992px) {
#   .hidden-lg-up[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (max-width: 1179px) {
#   .hidden-lg-down[_ngcontent-sc1] {
#     display: none !important; } }
#
# @media (min-width: 1180px) {
#   .hidden-xl-up[_ngcontent-sc1] {
#     display: none !important; } }
#
# .hidden-xl-down[_ngcontent-sc1] {
#   display: none !important; }
#
# .visible-print-block[_ngcontent-sc1] {
#   display: none !important; }
#
# @media print {
#     .visible-print-block[_ngcontent-sc1] {
#       display: block !important; } }
#
# .visible-print-inline[_ngcontent-sc1] {
#   display: none !important; }
#
# @media print {
#     .visible-print-inline[_ngcontent-sc1] {
#       display: inline !important; } }
#
# .visible-print-inline-block[_ngcontent-sc1] {
#   display: none !important; }
#
# @media print {
#     .visible-print-inline-block[_ngcontent-sc1] {
#       display: inline-block !important; } }
#
# @media print {
#   .hidden-print[_ngcontent-sc1] {
#     display: none !important; } }
#
# #contain-all[_ngcontent-sc1] {
#   width: 100%;
#   overflow: hidden;
#   background: #fff;
#   -webkit-backface-visibility: hidden;
#           backface-visibility: hidden;
#   -webkit-transform-style: preserve-3d; }
#
# .outer_contain[_ngcontent-sc1] {
#   margin: 0 auto;
#   max-width: 90rem; }
#
# .contain[_ngcontent-sc1] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto;
#   padding-top: 3rem;
#   padding-bottom: 3rem;
#   padding-left: 0.75rem;
#   padding-right: 0.75rem; }
#
# .contain[_ngcontent-sc1]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# @media screen and (min-width: 48rem) {
#
#     .contain[_ngcontent-sc1] {
#       padding-top: 6rem;
#       padding-bottom: 6rem; } }
#
# @media screen and (min-width: 30rem) {
#
#     .contain[_ngcontent-sc1] {
#       padding-left: 0.99rem;
#       padding-right: 0.99rem; } }
#
# @media screen and (min-width: 48rem) {
#
#     .contain[_ngcontent-sc1] {
#       padding-left: 1.5rem;
#       padding-right: 1.5rem; } }
#
# @media screen and (min-width: 73.75rem) {
#
#     .contain[_ngcontent-sc1] {
#       padding-left: 0;
#       padding-right: 0; } }
#
# .contain.no-padding[_ngcontent-sc1] {
#     padding: 0; }
#
# .contain.no-padding-top[_ngcontent-sc1] {
#     padding-top: 0; }
#
# .contain.no-padding-bottom[_ngcontent-sc1] {
#     padding-bottom: 0; }
#
# .contain--none[_ngcontent-sc1] {
#     padding-top: 0rem;
#     padding-bottom: 0rem;
#     margin: 0 auto; }
#
# @media screen and (min-width: 48rem) {
#
#       .contain--none[_ngcontent-sc1] {
#         padding-top: 0rem;
#         padding-bottom: 0rem; } }
#
# .contain--small[_ngcontent-sc1] {
#     padding-top: 3rem;
#     padding-bottom: 3rem;
#     margin: 0 auto; }
#
# @media screen and (min-width: 48rem) {
#
#       .contain--small[_ngcontent-sc1] {
#         padding-top: 4.5rem;
#         padding-bottom: 4.5rem; } }
#
# .cards_contain[_ngcontent-sc1] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto; }
#
# .cards_contain[_ngcontent-sc1]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# [_ngcontent-sc1]:-webkit-full-screen-ancestor {
#   -webkit-animation: none !important;
#           animation: none !important;
#   -webkit-animation-fill-mode: none !important;
#   animation-fill-mode: none !important; }
#
# [_ngcontent-sc1]:target:before {
#   content: '';
#   display: inline-block;
#   height: 130px;
#   margin: -130px 0 0; }
#
# .header[_ngcontent-sc1] {
#   max-width: 100%;
#   margin-left: auto;
#   margin-right: auto; }
#
# .header[_ngcontent-sc1]::after {
#     clear: both;
#     content: "";
#     display: table; }
#
# .header.header--clone[_ngcontent-sc1] {
#     width: 100%;
#     top: -1000px; }
#
# .header.header--clone[_ngcontent-sc1]   .header__navbar[_ngcontent-sc1] {
#       height: 4.5rem; }
#
# .header.header--stick[_ngcontent-sc1] {
#     top: 0;
#     background-color: #fff;
#     z-index: 8000;
#     box-shadow: 0px 1px 2px rgba(0, 0, 0, 0.1); }
#
# .header__navbar[_ngcontent-sc1] {
#     max-width: 73.75rem;
#     margin-left: auto;
#     margin-right: auto;
#     height: 4.5rem;
#     padding: 0 1.5em; }
#
# .header__navbar[_ngcontent-sc1]::after {
#       clear: both;
#       content: "";
#       display: table; }
#
# @media screen and (min-width: 48rem) {
#       .header__navbar[_ngcontent-sc1] {
#         height: 6rem; } }
#
# @media screen and (min-width: 73.75rem) {
#       .header__navbar[_ngcontent-sc1] {
#         padding: 0; } }
#
# .header__navbar--toggle[_ngcontent-sc1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69491525%;
#       width: 15.25423729%; }
#
# .header__navbar--toggle[_ngcontent-sc1]:last-child {
#         margin-right: 0; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--toggle[_ngcontent-sc1] {
#           display: none; } }
#
# .header__navbar--logo[_ngcontent-sc1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69491525%;
#       width: 66.10169492%; }
#
# .header__navbar--logo[_ngcontent-sc1]:last-child {
#         margin-right: 0; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc1] {
#           float: left;
#           display: block;
#           margin-right: 0.84033613%;
#           width: 20.16806723%; }
#           .header__navbar--logo[_ngcontent-sc1]:last-child {
#             margin-right: 0; } }
#
# .header__navbar--catalog[_ngcontent-sc1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       display: none; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--catalog[_ngcontent-sc1] {
#           float: left;
#           display: block;
#           margin-right: 0.84033613%;
#           width: 7.56302521%; }
#           .header__navbar--catalog[_ngcontent-sc1]:last-child {
#             margin-right: 0; } }
#
# .header__navbar--navigation[_ngcontent-sc1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       display: none; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--navigation[_ngcontent-sc1] {
#           float: left;
#           display: block;
#           margin-right: 1.69491525%;
#           width: 74.57627119%; }
#           .header__navbar--navigation[_ngcontent-sc1]:last-child {
#             margin-right: 0; } }
#
# .header__navbar--logo[_ngcontent-sc1] {
#     text-align: center; }
#
# @media screen and (min-width: 62rem) {
#       .header__navbar--logo[_ngcontent-sc1] {
#         text-align: left; } }
#
# .header__navbar--logo[_ngcontent-sc1]   .logo-wordmark[_ngcontent-sc1] {
#       width: 11.25rem;
#       height: 1.875rem;
#       display: none; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc1]   .logo-wordmark[_ngcontent-sc1] {
#           display: block; } }
#
# .header__navbar--logo[_ngcontent-sc1]   .logo-mark[_ngcontent-sc1] {
#       display: block;
#       margin: 0 auto;
#       width: 1.875rem;
#       height: 1.875rem; }
#
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc1]   .logo-mark[_ngcontent-sc1] {
#           display: none; } }
#
# .header__navbar--toggle[_ngcontent-sc1]   .nav-toggle[_ngcontent-sc1] {
#     display: block;
#     width: 1.25rem;
#     height: 1.25rem;
#     cursor: pointer;
#     transition: -webkit-transform .25s ease;
#     transition: transform .25s ease;
#     transition: transform .25s ease, -webkit-transform .25s ease; }
#
# .header__navbar--toggle[_ngcontent-sc1]   .nav-toggle[_ngcontent-sc1]   .bar[_ngcontent-sc1] {
#       display: block;
#       width: 100%;
#       height: 0.1875rem;
#       margin-left: -0.5rem;
#       margin-top: 0.1875rem;
#       background: #02b3e4;
#       transition: opacity .25s ease, -webkit-transform .25s ease;
#       transition: opacity .25s ease, transform .25s ease;
#       transition: opacity .25s ease, transform .25s ease, -webkit-transform .25s ease;
#       -webkit-user-select: none;
#          -moz-user-select: none;
#           -ms-user-select: none;
#               user-select: none; }
#
# .header__navbar--navigation[_ngcontent-sc1]   nav[_ngcontent-sc1] {
#     float: right; }
#
# .header__navbar--navigation[_ngcontent-sc1]   a[_ngcontent-sc1], .header__navbar--navigation[_ngcontent-sc1]   div[_ngcontent-sc1] {
#     float: left; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button[_ngcontent-sc1] {
#     display: none;
#     letter-spacing: 0;
#     font-size: 0.875rem;
#     text-transform: capitalize;
#     height: 2.25rem;
#     font-weight: 400;
#     margin-left: 2.5rem;
#     line-height: 1.9375rem; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button[_ngcontent-sc1]:first-child {
#       margin-left: 0; }
#
# @media screen and (min-width: 62rem) {
#       .header__navbar--navigation[_ngcontent-sc1]   .button[_ngcontent-sc1] {
#         display: block; } }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--navigation[_ngcontent-sc1] {
#       padding: 0;
#       color: #525c65; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--navigation[_ngcontent-sc1]:hover {
#         color: #474f57; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--primary[_ngcontent-sc1], .header__navbar--navigation[_ngcontent-sc1]   .button--turquoise[_ngcontent-sc1] {
#       width: 7.75rem;
#       box-shadow: 8px 10px 20px 0px rgba(46, 61, 73, 0.15);
#       background-color: #02b3e4; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--primary[_ngcontent-sc1]:hover, .header__navbar--navigation[_ngcontent-sc1]   .button--turquoise[_ngcontent-sc1]:hover {
#         box-shadow: 2px 4px 8px 0px rgba(46, 61, 73, 0.2);
#         background-color: #02b7e9; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--turquoise[_ngcontent-sc1] {
#       background-color: #02ccba; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--turquoise[_ngcontent-sc1]:hover {
#         background-color: #02d1bf; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .button--guest[_ngcontent-sc1], .header__navbar--navigation[_ngcontent-sc1]   .button--student[_ngcontent-sc1] {
#       display: none; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .divider[_ngcontent-sc1] {
#     cursor: default; }
#
# .header__navbar--navigation[_ngcontent-sc1]   .divider[_ngcontent-sc1]::before {
#       content: '';
#       border-left: 1px solid rgba(82, 92, 101, 0.4);
#       width: 0px;
#       height: 12px; }
#
# .header__sidenav[_ngcontent-sc1] {
#     background-color: #2e3d49; }
#
# .header__sidenav--logo[_ngcontent-sc1] {
#       height: 4.5rem;
#       display: block;
#       background-color: #1C262F; }
#
# .header__sidenav--logo[_ngcontent-sc1]::after {
#         clear: both;
#         content: "";
#         display: table; }
#
# .header__sidenav--logo[_ngcontent-sc1]   .logo-link[_ngcontent-sc1] {
#         display: block;
#         width: 100%;
#         height: 100%; }
#
# .header__sidenav--logo[_ngcontent-sc1]   .logo-link[_ngcontent-sc1]   .logo-wordmark[_ngcontent-sc1] {
#           position: relative;
#           top: 50%;
#           -webkit-transform: translateY(-50%);
#           transform: translateY(-50%);
#           padding-left: 1.5em;
#           width: 11.25rem;
#           height: 1.875rem; }
#
# .header__sidenav--logo[_ngcontent-sc1]   .logo-link[_ngcontent-sc1]   #wordmark[_ngcontent-sc1] {
#           fill: #fff; }
#
# .header__sidenav--navigation[_ngcontent-sc1] {
#       display: block; }
#
# .header__sidenav--navigation[_ngcontent-sc1]::after {
#         clear: both;
#         content: "";
#         display: table; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   li[_ngcontent-sc1] {
#         height: 4.5rem; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   a[_ngcontent-sc1] {
#         padding-top: 1.5rem;
#         padding-bottom: 1.5rem;
#         color: #fff;
#         display: block;
#         padding-left: 1.5em; }
#
# @media screen and (min-width: 48rem) {
#           .header__sidenav--navigation[_ngcontent-sc1]   a[_ngcontent-sc1] {
#             padding-top: 1.5rem;
#             padding-bottom: 1.5rem; } }
#
# .header__sidenav--navigation[_ngcontent-sc1]   a[_ngcontent-sc1]:hover {
#           color: #cccccc; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   .guest[_ngcontent-sc1], .header__sidenav--navigation[_ngcontent-sc1]   .student[_ngcontent-sc1] {
#         display: none; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   .guest[_ngcontent-sc1]   a[_ngcontent-sc1], .header__sidenav--navigation[_ngcontent-sc1]   .student[_ngcontent-sc1]   a[_ngcontent-sc1] {
#           color: #02b3e4; }
#
# .header__sidenav--navigation[_ngcontent-sc1]   .guest[_ngcontent-sc1]   a[_ngcontent-sc1]:hover, .header__sidenav--navigation[_ngcontent-sc1]   .student[_ngcontent-sc1]   a[_ngcontent-sc1]:hover {
#             color: #01647f; }
#
# [_nghost-sc1] {
#   background: #2e3d49;
#   position: fixed;
#   top: 0;
#   left: 0;
#   height: 100vh;
#   display: block;
#   overflow-y: auto;
#   z-index: -1000;
#   width: 16.25rem;
#   -webkit-overflow-scrolling: touch;
#   display: block; }
#
# @media screen and (min-width: 62rem) {
#     [_nghost-sc1] {
#       display: none; } }
#
# [_nghost-sc1]   .logo-link[_ngcontent-sc1] {
#     height: 4.5rem;
#     display: block;
#     background-color: #1C262F; }
#
# [_nghost-sc1]   .logo-link[_ngcontent-sc1]::after {
#       clear: both;
#       content: "";
#       display: table; }
#
# [_nghost-sc1]   .logo-link[_ngcontent-sc1]   .logo-wordmark[_ngcontent-sc1] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       padding-left: 1.5em;
#       width: 11.25rem;
#       height: 1.875rem; }
#
# [_nghost-sc1]   .logo-link[_ngcontent-sc1]   #wordmark[_ngcontent-sc1] {
#       fill: #fff; }
#
# [_nghost-sc1]   ul[_ngcontent-sc1] {
#     list-style: none;
#     padding: 0; }
#
# .mobile-nav__active[_nghost-sc1] {
#     visibility: visible;
#     opacity: 1; }
#
# .mobile-nav__inactive[_nghost-sc1] {
#     visibility: hidden;
#     transition: visibility 0.3s; }
#
# .page-lg[_nghost-sc1], .page-lg   [_nghost-sc1] {
#   display: none; }html[_ngcontent-sc2] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc2], *[_ngcontent-sc2]::after, *[_ngcontent-sc2]::before {
#   box-sizing: inherit; }
#
#
#
# html.wf-loading[_ngcontent-sc2]   .tk-font[_ngcontent-sc2] {
#   visibility: hidden; }
#
# html.wf-active[_ngcontent-sc2]   .tk-font[_ngcontent-sc2] {
#   visibility: initial; }
#
#
#
# .tk-font-balboa[_ngcontent-sc2] {
#   font-family: balboa, 'Open Sans', sans-serif; }
#
# .tk-font-balboa-condensed[_ngcontent-sc2] {
#   font-family: balboa-extra-condensed, 'Open Sans', sans-serif; }
#
# [_nghost-sc2] {
#   position: absolute;
#   width: 100%;
#   top: 0;
#   left: 0;
#   min-height: 100vh;
#   z-index: 0;
#   transition: -webkit-transform 0.3s ease;
#   transition: transform 0.3s ease;
#   transition: transform 0.3s ease, -webkit-transform 0.3s ease;
#   background: #fff; }
#
# .menu--open[_nghost-sc2]:not(.nav-experiment), .menu--open:not(.nav-experiment)   [_nghost-sc2] {
#   -webkit-transform: translateX(16.25rem);
#           transform: translateX(16.25rem); }
#
# .menu--open[_nghost-sc2], .menu--open   [_nghost-sc2] {
#   height: 100vh;
#   overflow: hidden; }
#
# @media screen and (min-width: 62rem) {
#     .menu--open[_nghost-sc2], .menu--open   [_nghost-sc2] {
#       overflow: auto;
#       -webkit-transform: none;
#               transform: none;
#       height: auto; } }
#
# .sticky[_nghost-sc2]:not(.no-sticky-header), .sticky:not(.no-sticky-header)   [_nghost-sc2] {
#   padding-top: 4.5rem; }
#
# @media screen and (min-width: 48rem) {
#     .sticky[_nghost-sc2]:not(.no-sticky-header), .sticky:not(.no-sticky-header)   [_nghost-sc2] {
#       padding-top: 6rem; } }
#
# .page-cn.page-school-of-data-science[_nghost-sc2], .page-cn.page-school-of-data-science   [_nghost-sc2] {
#   padding-top: 0; }html[_ngcontent-sc3] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc3], *[_ngcontent-sc3]::after, *[_ngcontent-sc3]::before {
#   box-sizing: inherit; }
#
#
#
# html.wf-loading[_ngcontent-sc3]   .tk-font[_ngcontent-sc3] {
#   visibility: hidden; }
#
# html.wf-active[_ngcontent-sc3]   .tk-font[_ngcontent-sc3] {
#   visibility: initial; }
#
#
#
# .tk-font-balboa[_ngcontent-sc3] {
#   font-family: balboa, 'Open Sans', sans-serif; }
#
# .tk-font-balboa-condensed[_ngcontent-sc3] {
#   font-family: balboa-extra-condensed, 'Open Sans', sans-serif; }
#
# [_nghost-sc3] {
#   display: block;
#   overflow: hidden; }
#
# .moustache[_ngcontent-sc3] {
#   position: relative;
#   width: 100%;
#   background: #fff;
#   padding: 0.75rem 1.75rem 0.75rem 1.5rem;
#   color: #fff;
#   z-index: 8999; }
#
# .moustache[_ngcontent-sc3]   .paragraph[_ngcontent-sc3] {
#     margin: 0 auto;
#     max-width: 73.75rem; }
#
# .moustache[_ngcontent-sc3]   p[_ngcontent-sc3]   a[_ngcontent-sc3] {
#     border-bottom: none; }
#
# .moustache[_ngcontent-sc3]   p[_ngcontent-sc3]   a.moustache__link--button[_ngcontent-sc3] {
#       border-bottom: 1px solid;
#       margin: 0 0.8rem; }
#
# .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache[_ngcontent-sc3]   a[_ngcontent-sc3] {
#     color: #02b3e4;
#     display: inline-block;
#     margin: 0; }
#
# .moustache[_ngcontent-sc3]   .close-btn[_ngcontent-sc3] {
#     position: absolute;
#     top: 0;
#     right: 1rem;
#     bottom: 0;
#     display: flex;
#     background-color: transparent;
#     border: none;
#     outline: none;
#     opacity: 0.75;
#     margin: auto 0;
#     padding: 0;
#     color: #fff;
#     transition: opacity 0.3s ease; }
#
# .moustache[_ngcontent-sc3]   .close-btn[_ngcontent-sc3]   svg[_ngcontent-sc3] {
#       height: 0.8rem;
#       width: auto; }
#
# .moustache[_ngcontent-sc3]   .close-btn[_ngcontent-sc3]:hover {
#       opacity: 1; }
#
# .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#     fill: #02b3e4; }
#
# .moustache.white[_ngcontent-sc3] {
#     background: #fff; }
#
# .moustache.white[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.white[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #02b3e4;
#       font-size: 1rem; }
#
# .moustache.white[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #02b3e4; }
#
# .moustache.blue[_ngcontent-sc3] {
#     background: #02b3e4; }
#
# .moustache.blue[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.blue[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #fff;
#       font-size: 1rem; }
#
# .moustache.blue[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #fff; }
#
# .moustache.blue-turquoise[_ngcontent-sc3] {
#     background: linear-gradient(to right, #02b3e4, #02ccba); }
#
# .moustache.blue-turquoise[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.blue-turquoise[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #fff;
#       font-size: 1rem; }
#
# .moustache.blue-turquoise[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #fff; }
#
# .moustache.purple-turquoise[_ngcontent-sc3] {
#     background: linear-gradient(to right, #a951ed, #02ccba); }
#
# .moustache.purple-turquoise[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.purple-turquoise[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #fff;
#       font-size: 1rem; }
#
# .moustache.purple-turquoise[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #fff; }
#
# .moustache.magenta-yellow[_ngcontent-sc3] {
#     background: linear-gradient(to right, #ff5483, #ffae0c); }
#
# .moustache.magenta-yellow[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.magenta-yellow[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #fff;
#       font-size: 1rem; }
#
# .moustache.magenta-yellow[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #fff; }
#
# .moustache.yellow-purple[_ngcontent-sc3] {
#     background: linear-gradient(to right, #ffae0c, #a951ed); }
#
# .moustache.yellow-purple[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.yellow-purple[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #fff;
#       font-size: 1rem; }
#
# .moustache.yellow-purple[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #fff; }
#
# .moustache.yellow-on-black[_ngcontent-sc3] {
#     background: #000; }
#
# .moustache.yellow-on-black[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.yellow-on-black[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #ffae0c;
#       font-size: 1rem; }
#
# .moustache.yellow-on-black[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #ffae0c; }
#
# .moustache.black-on-yellow[_ngcontent-sc3] {
#     background: #ecc81a; }
#
# .moustache.black-on-yellow[_ngcontent-sc3]   p[_ngcontent-sc3], .moustache.black-on-yellow[_ngcontent-sc3]   a[_ngcontent-sc3] {
#       color: #000;
#       font-size: 1rem; }
#
# .moustache.black-on-yellow[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#       fill: #000; }
#
# .page-in.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-corporate[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-corporate   [_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-campaign[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-campaign   [_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-google-india-scholarships[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-google-india-scholarships   [_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-ucollege[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-in.page-ucollege   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   display: none; }
#
# .page-cn[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-cn   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   background: #02b3e4; }
#
# .page-cn[_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn   [_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn[_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3], .page-cn   [_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3] {
#     color: #fff;
#     font-size: 1rem; }
#
# .page-cn[_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3], .page-cn   [_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#     fill: #fff; }
#
# .page-cn.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-cn.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   background: #fff; }
#
# .page-cn.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3], .page-cn.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3] {
#     color: #02b3e4;
#     font-size: 1rem; }
#
# .page-cn.page-homepage[_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3], .page-cn.page-homepage   [_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#     fill: #02b3e4; }
#
# .page-cn.page-homepage.sticky.isFixed[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-cn.page-homepage.sticky.isFixed   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   background: #02b3e4; }
#
# .page-cn.page-homepage.sticky.isFixed[_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn.page-homepage.sticky.isFixed   [_nghost-sc3]   .moustache[_ngcontent-sc3]   p[_ngcontent-sc3], .page-cn.page-homepage.sticky.isFixed[_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3], .page-cn.page-homepage.sticky.isFixed   [_nghost-sc3]   .moustache[_ngcontent-sc3]   a[_ngcontent-sc3] {
#     color: #fff;
#     font-size: 1rem; }
#
# .page-cn.page-homepage.sticky.isFixed[_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3], .page-cn.page-homepage.sticky.isFixed   [_nghost-sc3]   .moustache[_ngcontent-sc3]   #close-icon[_ngcontent-sc3] {
#     fill: #fff; }
#
# .sticky.isFixed[_nghost-sc3]   .moustache[_ngcontent-sc3], .sticky.isFixed   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   position: fixed;
#   z-index: 8001;
#   top: 0; }
#
# .page-cn.page-20181111[_nghost-sc3]   .moustache[_ngcontent-sc3], .page-cn.page-20181111   [_nghost-sc3]   .moustache[_ngcontent-sc3] {
#   display: none; }html[_ngcontent-sc4] {
#   box-sizing: border-box; }
#
# *[_ngcontent-sc4], *[_ngcontent-sc4]::after, *[_ngcontent-sc4]::before {
#   box-sizing: inherit; }
#
#
#
# html.wf-loading[_ngcontent-sc4]   .tk-font[_ngcontent-sc4] {
#   visibility: hidden; }
#
# html.wf-active[_ngcontent-sc4]   .tk-font[_ngcontent-sc4] {
#   visibility: initial; }
#
#
#
# .tk-font-balboa[_ngcontent-sc4] {
#   font-family: balboa, 'Open Sans', sans-serif; }
#
# .tk-font-balboa-condensed[_ngcontent-sc4] {
#   font-family: balboa-extra-condensed, 'Open Sans', sans-serif; }
#
# .geo-redirect-modal[_ngcontent-sc4] {
#   padding: 3.5em 2.5em 4em;
#   text-align: center; }
#
# .geo-redirect-modal[_ngcontent-sc4]   .geo-redirect-flag[_ngcontent-sc4] {
#     vertical-align: sub; }
#
# .geo-redirect-modal[_ngcontent-sc4]   .geo-redirect-cta[_ngcontent-sc4] {
#     vertical-align: baseline; }
#
# .geo-redirect-modal[_ngcontent-sc4]   .button[_ngcontent-sc4] {
#     margin: auto; }
#
# .geo-redirect-modal[_ngcontent-sc4]   label[_ngcontent-sc4] {
#     clear: left;
#     display: block;
#     position: relative;
#     padding-left: 2.833333333em;
#     margin: 0 auto 2.5em;
#     font-size: 0.875em;
#     color: #dbe2e8;
#     font-weight: 400;
#     text-align: left;
#     width: 60%; }
#
# .geo-redirect-modal[_ngcontent-sc4]   label[_ngcontent-sc4]::before {
#       content: '';
#       position: absolute;
#       top: 0;
#       left: 0;
#       width: 1.666666667em;
#       height: 1.666666667em;
#       border: 1px solid #dbe2e8; }
#
# .geo-redirect-modal[_ngcontent-sc4]   label[_ngcontent-sc4]::after {
#       content: '';
#       position: absolute;
#       top: 0;
#       left: 0;
#       width: 1.666666667em;
#       height: 1.666666667em;
#       background-image: url("/assets/iridium/images/svgs/check_blue.svg");
#       background-repeat: no-repeat;
#       background-position: center;
#       background-size: 0%;
#       transition: opacity 0.3s ease, background-size 0.3s ease; }
#
# .geo-redirect-modal[_ngcontent-sc4]   input[type=checkbox][_ngcontent-sc4] {
#     visibility: hidden;
#     width: 0; }@charset "UTF-8";
# html[_ngcontent-sc5] {
#   box-sizing: border-box; }
# *[_ngcontent-sc5], *[_ngcontent-sc5]::after, *[_ngcontent-sc5]::before {
#   box-sizing: inherit; }
#
# html.wf-loading[_ngcontent-sc5]   .tk-font[_ngcontent-sc5] {
#   visibility: hidden; }
# html.wf-active[_ngcontent-sc5]   .tk-font[_ngcontent-sc5] {
#   visibility: initial; }
#
# .tk-font-balboa[_ngcontent-sc5] {
#   font-family: balboa, 'Open Sans', sans-serif; }
# .tk-font-balboa-condensed[_ngcontent-sc5] {
#   font-family: balboa-extra-condensed, 'Open Sans', sans-serif; }
# .invisible[_ngcontent-sc5] {
#   visibility: hidden !important; }
# .hide[_ngcontent-sc5] {
#   display: none !important; }
# .show[_ngcontent-sc5] {
#   display: block !important; }
# .sr-only[_ngcontent-sc5] {
#   height: 1px;
#   width: 1px;
#   overflow: hidden;
#   position: absolute !important;
#   clip: rect(1px, 1px, 1px, 1px); }
# .hidden-xs-up[_ngcontent-sc5] {
#   display: none !important; }
# @media (max-width: 479px) {
#   .hidden-xs-down[_ngcontent-sc5] {
#     display: none !important; } }
# @media (min-width: 480px) {
#   .hidden-sm-up[_ngcontent-sc5] {
#     display: none !important; } }
# @media (max-width: 767px) {
#   .hidden-sm-down[_ngcontent-sc5] {
#     display: none !important; } }
# @media (min-width: 768px) {
#   .hidden-md-up[_ngcontent-sc5] {
#     display: none !important; } }
# @media (max-width: 991px) {
#   .hidden-md-down[_ngcontent-sc5] {
#     display: none !important; } }
# @media (min-width: 992px) {
#   .hidden-lg-up[_ngcontent-sc5] {
#     display: none !important; } }
# @media (max-width: 1179px) {
#   .hidden-lg-down[_ngcontent-sc5] {
#     display: none !important; } }
# @media (min-width: 1180px) {
#   .hidden-xl-up[_ngcontent-sc5] {
#     display: none !important; } }
# .hidden-xl-down[_ngcontent-sc5] {
#   display: none !important; }
# .visible-print-block[_ngcontent-sc5] {
#   display: none !important; }
# @media print {
#     .visible-print-block[_ngcontent-sc5] {
#       display: block !important; } }
# .visible-print-inline[_ngcontent-sc5] {
#   display: none !important; }
# @media print {
#     .visible-print-inline[_ngcontent-sc5] {
#       display: inline !important; } }
# .visible-print-inline-block[_ngcontent-sc5] {
#   display: none !important; }
# @media print {
#     .visible-print-inline-block[_ngcontent-sc5] {
#       display: inline-block !important; } }
# @media print {
#   .hidden-print[_ngcontent-sc5] {
#     display: none !important; } }
# #contain-all[_ngcontent-sc5] {
#   width: 100%;
#   overflow: hidden;
#   background: #fff;
#   -webkit-backface-visibility: hidden;
#           backface-visibility: hidden;
#   -webkit-transform-style: preserve-3d; }
# .outer_contain[_ngcontent-sc5] {
#   margin: 0 auto;
#   max-width: 90rem; }
# .contain[_ngcontent-sc5] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto;
#   padding-top: 3rem;
#   padding-bottom: 3rem;
#   padding-left: 0.75rem;
#   padding-right: 0.75rem; }
# .contain[_ngcontent-sc5]::after {
#     clear: both;
#     content: "";
#     display: table; }
# @media screen and (min-width: 48rem) {
#
#     .contain[_ngcontent-sc5] {
#       padding-top: 6rem;
#       padding-bottom: 6rem; } }
# @media screen and (min-width: 30rem) {
#
#     .contain[_ngcontent-sc5] {
#       padding-left: 0.99rem;
#       padding-right: 0.99rem; } }
# @media screen and (min-width: 48rem) {
#
#     .contain[_ngcontent-sc5] {
#       padding-left: 1.5rem;
#       padding-right: 1.5rem; } }
# @media screen and (min-width: 73.75rem) {
#
#     .contain[_ngcontent-sc5] {
#       padding-left: 0;
#       padding-right: 0; } }
# .contain.no-padding[_ngcontent-sc5] {
#     padding: 0; }
# .contain.no-padding-top[_ngcontent-sc5] {
#     padding-top: 0; }
# .contain.no-padding-bottom[_ngcontent-sc5] {
#     padding-bottom: 0; }
# .contain--none[_ngcontent-sc5] {
#     padding-top: 0rem;
#     padding-bottom: 0rem;
#     margin: 0 auto; }
# @media screen and (min-width: 48rem) {
#
#       .contain--none[_ngcontent-sc5] {
#         padding-top: 0rem;
#         padding-bottom: 0rem; } }
# .contain--small[_ngcontent-sc5] {
#     padding-top: 3rem;
#     padding-bottom: 3rem;
#     margin: 0 auto; }
# @media screen and (min-width: 48rem) {
#
#       .contain--small[_ngcontent-sc5] {
#         padding-top: 4.5rem;
#         padding-bottom: 4.5rem; } }
# .cards_contain[_ngcontent-sc5] {
#   max-width: 73.75rem;
#   margin-left: auto;
#   margin-right: auto; }
# .cards_contain[_ngcontent-sc5]::after {
#     clear: both;
#     content: "";
#     display: table; }
# [_ngcontent-sc5]:-webkit-full-screen-ancestor {
#   -webkit-animation: none !important;
#           animation: none !important;
#   -webkit-animation-fill-mode: none !important;
#   animation-fill-mode: none !important; }
# [_ngcontent-sc5]:target:before {
#   content: '';
#   display: inline-block;
#   height: 130px;
#   margin: -130px 0 0; }
# .header[_ngcontent-sc5], [_nghost-sc5] {
#   max-width: 100%;
#   margin-left: auto;
#   margin-right: auto; }
# .header[_ngcontent-sc5]::after, [_nghost-sc5]::after {
#     clear: both;
#     content: "";
#     display: table; }
# .header.header--clone[_ngcontent-sc5], .header--clone[_nghost-sc5] {
#     width: 100%;
#     top: -1000px; }
# .header.header--clone[_ngcontent-sc5]   .header__navbar[_ngcontent-sc5], .header--clone[_nghost-sc5]   .header__navbar[_ngcontent-sc5], .header.header--clone[_ngcontent-sc5]   header[_ngcontent-sc5], .header--clone[_nghost-sc5]   header[_ngcontent-sc5] {
#       height: 4.5rem; }
# .header.header--stick[_ngcontent-sc5], .header--stick[_nghost-sc5] {
#     top: 0;
#     background-color: #fff;
#     z-index: 8000;
#     box-shadow: 0px 1px 2px rgba(0, 0, 0, 0.1); }
# .header__navbar[_ngcontent-sc5], header[_ngcontent-sc5] {
#     max-width: 73.75rem;
#     margin-left: auto;
#     margin-right: auto;
#     height: 4.5rem;
#     padding: 0 1.5em; }
# .header__navbar[_ngcontent-sc5]::after, header[_ngcontent-sc5]::after {
#       clear: both;
#       content: "";
#       display: table; }
# @media screen and (min-width: 48rem) {
#       .header__navbar[_ngcontent-sc5], header[_ngcontent-sc5] {
#         height: 6rem; } }
# @media screen and (min-width: 73.75rem) {
#       .header__navbar[_ngcontent-sc5], header[_ngcontent-sc5] {
#         padding: 0; } }
# .header__navbar--toggle[_ngcontent-sc5] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69491525%;
#       width: 15.25423729%; }
# .header__navbar--toggle[_ngcontent-sc5]:last-child {
#         margin-right: 0; }
# @media screen and (min-width: 62rem) {
#         .header__navbar--toggle[_ngcontent-sc5] {
#           display: none; } }
# .header__navbar--logo[_ngcontent-sc5] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       float: left;
#       display: block;
#       margin-right: 1.69491525%;
#       width: 66.10169492%; }
# .header__navbar--logo[_ngcontent-sc5]:last-child {
#         margin-right: 0; }
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc5] {
#           float: left;
#           display: block;
#           margin-right: 0.84033613%;
#           width: 20.16806723%; }
#           .header__navbar--logo[_ngcontent-sc5]:last-child {
#             margin-right: 0; } }
# .header__navbar--catalog[_ngcontent-sc5] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       display: none; }
# @media screen and (min-width: 62rem) {
#         .header__navbar--catalog[_ngcontent-sc5] {
#           float: left;
#           display: block;
#           margin-right: 0.84033613%;
#           width: 7.56302521%; }
#           .header__navbar--catalog[_ngcontent-sc5]:last-child {
#             margin-right: 0; } }
# .header__navbar--navigation[_ngcontent-sc5] {
#       position: relative;
#       top: 50%;
#       -webkit-transform: translateY(-50%);
#       transform: translateY(-50%);
#       display: none; }
# @media screen and (min-width: 62rem) {
#         .header__navbar--navigation[_ngcontent-sc5] {
#           float: left;
#           display: block;
#           margin-right: 1.69491525%;
#           width: 74.57627119%; }
#           .header__navbar--navigation[_ngcontent-sc5]:last-child {
#             margin-right: 0; } }
# .header__navbar--logo[_ngcontent-sc5] {
#     text-align: center; }
# @media screen and (min-width: 62rem) {
#       .header__navbar--logo[_ngcontent-sc5] {
#         text-align: left; } }
# .header__navbar--logo[_ngcontent-sc5]   .logo-wordmark[_ngcontent-sc5], .header__navbar--logo[_ngcontent-sc5]   .logo-wordmark--cn[_ngcontent-sc5] {
#       width: 11.25rem;
#       height: 1.875rem;
#       display: none; }
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc5]   .logo-wordmark[_ngcontent-sc5], .header__navbar--logo[_ngcontent-sc5]   .logo-wordmark--cn[_ngcontent-sc5] {
#           display: block; } }
# .header__navbar--logo[_ngcontent-sc5]   .logo-mark[_ngcontent-sc5] {
#       display: block;
#       margin: 0 auto;
#       width: 1.875rem;
#       height: 1.875rem; }
# @media screen and (min-width: 62rem) {
#         .header__navbar--logo[_ngcontent-sc5]   .logo-mark[_ngcontent-sc5] {
#           display: none; } }
# .header__navbar--toggle[_ngcontent-sc5]   .nav-toggle[_ngcontent-sc5] {
#     display: block;
#     width: 1.25rem;
#     height: 1.25rem;
#     cursor: pointer;
#     transition: -webkit-transform .25s ease;
#     transition: transform .25s ease;
#     transition: transform .25s ease, -webkit-transform .25s ease; }
# .header__navbar--toggle[_ngcontent-sc5]   .nav-toggle[_ngcontent-sc5]   .bar[_ngcontent-sc5] {
#       display: block;
#       width: 100%;
#       height: 0.1875rem;
#       margin-left: -0.5rem;
#       margin-top: 0.1875rem;
#       background: #02b3e4;
#       transition: opacity .25s ease, -webkit-transform .25s ease;
#       transition: opacity .25s ease, transform .25s ease;
#       transition: opacity .25s ease, transform .25s ease, -webkit-transform .25s ease;
#       -webkit-user-select: none;
#          -moz-user-select: none;
#           -ms-user-select: none;
#               user-select: none; }
# .header__navbar--navigation[_ngcontent-sc5]   nav[_ngcontent-sc5] {
#     float: right; }
# .header__navbar--navigation[_ngcontent-sc5]   a[_ngcontent-sc5], .header__navbar--navigation[_ngcontent-sc5]   div[_ngcontent-sc5] {
#     float: left; }
# .header__navbar--navigation[_ngcontent-sc5]   .button[_ngcontent-sc5] {
#     display: none;
#     letter-spacing: 0;
#     font-size: 0.875rem;
#     text-transform: capitalize;
#     height: 2.25rem;
#     font-weight: 400;
#     margin-left: 2.5rem;
#     line-height: 1.9375rem; }
# .header__navbar--navigation[_ngcontent-sc5]   .button[_ngcontent-sc5]:first-child {
#       margin-left: 0; }
# @media screen and (min-width: 62rem) {
#       .header__navbar--navigation[_ngcontent-sc5]   .button[_ngcontent-sc5] {
#         display: block; } }
# .header__navbar--navigation[_ngcontent-sc5]   .button--navigation[_ngcontent-sc5] {
#       padding: 0;
#       color: #525c65; }
# .header__navbar--navigation[_ngcontent-sc5]   .button--navigation[_ngcontent-sc5]:hover {
#         color: #474f57; }
# .header__navbar--navigation[_ngcontent-sc5]   .button--primary[_ngcontent-sc5], .header__navbar--navigation[_ngcontent-sc5]   .button--turquoise[_ngcontent-sc5] {
#       width: 7.75rem;
#       box-shadow: 8px 10px 20px 0px rgba(46, 61, 73, 0.15);
#       background-color: #02b3e4; }
# .header__navbar--navigation[_ngcontent-sc5]   .button--primary[_ngcontent-sc5]:hover, .header__navbar--navigation[_ngcontent-sc5]   .button--turquoise[_ngcontent-sc5]:hover {
#         box-shadow: 2px 4px 8px 0px rgba(46, 61, 73, 0.2);
#         background-color: #02b7e9; }
# .header__navbar--navigation[_ngcontent-sc5]   .button--turquoise[_ngcontent-sc5] {
#       background-color: #02ccba; }
# .header__navbar--navigation[_ngcontent-sc5]   .button--turquoise[_ngcontent-sc5]:hover {
#         background-color: #02d1bf; }
# .header__navbar--navigation[_ngcontent-sc5]   .button--guest[_ngcontent-sc5], .header__navbar--navigation[_ngcontent-sc5]   .button--student[_ngcontent-sc5] {
#       display: none; }
# .header__navbar--navigation[_ngcontent-sc5]   .divider[_ngcontent-sc5] {
#     cursor: default; }
# .header__navbar--navigation[_ngcontent-sc5]   .divider[_ngcontent-sc5]::before {
#       content: '';
#       border-left: 1px solid rgba(82, 92, 101, 0.4);
#       width: 0px;
#       height: 12px; }
# .header__sidenav[_ngcontent-sc5] {
#     background-color: #2e3d49; }
# .header__sidenav--logo[_ngcontent-sc5] {
#       height: 4.5rem;
#       display: block;
#       background-color: #1C262F; }
# .header__sidenav--logo[_ngcontent-sc5]::after {
#         clear: both;
#         content: "";
#         display: table; }
# .header__sidenav--logo[_ngcontent-sc5]   .logo-link[_ngcontent-sc5] {
#         display: block;
#         width: 100%;
#         height: 100%; }
# .header__sidenav--logo[_ngcontent-sc5]   .logo-link[_ngcontent-sc5]   .logo-wordmark[_ngcontent-sc5], .header__sidenav--logo[_ngcontent-sc5]   .logo-link[_ngcontent-sc5]   .logo-wordmark--cn[_ngcontent-sc5] {
#           position: relative;
#           top: 50%;
#           -webkit-transform: translateY(-50%);
#           transform: translateY(-50%);
#           padding-left: 1.5em;
#           width: 11.25rem;
#           height: 1.875rem; }
# .header__sidenav--logo[_ngcontent-sc5]   .logo-link[_ngcontent-sc5]   #wordmark[_ngcontent-sc5] {
#           fill: #fff; }
# .header__sidenav--navigation[_ngcontent-sc5] {
#       display: block; }
# .header__sidenav--navigation[_ngcontent-sc5]::after {
#         clear: both;
#         content: "";
#         display: table; }
# .header__sidenav--navigation[_ngcontent-sc5]   li[_ngcontent-sc5] {
#         height: 4.5rem; }
# .header__sidenav--navigation[_ngcontent-sc5]   a[_ngcontent-sc5] {
#         padding-top: 1.5rem;
#         padding-bottom: 1.5rem;
#         color: #fff;
#         display: block;
#         padding-left: 1.5em; }
# @media screen and (min-width: 48rem) {
#           .header__sidenav--navigation[_ngcontent-sc5]   a[_ngcontent-sc5] {
#             padding-top: 1.5rem;
#             padding-bottom: 1.5rem; } }
# .header__sidenav--navigation[_ngcontent-sc5]   a[_ngcontent-sc5]:hover {
#           color: #cccccc; }
# .header__sidenav--navigation[_ngcontent-sc5]   .guest[_ngcontent-sc5], .header__sidenav--navigation[_ngcontent-sc5]   .student[_ngcontent-sc5] {
#         display: none; }
# .header__sidenav--navigation[_ngcontent-sc5]   .guest[_ngcontent-sc5]   a[_ngcontent-sc5], .header__sidenav--navigation[_ngcontent-sc5]   .student[_ngcontent-sc5]   a[_ngcontent-sc5] {
#           color: #02b3e4; }
# .header__sidenav--navigation[_ngcontent-sc5]   .guest[_ngcontent-sc5]   a[_ngcontent-sc5]:hover, .header__sidenav--navigation[_ngcontent-sc5]   .student[_ngcontent-sc5]   a[_ngcontent-sc5]:hover {
#             color: #01647f; }
# html[_ngcontent-sc5] {
#   box-sizing: border-box; }
# *[_ngcontent-sc5], *[_ngcontent-sc5]::after, *[_ngcontent-sc5]::before {
#   box-sizing: inherit; }
#
# html.wf-loading[_ngcontent-sc5]   .tk-font[_ngcontent-sc5] {
#   visibility: hidden; }
# html.wf-active[_ngcontent-sc5]   .tk-font[_ngcontent-sc5] {
#   visibility: initial; }
#
# .tk-font-balboa[_ngcontent-sc5] {
#   font-family: balboa, 'Open Sans', sans-serif; }
# .tk-font-balboa-condensed[_ngcontent-sc5] {
#   font-family: balboa-extra-condensed, 'Open Sans', sans-serif; }
# [_nghost-sc5] {
#   display: block;
#   z-index: 1;
#   position: relative; }
# header[_ngcontent-sc5]   .header__navbar--navigation[_ngcontent-sc5] {
#   float: right; }
# @-webkit-keyframes sticky-slide-down {
#   100% {
#     -webkit-transform: translateY(0);
#             transform: translateY(0); } }
# @keyframes sticky-slide-down {
#   100% {
#     -webkit-transform: translateY(0);
#             transform: translateY(0); } }
# ...
#       height: 10.625rem;
#       margin: 0 auto 1rem;
#       float: left;
#       display: block;
#       margin-right: 1.69491525%;
#       width: 100%; }
# .card__inner[_ngcontent-sc268]   .image_wrapper[_ngcontent-sc268]   .image-placeholder[_ngcontent-sc268]:last-child {
#         margin-right: 0; }
# .card__inner[_ngcontent-sc268]   .image_wrapper[_ngcontent-sc268]   .image-placeholder[_ngcontent-sc268]   span[_ngcontent-sc268] {
#         text-align: center; }
# @media screen and (min-width: 48rem) {
#         .card__inner[_ngcontent-sc268]   .image_wrapper[_ngcontent-sc268]   .image-placeholder[_ngcontent-sc268] {
#           height: 6.5rem; } }
# .card-wrapper[_ngcontent-sc268]   .card__expander[_ngcontent-sc268] {
#   transition: max-height 0.5s ease-in-out;
#   background-color: white;
#   box-shadow: 5px 5px 25px 0px rgba(46, 61, 73, 0.2);
#   border-radius: 0 0 0.375rem 0.375rem; }
# .card-wrapper.is-collapsed[_ngcontent-sc268]   .card__expander[_ngcontent-sc268] {
#   overflow: hidden;
#   width: 100%;
#   max-height: 0; }
# .card-wrapper.is-expanded[_ngcontent-sc268]   .card__expander[_ngcontent-sc268] {
#   overflow: hidden;
#   width: 100%;
#   max-height: 20rem; }
# .card-wrapper.is-expanded[_ngcontent-sc268]   .card__inner[_ngcontent-sc268] {
#   border-bottom-left-radius: 0;
#   border-bottom-right-radius: 0; }
# .card-wrapper[_ngcontent-sc268]   hr[_ngcontent-sc268] {
#   border-top: 1px solid #dbe2e8;
#   margin: 1.5rem 4rem; }
# .card[_ngcontent-sc268]   .category[_ngcontent-sc268] {
#   margin-top: 0;
#   font-weight: 600;
#   font-size: 0.75rem;
#   line-height: 1.5rem;
#   color: #7D97AD;
#   text-transform: none;
#   display: inline-block; }
# @media screen and (min-width: 48rem) {
#     .card[_ngcontent-sc268]   .category[_ngcontent-sc268] {
#       font-size: 0.75rem;
#       line-height: 1.5rem; } }
# @media screen and (min-width: 48rem) {
#     .card[_ngcontent-sc268]   .category[_ngcontent-sc268] {
#       font-size: 0.8125rem;
#       line-height: 1.5rem; } }
# @media screen and (min-width: 48rem) and (min-width: 48rem) {
#     .card[_ngcontent-sc268]   .category[_ngcontent-sc268] {
#       font-size: 0.8125rem;
#       line-height: 1.5rem; } }
# .card-heading[_ngcontent-sc268] {
#   margin-top: 0;
#   margin-bottom: 0.5rem; }
# .card-heading[_ngcontent-sc268]   a[_ngcontent-sc268] {
#     color: #2e3d49;
#     font-weight: 600;
#     display: block;
#     overflow: hidden;
#     text-overflow: ellipsis;
#     line-height: 1.6rem;
#     max-height: 4.8rem; }
# .card-heading[_ngcontent-sc268]   a[_ngcontent-sc268]:hover {
#       color: #02b3e4; }
# .card-content[_ngcontent-sc268] {
#   float: left;
#   display: block;
#   margin-right: 1.69491525%;
#   width: 74.57627119%; }
# .card-content[_ngcontent-sc268]:last-child {
#     margin-right: 0; }
# @media (max-width: 62rem) {
#     .card-content[_ngcontent-sc268] {
#       float: left;
#       display: block;
#       margin-right: 1.69491525%;
#       width: 100%; }
#       .card-content[_ngcontent-sc268]:last-child {
#         margin-right: 0; } }
# .card__expander[_ngcontent-sc268] {
#   background: linear-gradient(to top left, #F7F7F7, #EAFBFF); }
# .card__expander--summary[_ngcontent-sc268] {
#     font-size: 0.9rem;
#     padding: 1.5rem 4rem 0; }
# .card__expander--details[_ngcontent-sc268] {
#     float: left;
#     display: block;
#     margin-right: 1.69491525%;
#     width: 100%;
#     display: flex;
#     justify-content: space-between;
#     padding: 0 4rem 1.5rem; }
# .card__expander--details[_ngcontent-sc268]:last-child {
#       margin-right: 0; }
# .card__expander--details[_ngcontent-sc268]   .btn[_ngcontent-sc268] {
#       width: 10rem;
#       height: 2.5rem;
#       line-height: 2.3rem;
#       color: #fff;
#       background-color: #02b3e4; }
# .card[_ngcontent-sc268]   .right-sub[_ngcontent-sc268] {
#   display: flex; }
# .card[_ngcontent-sc268]   .right-sub[_ngcontent-sc268]   h4[_ngcontent-sc268] {
#     font-size: 0.9rem;
#     text-transform: capitalize;
#     margin-top: 0; }
# .card[_ngcontent-sc268]   .right-sub[_ngcontent-sc268]   div[_ngcontent-sc268] {
#     float: left;
#     display: block;
#     margin-right: 1.69491525%;
#     width: 49.15254237%; }
# .card[_ngcontent-sc268]   .right-sub[_ngcontent-sc268]   div[_ngcontent-sc268]:last-child {
#       margin-right: 0; }
# .card[_ngcontent-sc268]   .right-sub[_ngcontent-sc268]   span[_ngcontent-sc268] {
#     font-size: 0.875rem;
#     color: #2e3d49; }
# .card[_ngcontent-sc268]   .right-sub[_ngcontent-sc268]   span.truncate-content[_ngcontent-sc268] {
#       max-height: 3rem;
#       display: block;
#       overflow-y: hidden; }
# .card[_ngcontent-sc268]   .right-sub[_ngcontent-sc268]   .level[_ngcontent-sc268]   span[_ngcontent-sc268]:after {
#     content: '' !important; }
# .card[_ngcontent-sc268]   .right-sub[_ngcontent-sc268]   .skills[_ngcontent-sc268]    ~ .level[_ngcontent-sc268] {
#     margin-top: 1.4rem; }
# .card[_ngcontent-sc268]   h4[_ngcontent-sc268] {
#   margin-bottom: 0; }
# @media (max-width: 48rem) {
#   .card[_ngcontent-sc268]   .mobile-icon[_ngcontent-sc268] {
#     display: inline-block;
#     height: 0.8rem;
#     width: 1.5rem;
#     margin-right: 0.2rem;
#     background-image: url("/assets/iridium/images/course-catalog/course-icon-mobile.svg");
#     background-position: center;
#     background-size: contain;
#     background-repeat: no-repeat;
#     vertical-align: middle; } }
# .pointer[_ngcontent-sc268] {
#   cursor: pointer; }
# .course-level[_ngcontent-sc268] {
#   width: 0.8rem;
#   height: 0.8rem;
#   background-size: contain;
#   display: inline-block;
#   vertical-align: middle;
#   background-repeat: no-repeat;
#   margin-right: 0.5rem; }
# .course-level-advanced[_ngcontent-sc268] {
#     background-image: url("/assets/iridium/images/svgs/advanced.svg"); }
# .course-level-intermediate[_ngcontent-sc268] {
#     background-image: url("/assets/iridium/images/svgs/intermediate.svg"); }
# .course-level-beginner[_ngcontent-sc268] {
#     background-image: url("/assets/iridium/images/svgs/beginner.svg"); }
# .nanodegree-card[_nghost-sc268]   .image-overlay[_ngcontent-sc268], .nanodegree-card   [_nghost-sc268]   .image-overlay[_ngcontent-sc268] {
#   position: absolute;
#   float: left;
#   display: block;
#   margin-right: 1.69491525%;
#   width: 100%;
#   height: 100%;
#   background-image: url("/assets/iridium/images/course-catalog/nanodegree-icon.png");
#   background-repeat: no-repeat;
#   background-position: 0.5rem 0.5rem; }
# .nanodegree-card[_nghost-sc268]   .image-overlay[_ngcontent-sc268]:last-child, .nanodegree-card   [_nghost-sc268]   .image-overlay[_ngcontent-sc268]:last-child {
#     margin-right: 0; }
# @media (max-width: 48rem) {
#   .nanodegree-card[_nghost-sc268]   .mobile-icon[_ngcontent-sc268], .nanodegree-card   [_nghost-sc268]   .mobile-icon[_ngcontent-sc268] {
#     background-image: url("/assets/iridium/images/course-catalog/nanodegree-icon-mobile.svg"); } }
# .nanodegree-card[_nghost-sc268]:nth-child(3n+1)   .image-overlay[_ngcontent-sc268], .nanodegree-card:nth-child(3n+1)   [_nghost-sc268]   .image-overlay[_ngcontent-sc268] {
#   background-color: rgba(82, 92, 101, 0.6); }
# .nanodegree-card[_nghost-sc268]:nth-child(3n+2)   .image-overlay[_ngcontent-sc268], .nanodegree-card:nth-child(3n+2)   [_nghost-sc268]   .image-overlay[_ngcontent-sc268] {
#   background-color: rgba(255, 162, 52, 0.6); }
# .nanodegree-card[_nghost-sc268]:nth-child(3n+3)   .image-overlay[_ngcontent-sc268], .nanodegree-card:nth-child(3n+3)   [_nghost-sc268]   .image-overlay[_ngcontent-sc268] {
#   background-color: rgba(2, 204, 186, 0.6); }
# .tag[_ngcontent-sc268] {
#   float: right;
#   text-align: center;
#   font-size: 0.8125rem;
#   line-height: 1.5rem;
#   padding: 0.375rem 0.75rem;
#   letter-spacing: 0.125rem;
#   border-radius: 0.25rem;
#   text-transform: uppercase;
#   font-weight: 600; }
# @media screen and (min-width: 48rem) {
#     .tag[_ngcontent-sc268] {
#       font-size: 0.8125rem;
#       line-height: 1.5rem; } }
# @media screen and (max-width: 20rem) {
#     .tag[_ngcontent-sc268] {
#       background: none;
#       box-shadow: none;
#       margin: 0; } }
# .tag--free[_ngcontent-sc268] {
#     color: #02ccba; }
# .tag--new[_ngcontent-sc268] {
#     color: #6854c5; }
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# prebootInitFn(); Free Courses  Nanodegree  Hire Talent  For Enterprise  Log In  Career Paths  Nanodegree  For Enterprise  Hire Talent  Career Paths  Log In  Your Gift Program CatalogSort by PopularSort by NewestFiltersFilter BySelect Program DetailsTypeNanodegreeFree CoursesSkill LevelBeginnerIntermediateAdvancedEstimated Duration<1 month1 - 3 months3+ monthsIndustry SkillsSkillsAI AlgorithmsAR developmentARKitAlteryxAndroid DevelopmentBlueprint programmingC++Career AdvancementCSSControls and EstimationCore DataDeep LearningDesign SprintDigital MarketingDisplay AdsExcelFacebook MarketingGoogle VR SDK for UnityHTMLJava programmingJavaScriptJupyter NotebooksKalman FiltersMachine LearningMobile Web AppsNetworkingNeural NetworksOffline Capable Web AppsOptimizationPredictive ModelingProbabilityPrototypingPythonReactReact NativeReduxRobot Operating SystemRoboticsSQLSearch AdsSearch AlgorithmsSelf-Driving CarsSocial Media MarketingStatisticsSupervised LearningSwift programmingTableauUIKitUnityUnity ARKit PluginUnrealUnsupervised LearningUser testingVR developmentWeb Tooling and AutomationYouTube MarketingFilter BySelect Program DetailsTypeNanodegreeFree CoursesSkill LevelBeginnerIntermediateAdvancedEstimated Duration<1 month1 - 3 months3+ monthsIndustry SkillsSkillsAI AlgorithmsAR developmentARKitAlteryxAndroid DevelopmentBlueprint programmingC++Career AdvancementCSSControls and EstimationCore DataDeep LearningDesign SprintDigital MarketingDisplay AdsExcelFacebook MarketingGoogle VR SDK for UnityHTMLJava programmingJavaScriptJupyter NotebooksKalman FiltersMachine LearningMobile Web AppsNetworkingNeural NetworksOffline Capable Web AppsOptimizationPredictive ModelingProbabilityPrototypingPythonReactReact NativeReduxRobot Operating SystemRoboticsSQLSearch AdsSearch AlgorithmsSelf-Driving CarsSocial Media MarketingStatisticsSupervised LearningSwift programmingTableauUIKitUnityUnity ARKit PluginUnrealUnsupervised LearningUser testingVR developmentWeb Tooling and AutomationYouTube MarketingAll SchoolsArtificial IntelligenceArtificial IntelligenceDeep LearningDeep Reinforcement LearningMachine LearningComputer VisionAI Programming with PythonNatural Language ProcessingArtificial Intelligence for TradingData ScienceData AnalystData FoundationsData ScientistData EngineerBusiness AnalystProgramming and DevelopmentAndroid DeveloperAndroid BasicsBlockchainIntro To ProgrammingData Structures and AlgorithmsData EngineerFront End DeveloperFull Stack DeveloperPython ProgrammingAI Programming with PythonMobile Web SpecialistReactVirtual RealityUnrealARKitIOTiOSAutonomous SystemsFlying CarRoboticsIntro to Self Driving CarSelf Driving CarBusinessMarketing AnalyticsDigital MarketingGoogle AdsGoogle AnalyticsDesign SprintData FoundationsBusiness AnalystCareerApplying to JobsInterviewingSchoolAll SchoolsArtificial IntelligenceArtificial IntelligenceDeep LearningDeep Reinforcement LearningMachine LearningComputer VisionAI Programming with PythonNatural Language ProcessingArtificial Intelligence for TradingData ScienceData AnalystData FoundationsData ScientistData EngineerBusiness AnalystProgramming and DevelopmentAndroid DeveloperAndroid BasicsBlockchainIntro To ProgrammingData Structures and AlgorithmsData EngineerFront End DeveloperFull Stack DeveloperPython ProgrammingAI Programming with PythonMobile Web SpecialistReactVirtual RealityUnrealARKitIOTiOSAutonomous SystemsFlying CarRoboticsIntro to Self Driving CarSelf Driving CarBusinessMarketing AnalyticsDigital MarketingGoogle AdsGoogle AnalyticsDesign SprintData FoundationsBusiness AnalystCareerApplying to JobsInterviewingApply FiltersNew School of Programming Data Structures and AlgorithmsSkills CoveredData Structures and Algorithms, Problem Solving, Interview Practice Problems, PythonintermediateNanodegree DetailsintermediateGet hands-on practice with over 100 data structures and algorithm exercises and guidance from a dedicated mentor to help prepare you for interviews and on-the-job scenarios.Learn  ...
#
# {&q;/courses/all?udacityAgentHeader=Iridium-Circle-Build-1d9c7@CACHE_LOCALIZED_DATA-catalogFilters&a;locale=en-IN&q;:[{&q;section&q;:&q;Type&q;,&q;values&q;:[{&q;title&q;:&q;Nanodegree&q;,&q;propertyPath&q;:&q;slug&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;--nd&q;}},{&q;title&q;:&q;Free Courses&q;,&q;propertyPath&q;:&q;slug&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;notWithKey&q;:&q;--nd&q;}}]},{&q;section&q;:&q;Skill Level&q;,&q;values&q;:[{&q;title&q;:&q;Beginner&q;,&q;propertyPath&q;:&q;level&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;beginner&q;}},{&q;title&q;:&q;Intermediate&q;,&q;propertyPath&q;:&q;level&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;intermediate&q;}},{&q;title&q;:&q;Advanced&q;,&q;propertyPath&q;:&q;level&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;advanced&q;}}]},{&q;section&q;:&q;Estimated Duration&q;,&q;values&q;:[{&q;title&q;:&q;&l;1 month&q;,&q;propertyPath&q;:&q;metadata.expected_duration_in_months&q;,&q;type&q;:&q;range&q;,&q;matchCriteria&q;:{&q;rangeMin&q;:0,&q;rangeMinInclusive&q;:true,&q;rangeMax&q;:1,&q;rangeMaxInclusive&q;:false}},{&q;title&q;:&q;1 - 3 months&q;,&q;propertyPath&q;:&q;metadata.expected_duration_in_months&q;,&q;type&q;:&q;range&q;,&q;matchCriteria&q;:{&q;rangeMin&q;:1,&q;rangeMinInclusive&q;:true,&q;rangeMax&q;:3,&q;rangeMaxInclusive&q;:true}},{&q;title&q;:&q;3+ months&q;,&q;propertyPath&q;:&q;metadata.expected_duration_in_months&q;,&q;type&q;:&q;range&q;,&q;matchCriteria&q;:{&q;rangeMin&q;:3,&q;rangeMinInclusive&q;:true}}]}],&q;/courses/all?udacityAgentHeader=Iridium-Circle-Build-1d9c7@CACHE_LOCALIZED_DATA-skillFilters&a;locale=en-IN&q;:[{&q;section&q;:&q;Skills&q;,&q;values&q;:[{&q;title&q;:&q;AI Algorithms&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;AI Algorithms&q;}},{&q;title&q;:&q;AR development&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;AR development&q;}},{&q;title&q;:&q;ARKit&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;ARKit&q;}},{&q;title&q;:&q;Alteryx&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Alteryx&q;}},{&q;title&q;:&q;Android Development&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Android Development&q;}},{&q;title&q;:&q;Blueprint programming&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Blueprint programming&q;}},{&q;title&q;:&q;C++&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;C++&q;}},{&q;title&q;:&q;Career Advancement&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Career Advancement&q;}},{&q;title&q;:&q;CSS&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;CSS&q;}},{&q;title&q;:&q;Controls and Estimation&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Controls and Estimation&q;}},{&q;title&q;:&q;Core Data&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Core Data&q;}},{&q;title&q;:&q;Deep Learning&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Deep Learning&q;}},{&q;title&q;:&q;Design Sprint&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Design Sprint&q;}},{&q;title&q;:&q;Digital Marketing&q;,&q;propertyPath&q;:&q;metadata.skills&q;,&q;type&q;:&q;category&q;,&q;matchCriteria&q;:{&q;withKey&q;:&q;Digital Marketing&q;}},{&q;title&q;:&q;Display Ads&q;,&q;propertyPath&q; ...

# %% [markdown]
# ### Step 3: Find all course summaries
# Use the BeautifulSoup's `find_all` method to select based on tag type and class name. Just ike in the video, you can right click on the item, and click "Inspect" to view its html on a web page.

# %%
# Find all course summaries
summaries = soup.find_all("div", class_="course-summary-card")
print('Number of Courses:', len(summaries))
# Out:
# Number of Courses: 227

# %% [markdown]
# ### Step 4: Inspect the first summary to find selectors for the course name and school
# Tip: `.prettify()` is a super helpful method BeautifulSoup provides to output html in a nicely indented form! Make sure to use `print()` to ensure whitespace is displayed properly.

# %%
# print the first summary in summaries
print(summaries[0].prettify())
# Out:
# <div _ngcontent-sc265="" class="course-summary-card row row-gap-medium catalog-card nanodegree-card ng-star-inserted">
#  <ir-catalog-card _ngcontent-sc265="" _nghost-sc268="">
#   <div _ngcontent-sc268="" class="card-wrapper is-collapsed">
#    <div _ngcontent-sc268="" class="card__inner card mb-0">
#     <div _ngcontent-sc268="" class="card__inner--upper">
#      <div _ngcontent-sc268="" class="image_wrapper hidden-md-down">
#       <a _ngcontent-sc268="" href="/course/data-structures-and-algorithms-nanodegree--nd256">
#        <!-- -->
#        <div _ngcontent-sc268="" class="image-container ng-star-inserted" style="background-image:url(https://d20vrrgs8k4bvw.cloudfront.net/images/degrees/nd256/nd-card.jpg);">
#         <div _ngcontent-sc268="" class="image-overlay">
#         </div>
#        </div>
#       </a>
#       <!-- -->
#      </div>
#      <div _ngcontent-sc268="" class="card-content">
#       <!-- -->
#       <span _ngcontent-sc268="" class="tag tag--new card ng-star-inserted">
#        New
#       </span>
#       <!-- -->
#       <div _ngcontent-sc268="" class="category-wrapper">
#        <span _ngcontent-sc268="" class="mobile-icon">
#        </span>
#        <!-- -->
#        <h4 _ngcontent-sc268="" class="category ng-star-inserted">
#         School of Programming
#        </h4>
#       </div>
#       <h3 _ngcontent-sc268="" class="card-heading">
#        <a _ngcontent-sc268="" class="capitalize" href="/course/data-structures-and-algorithms-nanodegree--nd256">
#         Data Structures and Algorithms
#        </a>
#       </h3>
#       <div _ngcontent-sc268="" class="right-sub">
#        <!-- -->
#        <div _ngcontent-sc268="" class="skills ng-star-inserted">
#         <h4 _ngcontent-sc268="">
#          Skills Covered
#         </h4>
#         <span _ngcontent-sc268="" class="truncate-content">
#          <!-- -->
#          <span _ngcontent-sc268="" class="ng-star-inserted">
#           Data Structures and Algorithms,
#          </span>
#          <span _ngcontent-sc268="" class="ng-star-inserted">
#           Problem Solving,
#          </span>
#          <span _ngcontent-sc268="" class="ng-star-inserted">
#           Interview Practice Problems,
#          </span>
#          <span _ngcontent-sc268="" class="ng-star-inserted">
#           Python
#          </span>
#         </span>
#        </div>
#        <!-- -->
#        <div _ngcontent-sc268="" class="hidden-md-up level">
#         <span _ngcontent-sc268="" class="course-level course-level-intermediate" classname="course-level course-level-intermediate">
#         </span>
#         <span _ngcontent-sc268="" class="capitalize">
#          intermediate
#         </span>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div _ngcontent-sc268="" class="card__inner--lower hidden-sm-down">
#      <div _ngcontent-sc268="" class="left uppercase blue expander pointer">
#       <!-- -->
#       <span _ngcontent-sc268="" class="ng-star-inserted">
#        Nanodegree Details
#       </span>
#       <!-- -->
#      </div>
#      <div _ngcontent-sc268="" class="right">
#       <!-- -->
#       <span _ngcontent-sc268="" class="caption text-right level ng-star-inserted">
#        <span _ngcontent-sc268="" class="course-level course-level-intermediate" classname="course-level course-level-intermediate">
#        </span>
#        <span _ngcontent-sc268="" class="capitalize">
#         intermediate
#        </span>
#       </span>
#      </div>
#     </div>
#    </div>
#    <div _ngcontent-sc268="" class="card__expander">
#     <div _ngcontent-sc268="" class="card__expander--summary mb-1">
#      <!-- -->
#      <span _ngcontent-sc268="" class="ng-star-inserted">
#       Get hands-on practice with over 100 data structures and algorithm exercises and guidance from a dedicated mentor to help prepare you for interviews and on-the-job scenarios.
#      </span>
#     </div>
#     <hr _ngcontent-sc268=""/>
#     <div _ngcontent-sc268="" class="card__expander--details">
#      <div _ngcontent-sc268="" class="rating">
#       <!-- -->
#      </div>
#      <a _ngcontent-sc268="" class="button--primary btn" href="/course/data-structures-and-algorithms-nanodegree--nd256">
#       Learn More
#      </a>
#     </div>
#    </div>
#   </div>
#  </ir-catalog-card>
# </div>

# %% [markdown]
# Look for selectors that contain the courses title and school name text you want to extract. Then, use the `select_one` method on the summary object to pull out the html with those selectors. Afterwards, don't forget to do some extra cleaning to isolate the names (get rid of unnecessary html), as you saw in the last video.

# %%
# Extract course title
summaries[0].select_one("div").get_text().strip()
# Out:
# 'New School of Programming Data Structures and AlgorithmsSkills CoveredData Structures and Algorithms, Problem Solving, Interview Practice Problems, PythonintermediateNanodegree DetailsintermediateGet hands-on practice with over 100 data structures and algorithm exercises and guidance from a dedicated mentor to help prepare you for interviews and on-the-job scenarios.Learn More'

# %%
# Extract school
summaries[0].select_one("h4").get_text().strip()
# Out:
# 'School of Programming'

# %% [markdown]
# ### Step 5: Collect names and schools of ALL course listings
# Reuse your code from the previous step, but now in a loop to extract the name and school from every course summary in `summaries`!

# %%
courses = []
for summary in summaries:
    # append name and school of each summary to courses list
    courses.append([summary.select_one("div").get_text().strip(), summary.select_one("h4").get_text().strip()])
    
courses
# Out:
# [['New School of Programming Data Structures and AlgorithmsSkills CoveredData Structures and Algorithms, Problem Solving, Interview Practice Problems, PythonintermediateNanodegree DetailsintermediateGet hands-on practice with over 100 data structures and algorithm exercises and guidance from a dedicated mentor to help prepare you for interviews and on-the-job scenarios.Learn More',
#   'School of Programming'],
#  ['New School of Programming VR FoundationsSkills CoveredUnity, VR Principles, Major VR Platforms, VR Scenes and Objects, Programming AnimationsCollaboration WithUnitybeginnerNanodegree DetailsbeginnerLearn the Unity game engine, C#, and Google Cardboard, and gain foundational VR knowledge and skills.Learn More',
#   'School of Programming'],
#  ['New School of Programming VR Mobile 360Skills CoveredUnity, VR Design Principles, VR Platforms and Applications, Mobile Performance, 360 Media ProductionCollaboration WithUnityintermediateNanodegree DetailsintermediateCombine a specific focus on Mobile 360 Media with learning core Unity game engine and C# skills, and advance your VR expertiseLearn More',
#   'School of Programming'],
#  ['New School of Programming VR High-ImmersionSkills CoveredUnity, VR Design Principles, VR Platforms and Applications, High-Immersion, Performance BouncebackCollaboration WithUnityintermediateNanodegree DetailsintermediateLearn the advanced tools and techniques required for creating high-immersion VR experiences, as you build upon your Unity Game Engine and C# skills.Learn More',
#   'School of Programming'],
#  ['New School Of Business Google AnalyticsCollaboration WithGoogle, E-NorintermediateNanodegree DetailsintermediateAdvance your marketing or data analytics career. Unlike other online programs, our curriculum is shaped by Google’s Google Analytics education experts and provides students with an in-depth Google Analytics education using real-world projects and real data. Learn More',
#   'School Of Business'],
#  ['New School of AI Artificial Intelligence for TradingCollaboration WithWorldQuantintermediateNanodegree DetailsintermediateComplete real-world projects designed by industry experts, covering topics from asset management to trading signal generation. Master AI algorithms for trading, and build your career-ready portfolio.Learn More',
#   'School of AI'],
#  ['School of Programming Python FoundationSkills CoveredProgramming, pandas, NumPyintermediateNanodegree DetailsintermediateLearn how to program in Python and get ready for a career in data science, machine learning, deep learning, and artificial intelligence.Learn More',
#   'School of Programming'],
#  ['School of Data Science Data AnalystSkills CoveredPython, SQL, Statistics, Data Wrangling, Data VisualizationCollaboration WithKaggle, ModeintermediateNanodegree DetailsintermediateLearn to clean up messy data, uncover patterns and insights, make predictions using machine learning, and clearly communicate your findings.Learn More',
#   'School of Data Science'],
#  ['School of AI Machine Learning FoundationSkills CoveredIntroduction to Programming, Descriptive Statistics, Linear Algebra, Inferential Statistics, Evaluation and VerificationCollaboration WithkagglebeginnerNanodegree DetailsbeginnerLearn Python, Statistics and Linear Algebra to get your foundations right and ready for the advanced Machine Learning Engineer Nanodegree Program.Learn More',
#   'School of AI'],
#  ['School of AI AI Programming with PythonbeginnerNanodegree DetailsbeginnerLearn Python, NumPy, Pandas, Matplotlib, PyTorch, Calculus, and Linear Algebra—the foundations for building your own neural network.Learn More',
#   'School of AI'],
#  ['School of Programming Become an Android DeveloperSkills CoveredAndroid Development, Databases, Android Networking Libraries, Crash Analysis, Multilingual Support, Android Libraries, Gradle, APIsCollaboration WithGoogleintermediateNanodegree DetailsintermediateStart your career as an Android developer. Learn best practices for mobile development, build a portfolio of apps, and publish your own app to Google Play.Learn More',
#   'School of Programming'],
#  ['School of Programming Become a Professional Full Stack DeveloperSkills CoveredPython, JavaScript, SQL, HTML5 & CSS3, Python, Databases, Authentication & Authorization, AJAX & APIs, Configuration of Servers, Linux BasicsCollaboration WithGoogle, Amazon Web Services, GitHub, AT&TintermediateNanodegree DetailsintermediateIn this program, you’ll prepare for a job as a Full Stack Web Developer, and learn to create complex server-side web applications that use powerful relational databases to persistently store data.Learn More',
#   'School of Programming'],
#  ['New School of Data Science Become a Data ScientistCollaboration WithBertelsmann, Figure Eight, IBM Watson, Insight, Kaggle, StarbucksadvancedNanodegree DetailsadvancedWork on real-world data science projects designed by industry leaders. Enjoy support from mentors. Build your portfolio, and advance your data science career.Learn More',
#   'School of Data Science'],
#  ['School of Programming Android Basics by GoogleSkills CoveredAndroid Development, Java programming, Android Studio, XML layouts, Android ViewsCollaboration WithGooglebeginnerNanodegree DetailsbeginnerNo programming experience? No Problem! Start developing Android apps today.Learn More',
#   'School of Programming'],
#  ['School of AI Artificial IntelligenceSkills CoveredAI Algorithms, Search Algorithms, Optimization, Planning, Pattern RecognitionadvancedNanodegree DetailsadvancedLearn essential Artificial Intelligence concepts from AI experts like Peter Norvig and Sebastian Thrun, including search, optimization, planning, pattern recognition, and more.Learn More',
#   'School of AI'],
#  ['School of Programming IoT Software FoundationSkills CoveredPython programming, Backend Databases and Applications, C++ Basics, Performance Programming in C++, Hadoop and Mapreduce, Sensors and Controls, Natural Language Processing, Voice User InterfacesbeginnerNanodegree DetailsbeginnerBuild the future of smart living. Learn how to independently design, code, and build IOT products.Learn More',
#   'School of Programming'],
#  ['School of Programming Become a Front End DeveloperSkills CoveredJavaScript, jQuery, HTML5, HTML, CSS, Python, Object-Oriented ProgrammingCollaboration WithAT&T, Google, GithubintermediateNanodegree DetailsintermediateIn the Front End Developer Nanodegree program, you will complete five projects and build a resume-worthy portfolio.Learn More',
#   'School of Programming'],
#  ["School of Programming Learn to CodeSkills CoveredIntroduction to Programming, HTML, CSS, PythonbeginnerNanodegree DetailsbeginnerUdacity's Intro to Programming is your first step towards careers in Web and App Development, Machine Learning, Data Science, AI, and more! This program is perfect for beginners.Learn More",
#   'School of Programming'],
#  ['School Of Business Digital MarketingSkills CoveredDigital Marketing, Social Media Marketing, Facebook Marketing, Search Engine Optimization, Search Engine MarketingCollaboration WithFacebook Blueprint, Google, Hootsuite, HubSpot, MailChimp, MozbeginnerNanodegree DetailsbeginnerGain real-world experience running live campaigns as you learn from top experts in the field. Launch your career with a 360-degree understanding of digital marketing.Learn More',
#   'School Of Business'],
#  ['New School Of Autonomous Systems Robotics Software EngineerSkills CoveredC++, ROS, Localization, Mapping, SLAM, Navigation, Path PlanningadvancedNanodegree DetailsadvancedBuild five hands-on projects to acquire core robotics software engineering skills: ROS, Gazebo, Localization, Mapping, SLAM, Navigation, and Path Planning.Learn More',
#   'School Of Autonomous Systems'],
#  ['School of AI Computer VisionCollaboration WithAffectiva, Nvidia DLIadvancedNanodegree DetailsadvancedMaster the computer vision skills behind advances in robotics and automation. Write programs to analyze images, implement feature extraction, and recognize objects using deep learning models.Learn More',
#   'School of AI'],
#  ['School Of Autonomous Systems Intro to Self-Driving Cars NanodegreeSkills CoveredStatistics, Linear Algebra, C++, Calculus and ControlsCollaboration WithLyft, Polysync, Roborace, VoyageintermediateNanodegree DetailsintermediateBuild a foundation of technical abilities and take the first steps to becoming a self-driving car engineer!Learn More',
#   'School Of Autonomous Systems'],
#  ['School Of Business Predictive Analytics for BusinessCollaboration WithAlteryx, TableauintermediateNanodegree DetailsintermediateLearn to apply predictive analytics and business intelligence to solve real-world business problemsLearn More',
#   'School Of Business'],
#  ['School of Programming Become a Professional React DeveloperSkills CoveredReact, Redux, React NativeintermediateNanodegree DetailsintermediateReact is completely transforming Front-End Development. Master this powerful UI library from Facebook with Udacity.Learn More',
#   'School of Programming'],
#  ['School Of Autonomous Systems Self Driving Car EngineerSkills CoveredComputer Vision, Deep Learning, Sensor Fusion, LocalizationCollaboration WithMercedes, Nvidia, Uber ATG, Didi, BMW, McLarenadvancedNanodegree DetailsadvancedSelf-driving cars are set to revolutionize the way we live. This is transformational technology, on the cutting-edge of robotics, machine learning, software engineering, and mechanical engineering. In this program, you’ll learn the skills and techniques used by self-driving car teams at the most advanced technology companies in the world.Learn More',
#   'School Of Autonomous Systems'],
#  ['School of AI Natural Language ProcessingCollaboration WithAmazon Alexa, IBM WatsonadvancedNanodegree DetailsadvancedMaster the skills to get computers to understand, process, and manipulate human language. Build models on real data, and get hands-on experience with sentiment analysis, machine translation, and more.Learn More',
#   'School of AI'],
#  ['School of Programming Become an iOS DeveloperSkills CoveredSwift programming, Core Data, UIKit, iOS networking, app publishing, User interfaces, Local Persistence, APIsCollaboration WithAT&T, Lyft, GoogleintermediateNanodegree DetailsintermediateMaster the Swift programming language, and create a portfolio of iOS apps for iPhone and iPad to showcase your skills!Learn More',
#   'School of Programming'],
#  ['School Of Autonomous Systems Flying Car and Autonomous Flight Engineer NanodegreeSkills Covered3D Motion Planning, Controls, Estimation, Kalman FiltersadvancedNanodegree DetailsadvancedMaster job-ready autonomous flight software engineering skills as you tackle advanced challenges, write real code for real aircraft, and develop a systems understanding of the Flying Car full-stack.Learn More',
#   'School Of Autonomous Systems'],
#  ["School of Programming Become a Mobile Web SpecialistSkills CoveredMobile Web Apps, Web Tooling and Automation, Offline Capable Web Apps, Performant Web Apps, Asynchronous JavaScript RequestsCollaboration WithGoogleadvancedNanodegree DetailsadvancedPrepare for Google's Mobile Web Specialist certification with courses from GoogleLearn More",
#   'School of Programming'],
#  ['School of AI Machine Learning EngineerSkills CoveredMachine Learning, Supervised Learning, Unsupervised Learning, Reinforcement Learning, Deep LearningCollaboration WithKaggle, AWSadvancedNanodegree DetailsadvancedIn this program you will master Supervised, Unsupervised, Reinforcement, and Deep Learning fundamentals. You will also complete a capstone project in your chosen domain.Learn More',
#   'School of AI'],
#  ['School Of Business Become a Google Ads expertSkills CoveredSearch Ads, Display Ads, YouTube Marketing, Google Shopping Campaigns, Google Ads RemarketingbeginnerNanodegree DetailsbeginnerIn this program, you’ll gain a 360-degree understanding of the new Google Ads as you run live campaigns with real budgets. Topics include: Search, Display, Video, App Advertising, and more.Learn More',
#   'School Of Business'],
#  ['School Of Business Design Sprint FoundationsSkills CoveredDesign Sprint, Prototyping, User testingbeginnerNanodegree DetailsbeginnerLearn to use the Design Sprint process to test ideas, leverage opportunities, and power innovation. With expert instruction and hands-on training, you’ll become an exceptional problem-solver.Learn More',
#   'School Of Business'],
#  ['New School of AI Deep Reinforcement LearningCollaboration WithUnity, Nvidia-deep-learning-instituteadvancedNanodegree DetailsadvancedMaster the deep reinforcement learning skills that are powering amazing advances in AI. Then start applying these to applications like video games and robotics.Learn More',
#   'School of AI'],
#  ['School of AI Deep LearningSkills CoveredDeep Learning, Neural Networks, Jupyter Notebooks, CNNs, GANsintermediateNanodegree DetailsintermediateDeep learning is driving advances in artificial intelligence that are changing our world. Enroll now to build and apply your own deep neural networks to produce amazing solutions to important challenges.Learn More',
#   'School of AI'],
#  ["Free School of Programming Developing Android AppsSkills CoveredAndroid Development, Layouts, Intents, UICollaboration WithGoogleintermediateCourse DetailsintermediateBuild a cloud-connected Android app, and learn the tools, principles, and best practices of mobile and Android development that you'll apply to your own projects.Learn More",
#   'School of Programming'],
#  ['Free School of Programming Android Basics: User InterfaceSkills CoveredAndroid Development, Building Layouts, Android Studio, Views and ViewGroups, StylingCollaboration WithGooglebeginnerCourse DetailsbeginnerLearn how to design your first layout in Android! This is the first course in the Android Basics Nanodegree program.Learn More',
#   'School of Programming'],
#  ["Free School of Programming Intro to Computer ScienceSkills CoveredPython, Managing Data, Responding to Queries, How programs runbeginnerCourse DetailsbeginnerLearn key computer science concepts in this introductory Python course. You'll learn by doing, and will build your own search engine and social network.Learn More",
#   'School of Programming'],
#  ['New Career Advancement Refresh Your ResumeSkills CoveredResume writing, Company targeting, Storytelling, Career AdvancementCollaboration WithGrow With GooglebeginnerCourse DetailsbeginnerCreate a targeted resume that gets the attention of recruiters and lands you an interview in tech.Learn More',
#   'Career Advancement'],
#  ["Free School of AI Deep LearningSkills CoveredNeural Networks, Convolutional Neural Networks, Computer Vision, Natural Language Processing, TensorFlowCollaboration WithGoogleintermediateCourse DetailsintermediateShow off what you've learned in your Nanodegree program with a project that definesLearn More",
#   'School of AI'],
#  ['Free School of Programming Intro to JavaScriptSkills CoveredJavaScript, Conditionals, Loops, Data Types & VariablesbeginnerCourse DetailsbeginnerLearn the fundamentals of JavaScript, the most popular programming language in web development.Learn More',
#   'School of Programming'],
#  ['New Career Advancement Data Structures & Algorithms in SwiftSkills CoveredInterview practice, Swift, Data structures, Career AdvancementintermediateCourse DetailsintermediateReview and practice the skills technical interviewers expect you to know and learn how to explain your Swift solutions.Learn More',
#   'Career Advancement'],
#  ["Free School of AI Intro to Machine LearningSkills CoveredMachine Learning, Supervised Learning, Unsupervised Learning, Evaluation Metrics, Data ManipulationintermediateCourse DetailsintermediateThis class will teach you the end-to-end process of investigating data through a machine learning lens, and you'll apply what you've learned to a real-world data set.Learn More",
#   'School of AI'],
#  ["Free School of Programming Intro to HTML and CSSSkills CoveredHTML, CSS, CSS Syntax, HTML Syntax Problem SetbeginnerCourse DetailsbeginnerIn this course, you'll learn the fundamentals web development, along with best practices and professional problem-solving techniques using Developer Tools.Learn More",
#   'School of Programming'],
#  ['Free School of Programming Java Programming BasicsSkills CoveredJava Programming, Java Syntax, Java Functions, LoopsbeginnerCourse DetailsbeginnerTake your first steps towards becoming a Java developer! Learn Java syntax and create conditional statements, loops, and functions.Learn More',
#   'School of Programming'],
#  ['New Career Advancement Strengthen Your LinkedIn Network & BrandSkills CoveredPersonal branding, LinkedIn, Networking, Career AdvancementCollaboration WithGrow With GooglebeginnerCourse DetailsbeginnerLearn how to excel at networking both in-person and on LinkedIn.Learn More',
#   'Career Advancement'],
#  ['Free School of Programming How to Use Git and GitHubSkills CoveredGitHub, Version Control, RepositoriesbeginnerCourse DetailsbeginnerLearn to use version control, an important tool for any developer.  The course will focus on Git, a specific version control system, and GitHub, a collaboration platform.Learn More',
#   'School of Programming'],
#  ['Free School of Programming Programming Foundations with PythonSkills CoveredPython, Functions, Classes, Create a ClassbeginnerCourse DetailsbeginnerIntroductory programming class to learn Object-Oriented Programming, a must-have technique to reuse and share code easily. Learn by making projects that spread happiness!Learn More',
#   'School of Programming'],
#  ['Free School of AI Intro to Artificial IntelligenceSkills CoveredArtificial Intelligence, Machine Learning, Probability, Logic and Planning, Markov modelsintermediateCourse DetailsintermediateThis course will introduce you to the basics of AI. Topics include machine learning, probabilistic reasoning, robotics, computer vision, and natural language processing.Learn More',
#   'School of AI'],
#  ['New Career Advancement Craft Your Cover LetterSkills CoveredCreating a narrative, Targeting your pitch, Communicating value, Career AdvancementbeginnerCourse DetailsbeginnerWrite a compelling narrative that showcases your value to the company.Learn More',
#   'Career Advancement'],
#  ['New Career Advancement iOS Interview PrepSkills CoveredInterview practice, Common iOS Questions, Whiteboarding, Career AdvancementintermediateCourse DetailsintermediateAnswer iOS and mobile development interview questions with confidence and poise.Learn More',
#   'Career Advancement'],
#  ['Free School of AI Intro to Descriptive StatisticsSkills CoveredDescriptive Statistics, Estimation, Central Limit TheorembeginnerCourse DetailsbeginnerIntro to Descriptive Statistics will teach you the basic concepts of statistics that can be used to extract information from data.Learn More',
#   'School of AI'],
#  ['New School of Programming Build Native Mobile Apps with FlutterSkills CoveredAndroid DevelopmentCollaboration WithGoogleintermediateCourse DetailsintermediateLearn from experts at Google how to use Flutter to craft high-quality native interfaces on iOS and Android devices in record time.Learn More',
#   'School of Programming'],
#  ['New Career Advancement Android Interview PrepSkills CoveredInterview practice, Common Android Questions, Whiteboarding, Career AdvancementCollaboration WithGrow With GoogleintermediateCourse DetailsintermediateLearn how to respond to common Android and mobile development interview questions.Learn More',
#   'Career Advancement'],
#  ["Free School of Data Science Intro to Data AnalysisSkills CoveredData Analysis, Python, numpy, pandasbeginnerCourse DetailsbeginnerExplore a variety of datasets, posing and answering your own questions about each. You'll be using the Python libraries NumPy, Pandas, and Matplotlib.Learn More",
#   'School of Data Science'],
#  ["Free School of Programming Android Basics: User InputSkills CoveredAndroid Development, Java, Object Oriented Programming, Conditional Code, Methods, VariablesCollaboration WithGooglebeginnerCourse DetailsbeginnerLearn how to make your apps interactive using buttons and text! In this course you'll learn the basics of the Java programming language and how to apply them to Android.Learn More",
#   'School of Programming'],
#  ['Free School Of Business How to Build a StartupSkills CoveredEntrepreneurship, Value Proposition, Revenue Models, Customer SegmentsintermediateCourse DetailsintermediateLearn what it takes to build a successful startup using the Customer Development process, where entrepreneurs "get out of the building" to gather and iterate on feedback.Learn More',
#   'School Of Business'],
#  ['New Career Advancement VR Interview PrepSkills CoveredInterview practice, Common VR Questions, Whiteboarding, Career AdvancementCollaboration WithGrow With GoogleintermediateCourse DetailsintermediateLearn how to tackle interview questions for technical roles in VR Development.Learn More',
#   'Career Advancement'],
#  ['Free School of Programming Intro to StatisticsSkills CoveredProbability, Descriptive Statistics, Inferential StatisticsbeginnerCourse DetailsbeginnerGet ready to analyze, visualize, and interpret data! Thought-provoking examples and chances to combine statistics and programming will keep you engaged and challenged.Learn More',
#   'School of Programming'],
#  ['New Career Advancement Optimize Your GitHubSkills CoveredGitHub, Version Control, Repositories, Career AdvancementCollaboration WithGrow With GooglebeginnerCourse DetailsbeginnerGet noticed by recruiters and hiring managers with a professional GitHub Profile. Learn best practices on commit style and contributing to open source.Learn More',
#   'Career Advancement'],
#  ['Free School of Data Science Intro to Data ScienceSkills CoveredData Analysis Process, pandas (Python package), MapReduce paradigmintermediateCourse DetailsintermediateWhat does a data scientist do? In this course, we will survey the main topics in data science so you can understand the skills that are needed to become a data scientist!Learn More',
#   'School of Data Science'],
#  ['Free School of Programming Advanced Android App DevelopmentSkills CoveredAndroid Development, Fragments, Libraries, Firebase, EspressoCollaboration WithGoogleadvancedCourse DetailsadvancedMake your app production-ready by applying advanced features like library integration, material design, widgets, receiving cloud messages, and more!Learn More',
#   'School of Programming'],
#  ['New Career Advancement Data Science Interview PrepSkills CoveredInterview practice, Common Data Questions, Data Structures, Career AdvancementintermediateCourse DetailsintermediatePrepare for data science interviews by practicing data analysis, machine learning, and data structure and algorithms questions.Learn More',
#   'Career Advancement'],
#  ["Free School of Programming Android Basics: Multiscreen AppsSkills CoveredAndroid Development, Intents and Activities, Data, Loops and Custom Classes, Images and Visual Polish, Audio and LibrariesCollaboration WithGooglebeginnerCourse DetailsbeginnerLearn to build multiple screens and link them together, expanding the range of apps you can create! You'll also learn how to play audio and add images to your apps.Learn More",
#   'School of Programming'],
#  ['New Career Advancement Full-Stack Interview PrepSkills CoveredInterview practice, Common FS Questions, Whiteboarding, Career AdvancementintermediateCourse DetailsintermediateAnswer common full stack and web security interview questions with confidence and poise.Learn More',
#   'Career Advancement'],
#  ['Free School of Programming Scalable Microservices with KubernetesSkills CoveredMicroservices, Docker, Kubernetes, Deploying MicroservicesCollaboration WithGoogleintermediateCourse DetailsintermediateThis course is designed to teach you about managing microservices, using Kubernetes. This course is built in partnership with experts such as Google’s Kelsey Hightower.Learn More',
#   'School of Programming'],
#  ["Free School of Programming Responsive Web Design FundamentalsSkills CoveredResponsive design patterns, Remote debugging and emulation, Optimizing layout, CSS media queries, CSS flexboxCollaboration WithGoogleintermediateCourse DetailsintermediateLearn and practice strategies for developing websites that look great on every device! Made with Google's Pete LePage.Learn More",
#   'School of Programming'],
#  ['Free School of Programming Linux Command Line BasicsSkills CoveredCommand line interface (Linux server), Terminal and Shell (GNU Bash), Linux filesystem, Shell commandsbeginnerCourse DetailsbeginnerAn introduction to the Linux command line interface.Learn More',
#   'School of Programming'],
#  ['Free School of AI Introduction to Computer VisionSkills CoveredImage Processing, Stereo Geometry, Feature Detection & Matching, Object Tracking, Classification & RecognitionCollaboration WithGeorgia Institute of TechnologyintermediateCourse DetailsintermediateThis course provides an introduction to computer vision including fundamentals, methods for application and machine learning classification.Learn More',
#   'School of AI'],
#  ["Free School of AI Machine LearningSkills CoveredSupervised Learning, Unsupervised Learning, Information Theory, Reinforcement Learning, Game TheoryCollaboration WithGeorgia Institute of TechnologyintermediateCourse DetailsintermediateIn this course, you'll learn how to apply Supervised, Unsupervised and Reinforcement Learning techniques for solving a range of data science problems.Learn More",
#   'School of AI'],
#  ['Free School of Programming C++ For ProgrammersSkills CoveredPointers and Arrays, Control Flow, Object Oriented Programming, C++ Templates, C++ Standard LibraryintermediateCourse DetailsintermediateThis course teaches C++ to students already familiar with a programming language. Students will learn how to use header files, control flow, functions, classes.Learn More',
#   'School of Programming'],
#  ['New Career Advancement Front-End Interview PrepSkills CoveredInterview questions, Common FE Questions, Whiteboarding, Career AdvancementintermediateCourse DetailsintermediateAnswer front-end technical and behavioral interview questions with confidence and poise.Learn More',
#   'Career Advancement'],
#  ['Free School of AI Machine Learning for TradingSkills CoveredPandas, Time Series Analysis, Computational Investing, Algorithmic Trading, Reinforcement Learning for TradingCollaboration WithGeorgia Institute of TechnologyintermediateCourse DetailsintermediateImplement machine learning based strategies to make trading decisions using real-world data.Learn More',
#   'School of AI'],
#  ['Free School of Programming Intro to AlgorithmsSkills CoveredAlgorithms, Social Networks, Graph AlgorithmsintermediateCourse DetailsintermediateThis class will give you an introduction to the design and analysis of algorithms, enabling you to analyze networks and discover how individuals are connected.Learn More',
#   'School of Programming'],
#  ["Free School of Programming Android Basics: Data StorageSkills CoveredAndroid Development, SQLite, ContentProvider, CursorAdapter & CursorLoader, Database, DesignCollaboration WithGooglebeginnerCourse DetailsbeginnerIn this course, you'll learn the basics of data storage in Android, building your first database and an app that could be used for any small business!Learn More",
#   'School of Programming'],
#  ["Free School of Programming UX Design for Mobile DevelopersSkills CoveredAndroid, UX Design, User-Centered DesignCollaboration WithGooglebeginnerCourse DetailsbeginnerThis is a design course made for developers. You'll learn UX design skills which will help you make 5-star mobile apps that your users will love.Learn More",
#   'School of Programming'],
#  ['Free School of Data Science Intro to Inferential StatisticsSkills CoveredInferential Statistics, Hypothesis Testing, T-tests, ANOVAbeginnerCourse DetailsbeginnerIntro to Inferential Statistics will teach you how to test your hypotheses and begin to make predictions based on statistical results drawn from data!Learn More',
#   'School of Data Science'],
#  ['Free School of Programming Android Basics: NetworkingSkills CoveredAndroid Development, JSON Parsing, HTTP Networking, Threads and Parallelism, Control Flow and Conditionals, PreferencesCollaboration WithGooglebeginnerCourse DetailsbeginnerThis class teaches the basics of networking using Android, and is a part of the Android Basics Nanodegree by Google.Learn More',
#   'School of Programming'],
#  ['Free School of Programming Object Oriented Programming in JavaSkills CoveredObject Oriented Programming, Java, User InteractionintermediateCourse DetailsintermediateLearn how to apply powerful object-oriented programming concepts in JavaLearn More',
#   'School of Programming'],
#  ['New School of Programming Kotlin Bootcamp for ProgrammersSkills CoveredAndroid DevelopmentCollaboration WithGoogleintermediateCourse DetailsintermediateLearn the fundamentals of the Kotlin programming language from Kotlin experts at Google.Learn More',
#   'School of Programming'],
#  ['Free School of AI Data Analysis with RSkills CoveredR, Exploratory Data Analysis, Data VisualizationCollaboration WithFacebookintermediateCourse DetailsintermediateData is everywhere and so much of it is unexplored. Learn how to investigate and summarize data sets using R and eventually create your own analysis.Learn More',
#   'School of AI'],
#  ['Free School Of Business Product DesignSkills CoveredProduct Design, Design Sprints, Ideation and Validation, UI/UXCollaboration WithGoogleintermediateCourse DetailsintermediateLearn product validation, UI/UX practices, Google’s Design Sprint and the process for setting and tracking actionable metrics.Learn More',
#   'School Of Business'],
#  ['Free School of Programming Computer NetworkingSkills CoveredSoftware-Defined Networking, Data Center Networking, Content Distribution, Congestion Control, Traffic ShapingCollaboration WithGeorgia Institute of TechnologyintermediateCourse DetailsintermediateThis is an advanced Computer Networking course that delves into the latest concepts and tools used by the CN industry.Learn More',
#   'School of Programming'],
#  ['Free School of Programming Firebase in a Weekend: AndroidSkills CoveredAndroid DevelopmentCollaboration WithGoogleintermediateCourse DetailsintermediateThis course will teach you when and why to choose Firebase as a backend for your Android application.Learn More',
#   'School of Programming'],
#  ['Free School of Programming Intro to Relational DatabasesSkills CoveredRational databases, SQL, Python API, Python DB-API, Select and insert statementsintermediateCourse DetailsintermediateRelational databases are a powerful tool used throughout the industry. Learn the basics of SQL and how to connect your Python code to a relational database.Learn More',
#   'School of Programming'],
#  ['Free School of AI Reinforcement LearningSkills CoveredTemporal Difference Learning, Value Iteration, Policy Iteration, Reward Shaping, Game TheoryCollaboration WithGeorgia Institute of TechnologyadvancedCourse DetailsadvancedStudy machine learning at a deeper level and become a participant in the reinforcement learning research community.Learn More',
#   'School of AI'],
#  ['Free School of Programming Version Control with GitSkills CoveredGit, Version Control, Creating a Git repo, Editing commitsbeginnerCourse DetailsbeginnerLearn how to use Git, a popular Version Control System and essential tool for any developer.Learn More',
#   'School of Programming'],
#  ['Free School of Programming Website Performance OptimizationSkills CoveredChrome Developer Tools, DOM and CSSOM, Critical Rendering Path HTML, CSS and JavaScript optimizationsCollaboration WithGoogleintermediateCourse DetailsintermediateLearn how browsers convert HTML, CSS and JavaScript into websites while you experiment with Chrome Developer Tools to measure and optimize website speed!Learn More',
#   'School of Programming'],
#  ['Free School of AI Intro to Hadoop and MapReduceSkills CoveredBig Data, Hadoop, MapReduceCollaboration WithClouderaintermediateCourse DetailsintermediateIn this short course, learn the fundamentals of MapReduce and Apache Hadoop to start making sense of Big Data in the real world!Learn More',
#   'School of AI'],
#  ['Free School of Programming Kotlin for Android DevelopersSkills CoveredKotlin, AndroidadvancedCourse DetailsadvancedTake an Android app in Java and convert it to Kotlin, learning key features of the Kotlin programming language along the way.Learn More',
#   'School of Programming'],
#  ['Free School of AI Artificial Intelligence for RoboticsSkills CoveredProbabilistic Models, Kalman Filters, Motion Planning, Robot Control, Simultaneous Localization & MappingCollaboration WithGeorgia Institute of TechnologyadvancedCourse DetailsadvancedLearn how to program all the major systems of a robotic car. Topics include planning, search, localization, tracking, and control.Learn More',
#   'School of AI'],
#  ['Free School of Programming Introduction to Operating SystemsSkills CoveredProcesses & Threads, Memory Management, Inter-Process Communication, Resource Virtualization, Distributed File SystemsCollaboration WithGeorgia Institute of TechnologyintermediateCourse DetailsintermediateIntroduction to Operating Systems teaches the basic operating system abstractions, mechanisms, and their implementations.Learn More',
#   'School of Programming'],
#  ["Free School of Programming Networking for Web DevelopersSkills CoveredHTTP, Domain Name System, Ping, TCP/IP stack, IP addressingbeginnerCourse DetailsbeginnerYou've used the Internet. Now find out more about how it works.Learn More",
#   'School of Programming'],
#  ['Free School of Programming Full Stack FoundationsSkills CoveredFlask, CRUD, Model-View-Controller, Python, Object-relational MappingCollaboration WithAmazon Web ServicesintermediateCourse DetailsintermediateLearn the fundamentals of back-end web development by creating your own web application from the ground up using the iterative development process.Learn More',
#   'School of Programming'],
#  ['Free School of Programming Intro to iOS App Development with SwiftSkills CoveredSwift, UIKit, AVFoundationintermediateCourse DetailsintermediateTake the first step in becoming an iOS Developer by learning about Swift and writing your first app.Learn More',
#   'School of Programming'],
#  ['New Career Advancement Data Structures & Algorithms in PythonSkills CoveredInterview practice, Python, Data structures and Algorithms, Career AdvancementCollaboration WithGrow With GoogleintermediateCourse DetailsintermediateReview and practice the skills technical interviewers expect you to know and learn how to explain your Python solutions.Learn More',
#   'Career Advancement'],
#  ["Free School of Programming Swift for BeginnersSkills CoveredVariables and Constants, Strings, Control Flow, FunctionsbeginnerCourse DetailsbeginnerLearn Swift, Apple's programming language for building iOS applications. Start with the basics and work your way towards completing sets of challenges in Swift.Learn More",
#   'School of Programming'],
#  ["Free School of Programming Object-Oriented JavaScriptCollaboration WithHack ReactorintermediateCourse DetailsintermediateBuild a variety of JavaScript objects and explore how their inheritance models affect your app's in-memory model. Gain simplicity and modularity in your own code.Learn More",
#   'School of Programming'],
#  ['Free School of Programming Intro to Progressive Web AppsSkills CoveredProgressive Web Apps, Service Workers, Web App Manifest, Offline appsCollaboration WithGoogleintermediateCourse DetailsintermediateIn this course you’ll get started working on your very first Progressive Web App (PWA) - a web app that can take advantage of many features native applications have enjoyed!Learn More',
#   'School of Programming'],
#  ['Free School of AI Linear Algebra Refresher CourseSkills CoveredAlgebra, Python, Vectors, IntersectionsintermediateCourse DetailsintermediateLearn linear algebra by doing: you will code your own library of linear algebra functions!Learn More',
#   'School of AI'],
#  ['Free School of Programming GitHub & CollaborationSkills CoveredRepositories, Fork a repository, Create and Send a Pull Request, Remote Repositories, Collaborative projectsbeginnerCourse DetailsbeginnerLearn how to interact with remote repositories and collaborate with other developers on GitHub.Learn More',
#   'School of Programming'],
#  ['Free School of Programming Responsive ImagesSkills CoveredResponsive Images, Mobile Image debugging, Creating responsive graphicsCollaboration WithGoogleintermediateCourse DetailsintermediateGo beyond image tags! Learn how to make images a part of your responsive design workflow.Learn More',
#   'School of Programming'],
#  ['Free School of Programming Designing RESTful APIsSkills CoveredFlask, REST APIs, PythonintermediateCourse DetailsintermediateBuild and secure a web server with a RESTful Developer-Friendly API that developers will love to use.Learn More',
#   'School of Programming'],
#  ['Free School of Programming Intro to HTML and CSSbeginnerCourse DetailsbeginnerLearn how to convert digital design mockups into static web pages and how to build a responsive portfolio site to showcase your work.Learn More',
#   'School of Programming'],
#  ['Free School of Programming JavaScript PromisesSkills CoveredNative JavaScript Promises, Asynchronous code, Advanced error handling, Generating sequences of async workCollaboration WithGoogleadvancedCourse DetailsadvancedLearn how to simplify asynchronous work with Native JavaScript Promises!Learn More',
#   'School of Programming'],
#  ['Free School of Programming ES6 - JavaScript ImprovedSkills CoveredJavaScript, ES6, Syntax, FunctionsadvancedCourse DetailsadvancedLearn about the changes made to the JavaScript programming language in ECMAScript 6 and how to use these new improvements to write better cleaner code.Learn More',
#   'School of Programming'],
#  ['Free School of Programming JavaScript Design PatternsSkills CoveredSeparating concerns, Code organization, Using an Organizational Library, KnockoutJSadvancedCourse DetailsadvancedLearn the importance of code organization and how to implement it with either vanilla JavaScript or an organizational library or framework.Learn More',
#   'School of Programming'],
#  ['Free School of Programming Data Wrangling with MongoDBSkills CoveredGathering Data, Assessing Data, Cleaning Data, Data Wrangling, MongoDBCollaboration WithMongoDBintermediateCourse DetailsintermediateData Scientists spend most of their time cleaning data. In this course, you will learn to convert and manipulate messy data to extract what you need.Learn More',
#   'School of Programming'],
#  ['Free School of Programming Software TestingSkills CoveredSoftware Testing, Debugging, Code CoverageintermediateCourse DetailsintermediateLearn how to catch bugs and break software as you discover different testing methods that will help you build better software.Learn More',
#   'School of Programming'],
#  ["Free School of Programming Material Design for Android DevelopersSkills CoveredAndroid Development, Material Design, Surfaces, Graphic DesignCollaboration WithGoogleintermediateCourse DetailsintermediateLearn and apply the material design principles that define Android's visual language to your apps.Learn More",
#   'School of Programming'],
#  ['Free School of Programming Intro to AJAXSkills CoveredAsynchronous requests with JavaScript, Data APIs, Web Applications, Site CustomizationintermediateCourse DetailsintermediateLearn how to perform asynchronous requests as you build a web app with data from Google Street View, the New York Times and Wikipedia!Learn More',
#   'School of Programming'],
#  ['New Career Advancement Machine Learning Interview PreparationSkills CoveredInterview practice, Machine Learning, Career AdvancementintermediateCourse DetailsintermediateIn this course, you’ll learn exactly what to expect during a machine learning interview.Learn More',
#   'Career Advancement'],
#  ['Free School of Programming Introduction to CybersecurityCollaboration WithChronicleintermediateCourse DetailsintermediateExplore the fundamental building blocks of cybersecurity.Learn More',
#   'School of Programming'],
#  ["Free School of Programming Android Wear DevelopmentSkills CoveredAndroid, Android Wear, Smartwatches, Ubiquitous ComputingCollaboration WithGoogleadvancedCourse DetailsadvancedLearn how to extend your app to Android Wear smartwatches, allowing you to reach users wherever and whenever they'd want or need your app.Learn More",
#   'School of Programming'],
#  ['School of Data Science Data EngineerSkills CoveredData Modeling, Data Pipelines, Data Lakes, Spark, AirflowintermediateNanodegree DetailsintermediateLearn More',
#   'School of Data Science'],
#  ['Free School of AI A/B TestingSkills CoveredA/B Testing, Experiment Design, StatisticsCollaboration WithGoogleintermediateCourse DetailsintermediateDesign and implement an A/B test to determine the efficacy of potential improvements to an online site or mobile app while specifying metrics to measure.Learn More',
#   'School of AI'],
#  ["New School of Programming Blockchain Developer Nanodegree programSkills CoveredEthereum Blockchain, Blockchain Architecture, Data AuditingintermediateNanodegree DetailsintermediateDemand for blockchain developers is skyrocketing. In this program, you'll work with the Bitcoin and Ethereum protocols, build projects for real-world application, and gain the essential skills for a career in this dynamic space.Learn More",
#   'School of Programming'],
#  ['New School Of Autonomous Systems Self-Driving Fundamentals: Featuring Apollo Skills CoveredApollo HD Map, Localization, Perception, Prediction, Planning, ControlCollaboration WithBaidubeginnerCourse DetailsbeginnerIdentify key parts of self-driving cars, utilize Apollo HD Map, localization, perception, prediction, planning and control, and start the learning path of building a self-driving car. Learn More',
#   'School Of Autonomous Systems'],
#  ["Free School of Programming Android Auto DevelopmentSkills CoveredAndroid Development, Auto Development, Ubiquitous ComputingCollaboration WithGoogleadvancedCourse DetailsadvancedReach your users while they're out and about by extending your Media or Messaging app to Android Auto!Learn More",
#   'School of Programming'],
#  ['New School Of Business Marketing AnalyticsSkills CoveredGoogle Analytics, Excel & Spreadsheets, Data Visualization, Customer SegmentationbeginnerNanodegree DetailsbeginnerGain foundational data skills applicable to marketing. Collect and analyze data, model marketing scenarios, and communicate your findings with Excel, Tableau, Google Analytics, and Data Studios.Learn More',
#   'School Of Business'],
#  ['New School of AI Intro to TensorFlow for Deep LearningCollaboration WithTensorFlowintermediateCourse DetailsintermediateDeveloped by Google and Udacity, this course teaches a practical approach to deep learning for software developers.Learn More',
#   'School of AI'],
#  ['New School of AI Intro to Deep Learning with PyTorchSkills CoveredDeep Learning, PyTorch, Neural Networks, CNNs, LSTMs, Style TransferCollaboration WithFacebook AIintermediateCourse DetailsintermediateLearn the basics of deep learning and implement your own deep neural networks with PyTorchLearn More',
#   'School of AI'],
#  ['Free School of Programming Android TV and Google Cast DevelopmentSkills CoveredAndroid Development, Android TV, Google Cast, Ubiquitous ComputingCollaboration WithGoogleadvancedCourse DetailsadvancedGo where your users are: the living room! This course shows you how to extend your existing Android app to also work on Android TV, and/or with Google Cast.Learn More',
#   'School of Programming'],
#  ['New School of Programming Developing Android Apps with KotlinSkills CoveredAndroid DevelopmentCollaboration WithGoogleintermediateCourse DetailsintermediateLearn the fundamentals of the Kotlin programming language from Kotlin experts at Google.Learn More',
#   'School of Programming'],
#  ['Free School of Programming Intro to DevOpsSkills CoveredDevOps, CAMS principles, Continuous Integration, Delivery workflowsCollaboration WithNutanixadvancedCourse DetailsadvancedLearn all about the DevOps landscape, workflow, and a survey of the systems currently being used to support scalable software deployment.Learn More',
#   'School of Programming'],
#  ['Free School of Programming HTML5 CanvasSkills CoveredHTML5 Canvas, Canvas2D, Creating animationbeginnerCourse DetailsbeginnerLearn how you can use HTML5 Canvas to create and modify images or even interactive animations.Learn More',
#   'School of Programming'],
#  ['Free School of Programming Software Architecture & DesignSkills CoveredUnified Modeling Language, Object Constraint Language, Software Architecture, Software Design, Code ReviewCollaboration WithGeorgia Institute of TechnologyintermediateCourse DetailsintermediateSoftware Architecture and Design teaches the principles and concepts involved in the analysis and design of large software systems.Learn More',
#   'School of Programming'],
#  ['Free School of Programming Shell WorkshopSkills CoveredShell, Using Terminal, Running command-line programs, Customizing ShellbeginnerCourse DetailsbeginnerThe Unix shell is a valuable tool for developing and deploying software. Learn the basics of this terminal-based, command-line interface.Learn More',
#   'School of Programming'],
#  ['No Image AvailableFree School of Programming Intro to BackendSkills CoveredUser Input, Producing templated output, Databases and data stores, Secure user account systemsintermediateCourse DetailsintermediateLearn to build a multiuser blog with Google App Engine that permits users to sign inLearn More',
#   'School of Programming'],
#  ['Free School of Programming Software Development ProcessSkills CoveredSoftware Development Life Cycle, Requirements Engineering, Design Patterns, Black-Box & White-Box Testing, Agile Development MethodologyCollaboration WithGeorgia Institute of TechnologyintermediateCourse DetailsintermediateSoftware Development Processes explores requirements engineering, architecture and design, testing, and software quality in general.Learn More',
#   'School of Programming'],
#  ['Free School of Programming Gradle for Android and JavaSkills CoveredAndroid Development, Gradle, JavaCollaboration WithGoogle, GradleadvancedCourse DetailsadvancedBuild bigger and better Android and Java apps using the Gradle build tool.Learn More',
#   'School of Programming'],
#  ['Free School Of Business Problem Solving with Advanced AnalyticsSkills CoveredLinear RegressionCollaboration WithAlteryxbeginnerCourse DetailsbeginnerLearn a scientific approach to solving problems with data, a foundational skill for anyone interested in making data driven decisions in a business context.Learn More',
#   'School Of Business'],
#  ['Free School of Programming Introduction to Virtual RealitySkills CoveredVR development, Unity, Google VR SDK for Unity, General understanding of how VR works, Deploying to Android and iOSCollaboration WithGoogle VRbeginnerCourse DetailsbeginnerIf you are interested in learning more about virtual reality, this course will teach you the principles of VR technology and help you understand what you can build in VR.Learn More',
#   'School of Programming'],
#  ['Free School of AI Data Visualization and D3.jsSkills Coveredd3.js, Design of Visualizations, Data Visualization, Visual EncodingsCollaboration WithZipfianintermediateCourse DetailsintermediateLearn the fundamentals of data visualization and apply design and narrative concepts to create your own visualization.Learn More',
#   'School of AI'],
#  ['Free School of Programming Intro to jQuerySkills CoveredjQuery, DOM Structure, Reading jQuery documentation, Modify HTML attributes and contentintermediateCourse DetailsintermediateLearn how to access and modify the DOM with ease using jQuery!Learn More',
#   'School of Programming'],
# ...
#   'School of AI'],
#  ['Free School Of Business A/B Testing for Business AnalystsSkills CoveredA/B Randomized Design Tests, A/B Matched Pair Design TestsintermediateCourse DetailsintermediateThe A/B Testing course provides students with the foundational knowledge to design and analyze A/B tests to create business insights and support decision making.Learn More',
#   'School Of Business'],
#  ['Free School of Programming iOS Networking with SwiftSkills CoveredNetworking, URLSession, JSON ParsingadvancedCourse DetailsadvancedLearn how to incorporate networking into your apps to access data from around the world. Build the On the Map app to share location and fun links with fellow students.Learn More',
#   'School of Programming'],
#  ['Free School of Programming Building High Conversion Web FormsSkills CoveredResearch HTML5 input types, Datalist input, User input validation with HTML5 attributes, Validate user input using JavaScript, Optimizing formsCollaboration WithGoogleintermediateCourse DetailsintermediateIncrease conversions with best practices for fast, efficient forms! Learn how to design and build web forms for users on any device.Learn More',
#   'School of Programming'],
#  ['Free School of Programming UIKit FundamentalsSkills CoveredAutoLayout, Navigation, Table Views, Collection ViewsintermediateCourse DetailsintermediateLearn the iOS UIKit framework, which is the cornerstone of creating user interfaces in all iOS apps and crucial for any iOS Developer to be intimately familiar with.Learn More',
#   'School of Programming'],
#  ['Free School Of Business Classification ModelsSkills CoveredBinary Classication Models, Non-Binary Classification ModelsCollaboration WithAlteryxintermediateCourse DetailsintermediateLearn how to use classification predictive models to solve business problems involving non-numeric data.Learn More',
#   'School Of Business'],
#  ["Free School of Programming Firebase Analytics: AndroidSkills CoveredAndroid Development, Firebase, AnalyticsCollaboration WithGoogleintermediateCourse DetailsintermediateLearn how to grow an app's user base using Firebase Analytics, a free and unlimited analytics solutionLearn More",
#   'School of Programming'],
#  ['FreeVR Software DevelopmentSkills CoveredVR development, Unity, Google VR SDK for Unity, C#, UI interfaces and interactionCollaboration WithGoogle VRbeginnerCourse DetailsbeginnerLearn about the world of virtual reality programming! You will learn the basics of programming in C# and how to use it control virtual reality applications in Unity.Learn More',
#   'Skills Covered'],
#  ['Free School of AI Knowledge-Based AI: Cognitive SystemsSkills CoveredSemantic Networks, Common-Sense Reasoning, Logic & Planning, Analogical Reasoning, Visuospatial ReasoningCollaboration WithGeorgia Institute of TechnologyadvancedCourse DetailsadvancedThe twin goals of knowledge-based artificial intelligence (AI) are to build AI agents capable of human-level intelligence and gain insights into human cognition.Learn More',
#   'School of AI'],
#  ['Free School Of Autonomous Systems Differential Equations in ActionSkills CoveredMath, Differential EquationsintermediateCourse DetailsintermediateWrite Python code to find numerical solutions to systems of differential equations. The models you create will fight wildfires, bring spaceships back to earth, and more!Learn More',
#   'School Of Autonomous Systems'],
#  ['FreeComputational PhotographySkills CoveredDigital Imaging, Panorama & Morphing, Light Field, High Dynamic Range, Video StabilizationCollaboration WithGeorgia Institute of TechnologyintermediateCourse DetailsintermediateThis class explores how computation impacts the entire workflow of photography, which is traditionally aimed at capturing light from a 3D scene to form a 2D image.Learn More',
#   'Skills Covered'],
#  ['Free School of AI Real-Time Analytics with Apache StormSkills CoveredData Analysis, Real-time Analytics, Apache StormCollaboration WithTwitterintermediateCourse DetailsintermediateThe world is trending in real time! Learn Apache Storm, taught by Twitter, to scalably analyze real-time tweets and drive d3 visualizations. Storm is free, open and fun!Learn More',
#   'School of AI'],
#  ['Free School Of Business Segmentation and ClusteringSkills CoveredVariable Reduction, Clustering Models designintermediateCourse DetailsintermediateThe Segmentation & Clustering course provides students with the knowledge to build and apply clustering models to develop sophisticated segmentation in business contexts.Learn More',
#   'School Of Business'],
#  ['Free School of Programming Human-Computer InteractionSkills CoveredDesign Principles, Direct Manipulation Interfaces, Mental Models, Distributed Cognition, PrototypingCollaboration WithGeorgia Institute of TechnologyintermediateCourse DetailsintermediateThis course is an introductory course on human-computer interaction, covering the principles, techniques, and open areas of development in HCI.Learn More',
#   'School of Programming'],
#  ['FreeVR Scenes and ObjectsSkills CoveredVR development, Unity, Google VR SDK for Unity, Game Objects, MaterialsCollaboration WithGoogle VRbeginnerCourse DetailsbeginnerTake the first step in Unity and begin to develop VR content. Learn the principles of the Unity platform and help you understand what you can build in VR!Learn More',
#   'Skills Covered'],
#  ['Free School Of Business App MonetizationSkills CoveredProduct Design, Google AnalyticsCollaboration WithGoogleintermediateCourse DetailsintermediateLearn how to effectively develop, implement, and measure your monetization strategy, iterating on the model as appropriate.Learn More',
#   'School Of Business'],
#  ['Free School of Programming Learn Backbone.jsSkills CoveredBackbone, Building a Todo Application from Scratch, Data with FirebaseadvancedCourse DetailsadvancedThis is a collection of curated resources to teach you how to write well organized web applications using the Backbone framework.Learn More',
#   'School of Programming'],
#  ['Free School of Programming Software Analysis & TestingSkills CoveredSoftware Testing, Debugging, Dataflow Analysis, Constraint-based Analysis, Symbolic ExecutionCollaboration WithGeorgia Institute of TechnologyintermediateCourse DetailsintermediateThis course covers the theory and practice of software analysis, which is at the heart of software development processes such as diagnosing bugs, testing, and debugging.Learn More',
#   'School of Programming'],
#  ["Free School of Programming Core ML: Machine Learning for iOSSkills CoverediOS, Image Classification, Core MLintermediateCourse DetailsintermediateLearn how to use Apple's Core ML framework to build iOS apps with intelligent new features.Learn More",
#   'School of Programming'],
#  ['Free School of Programming Deploying Applications with HerokuSkills CoveredApp Deployment, HerokuintermediateCourse DetailsintermediateDeploy your first web application using the Heroku platform and learn about the underlying mechanics of web hosting.Learn More',
#   'School of Programming'],
#  ['Free School of Programming iOS Persistence and Core DataSkills CoveredData Persistence, Core Data, UserDefaults, FileManageradvancedCourse DetailsadvancedPersisting data is a core skill for any iOS developer. Learn how to store app data to your device using three common techniques: NSUserDefaults, Sandbox, and Core Data.Learn More',
#   'School of Programming'],
#  ["No Image AvailableFree School of Programming How to Install Android StudioSkills CoveredAndroid, Android Studio, JavabeginnerCourse DetailsbeginnerParticipate in this short tutorial to install Android Studio on your computer and set up a new project using the program's Project Wizard.Learn More",
#   'School of Programming'],
#  ['Free School of Programming AutoLayoutSkills CoveredDesign, UI, Stack Views, ConstraintsintermediateCourse DetailsintermediateWith this course, you will learn about AutoLayout and how to use stack views and constraints to create pixel-perfect UIs.Learn More',
#   'School of Programming'],
#  ['FreeEducational TechnologySkills CoveredEducational Technology & Research, Online Learning, Game-based Learning, Communities of Practice, Ethics & Privacy in EdTechCollaboration WithGeorgia Institute of TechnologybeginnerCourse DetailsbeginnerThis class is an an introductory course about educational technology offered as CS6460 at Georgia Tech where it is a part of the Online Masters Degree (OMS).Learn More',
#   'Skills Covered'],
#  ['FreeTales from the GenomeSkills CoveredGenetics, DNA, Gene regulationCollaboration With23andMebeginnerCourse DetailsbeginnerLearn the basics of genetics, with a personal twist. This class is all about DNA and how it shapes who we are.Learn More',
#   'Skills Covered'],
#  ["Free School of Programming Mobile Design and Usability for iOSSkills CoveredProduct Design, PrototypingCollaboration WithFacebook for DevelopersintermediateCourse DetailsintermediateIn this course, taught in collaboration with Facebook, you'll learn how to design an intuitive, user-centered mobile app, from product conception to release.Learn More",
#   'School of Programming'],
#  ['Free School of Programming Deploying a Hadoop ClusterSkills CoveredData Analysis, Hadoop, MapReduceintermediateCourse DetailsintermediateDeploy your own Hadoop cluster to crunch some big data!Learn More',
#   'School of Programming'],
#  ['Free School of Programming Firebase in a Weekend: iOSSkills CoveredAndroid DevelopmentCollaboration WithGoogleintermediateCourse DetailsintermediateThis course will teach you when and why to choose Firebase as a backend for your iOS application.Learn More',
#   'School of Programming'],
#  ["Free School of Programming Server-Side SwiftSkills CoveredSwift Package Manager, MySQL, Docker, Terraform, MicroservicesintermediateCourse DetailsintermediateIn this course, built in collaboration with IBM and Hashicorp, you'll learn how to use Swift as a server-side language for building end-to-end applications.Learn More",
#   'School of Programming'],
#  ["Free School of Programming Passwordless Login Solutions for iOSSkills CoveredAccount Kit, Facebook SDK, Graph APICollaboration WithFacebook for DevelopersintermediateCourse DetailsintermediateIn this course you'll implement Account Kit and Facebook Login side by side in a sample app, test our login flow on a series of common use cases, and wrap things up with an introduction to Facebook’s Graph API.Learn More",
#   'School of Programming'],
#  ['Free School of AI Eigenvectors and EigenvaluesSkills CoveredLinear Algebra, Eigenvectors, EigenvaluesbeginnerCourse DetailsbeginnerLearn how to calculate eigenvalues and eigenvectors and why they are important for AI applications.Learn More',
#   'School of AI'],
#  ["Free School of Programming Xcode DebuggingSkills CoveredDebugging, LLDBadvancedCourse DetailsadvancedIn this course, you'll learn standard methodologies for debugging software, and how to use Xcode's debugging tools to find and squash bugs.Learn More",
#   'School of Programming'],
#  ['Free School of Programming The MVC Pattern in RubySkills CoveredRuby, Sinatra, MVC Design Pattern, Writing organized codeintermediateCourse DetailsintermediateIn this course you’ll learn how to organize your code, and why that’s important. You’ll be using the MVC Design Pattern in the web application micro-framework Sinatra.Learn More',
#   'School of Programming'],
#  ['FreeHealth Informatics in the CloudSkills CoveredHealth Information Exchange, Security and Trust, Interoperability Standards, Data Collection & VisualizationCollaboration WithGeorgia Institute of TechnologybeginnerCourse DetailsbeginnerThis survey course provides a broad, forward-facing overview of contemporary health informatics within the context of the US healthcare delivery system.Learn More',
#   'Skills Covered'],
#  ['Free School of Programming Cyber-Physical Systems SecuritySkills CoveredIndustrial Networks, Industrial Control Systems, Smart Grid Infrastructure, Cyber Security, PrivacyCollaboration WithGeorgia Institute of TechnologyintermediateCourse DetailsintermediateThis course provides an introduction to security issues relating to cyber-physical systems including industrial control systems and critical infrastructures.Learn More',
#   'School of Programming'],
#  ["Free School of Programming Dynamic Web Applications with SinatraSkills CoveredRuby, Sinatra, Building web applicationsintermediateCourse DetailsintermediateSinatra is a micro-framework for quickly developing small Ruby applications for the web. In this course, you'll learn all about Sinatra, routing, and templating.Learn More",
#   'School of Programming'],
#  ["Free School of Programming Intro to Point & Click App DevelopmentSkills CoveredSalesforce App Development, Schema Building, Data ModelingCollaboration WithSalesforcebeginnerCourse DetailsbeginnerIn this short class you'll build powerful apps without writing code. Great if you're an aspiring developer or someone who wants to learn what programmers do.Learn More",
#   'School of Programming'],
#  ["Free School of Programming Grand Central Dispatch (GCD)Skills CoveredClosures, GCDintermediateCourse DetailsintermediateLearn how to prevent background operations from interfering with an app's UI by implementing Apple's GCD framework.Learn More",
#   'School of Programming'],
#  ["Free School of Programming Firebase Analytics: iOSSkills CoveredAndroid Development, Firebase Analytics, Firebase Crash Reporting, Firebase Remote Config, Firebase Dynamic LinksCollaboration WithGoogleintermediateCourse DetailsintermediateLearn how to grow an app's user base using Firebase Analytics, a free and unlimited analytics solutionLearn More",
#   'School of Programming'],
#  ['Free School of Programming How to Make a Platformer Using libGDXSkills CoveredLibGDX, Game Development, Asset managementCollaboration WithAmazon Appstore for AndroidintermediateCourse DetailsintermediateThis course will explore how to create a game called Giga Gal. Giga Gal is a platformer in which you run, collect energy packs, jump a bunch, and shoot enemies.Learn More',
#   'School of Programming'],
#  ['Free School of Programming Introduction to Graduate AlgorithmsCollaboration WithGeorgia Institute of TechnologyadvancedCourse DetailsadvancedLearn advanced techniques for designing algorithms and apply them to hard computational problems.Learn More',
#   'School of Programming'],
#  ['Free School of Programming Engagement & Monetization | Mobile GamesSkills CoveredGame Development, Monetization, EngagementCollaboration WithAmazon Appstore for AndroidbeginnerCourse DetailsbeginnerYou will learn the most effective monetization strategies for your game, how to  keep your players interested and engaged, so that your game stands out in the app store.Learn More',
#   'School of Programming'],
#  ["School of Programming Intro to ProgrammingSkills CoveredIntroduction to Programming, HTML, CSS, PythonbeginnerCourse DetailsbeginnerThis introductory Nanodegree program teaches you the foundational skills all programmers use. It's ideal for beginners who want make informed choices about career goals.Learn More",
#   'School of Programming'],
#  ['New School Of Autonomous Systems Cyber-Physical Systems Design & AnalysisCollaboration WithGeorgia Institute of TechnologyadvancedCourse DetailsadvancedThis course provides an introduction to cyber-physical systems with an industrial perspective.Learn More',
#   'School Of Autonomous Systems'],
#  ['FreeOMSCS Student OrientationCollaboration WithGeorgia Institute of TechnologybeginnerCourse DetailsbeginnerIn this OMS Orientation, we cover several things you will need to know to be a successful OMS student.Learn More',
#   'Collaboration With']]

# %%
# display results
print(len(courses), "course summaries found. Sample:")
courses[:20]
# Out:
# 227 course summaries found. Sample:
# [['New School of Programming Data Structures and AlgorithmsSkills CoveredData Structures and Algorithms, Problem Solving, Interview Practice Problems, PythonintermediateNanodegree DetailsintermediateGet hands-on practice with over 100 data structures and algorithm exercises and guidance from a dedicated mentor to help prepare you for interviews and on-the-job scenarios.Learn More',
#   'School of Programming'],
#  ['New School of Programming VR FoundationsSkills CoveredUnity, VR Principles, Major VR Platforms, VR Scenes and Objects, Programming AnimationsCollaboration WithUnitybeginnerNanodegree DetailsbeginnerLearn the Unity game engine, C#, and Google Cardboard, and gain foundational VR knowledge and skills.Learn More',
#   'School of Programming'],
#  ['New School of Programming VR Mobile 360Skills CoveredUnity, VR Design Principles, VR Platforms and Applications, Mobile Performance, 360 Media ProductionCollaboration WithUnityintermediateNanodegree DetailsintermediateCombine a specific focus on Mobile 360 Media with learning core Unity game engine and C# skills, and advance your VR expertiseLearn More',
#   'School of Programming'],
#  ['New School of Programming VR High-ImmersionSkills CoveredUnity, VR Design Principles, VR Platforms and Applications, High-Immersion, Performance BouncebackCollaboration WithUnityintermediateNanodegree DetailsintermediateLearn the advanced tools and techniques required for creating high-immersion VR experiences, as you build upon your Unity Game Engine and C# skills.Learn More',
#   'School of Programming'],
#  ['New School Of Business Google AnalyticsCollaboration WithGoogle, E-NorintermediateNanodegree DetailsintermediateAdvance your marketing or data analytics career. Unlike other online programs, our curriculum is shaped by Google’s Google Analytics education experts and provides students with an in-depth Google Analytics education using real-world projects and real data. Learn More',
#   'School Of Business'],
#  ['New School of AI Artificial Intelligence for TradingCollaboration WithWorldQuantintermediateNanodegree DetailsintermediateComplete real-world projects designed by industry experts, covering topics from asset management to trading signal generation. Master AI algorithms for trading, and build your career-ready portfolio.Learn More',
#   'School of AI'],
#  ['School of Programming Python FoundationSkills CoveredProgramming, pandas, NumPyintermediateNanodegree DetailsintermediateLearn how to program in Python and get ready for a career in data science, machine learning, deep learning, and artificial intelligence.Learn More',
#   'School of Programming'],
#  ['School of Data Science Data AnalystSkills CoveredPython, SQL, Statistics, Data Wrangling, Data VisualizationCollaboration WithKaggle, ModeintermediateNanodegree DetailsintermediateLearn to clean up messy data, uncover patterns and insights, make predictions using machine learning, and clearly communicate your findings.Learn More',
#   'School of Data Science'],
#  ['School of AI Machine Learning FoundationSkills CoveredIntroduction to Programming, Descriptive Statistics, Linear Algebra, Inferential Statistics, Evaluation and VerificationCollaboration WithkagglebeginnerNanodegree DetailsbeginnerLearn Python, Statistics and Linear Algebra to get your foundations right and ready for the advanced Machine Learning Engineer Nanodegree Program.Learn More',
#   'School of AI'],
#  ['School of AI AI Programming with PythonbeginnerNanodegree DetailsbeginnerLearn Python, NumPy, Pandas, Matplotlib, PyTorch, Calculus, and Linear Algebra—the foundations for building your own neural network.Learn More',
#   'School of AI'],
#  ['School of Programming Become an Android DeveloperSkills CoveredAndroid Development, Databases, Android Networking Libraries, Crash Analysis, Multilingual Support, Android Libraries, Gradle, APIsCollaboration WithGoogleintermediateNanodegree DetailsintermediateStart your career as an Android developer. Learn best practices for mobile development, build a portfolio of apps, and publish your own app to Google Play.Learn More',
#   'School of Programming'],
#  ['School of Programming Become a Professional Full Stack DeveloperSkills CoveredPython, JavaScript, SQL, HTML5 & CSS3, Python, Databases, Authentication & Authorization, AJAX & APIs, Configuration of Servers, Linux BasicsCollaboration WithGoogle, Amazon Web Services, GitHub, AT&TintermediateNanodegree DetailsintermediateIn this program, you’ll prepare for a job as a Full Stack Web Developer, and learn to create complex server-side web applications that use powerful relational databases to persistently store data.Learn More',
#   'School of Programming'],
#  ['New School of Data Science Become a Data ScientistCollaboration WithBertelsmann, Figure Eight, IBM Watson, Insight, Kaggle, StarbucksadvancedNanodegree DetailsadvancedWork on real-world data science projects designed by industry leaders. Enjoy support from mentors. Build your portfolio, and advance your data science career.Learn More',
#   'School of Data Science'],
#  ['School of Programming Android Basics by GoogleSkills CoveredAndroid Development, Java programming, Android Studio, XML layouts, Android ViewsCollaboration WithGooglebeginnerNanodegree DetailsbeginnerNo programming experience? No Problem! Start developing Android apps today.Learn More',
#   'School of Programming'],
#  ['School of AI Artificial IntelligenceSkills CoveredAI Algorithms, Search Algorithms, Optimization, Planning, Pattern RecognitionadvancedNanodegree DetailsadvancedLearn essential Artificial Intelligence concepts from AI experts like Peter Norvig and Sebastian Thrun, including search, optimization, planning, pattern recognition, and more.Learn More',
#   'School of AI'],
#  ['School of Programming IoT Software FoundationSkills CoveredPython programming, Backend Databases and Applications, C++ Basics, Performance Programming in C++, Hadoop and Mapreduce, Sensors and Controls, Natural Language Processing, Voice User InterfacesbeginnerNanodegree DetailsbeginnerBuild the future of smart living. Learn how to independently design, code, and build IOT products.Learn More',
#   'School of Programming'],
#  ['School of Programming Become a Front End DeveloperSkills CoveredJavaScript, jQuery, HTML5, HTML, CSS, Python, Object-Oriented ProgrammingCollaboration WithAT&T, Google, GithubintermediateNanodegree DetailsintermediateIn the Front End Developer Nanodegree program, you will complete five projects and build a resume-worthy portfolio.Learn More',
#   'School of Programming'],
#  ["School of Programming Learn to CodeSkills CoveredIntroduction to Programming, HTML, CSS, PythonbeginnerNanodegree DetailsbeginnerUdacity's Intro to Programming is your first step towards careers in Web and App Development, Machine Learning, Data Science, AI, and more! This program is perfect for beginners.Learn More",
#   'School of Programming'],
#  ['School Of Business Digital MarketingSkills CoveredDigital Marketing, Social Media Marketing, Facebook Marketing, Search Engine Optimization, Search Engine MarketingCollaboration WithFacebook Blueprint, Google, Hootsuite, HubSpot, MailChimp, MozbeginnerNanodegree DetailsbeginnerGain real-world experience running live campaigns as you learn from top experts in the field. Launch your career with a 360-degree understanding of digital marketing.Learn More',
#   'School Of Business'],
#  ['New School Of Autonomous Systems Robotics Software EngineerSkills CoveredC++, ROS, Localization, Mapping, SLAM, Navigation, Path PlanningadvancedNanodegree DetailsadvancedBuild five hands-on projects to acquire core robotics software engineering skills: ROS, Gazebo, Localization, Mapping, SLAM, Navigation, and Path Planning.Learn More',
#   'School Of Autonomous Systems']]
